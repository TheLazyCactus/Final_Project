# %%
import requests

cookies = {
    'tc_cj_v2_cmp': '',
    'tc_cj_v2_med': '',
    'tc_ts': '40',
    'FRONTONE_ONLINE': '1745247464',
    'FRONTONE_SESSION_ID': 'fe0e97616cc0dc73679f62b16fa7c577b2d86018',
    'CAID': '202503221557457366701354',
    'OptanonAlertBoxClosed': '2025-03-22T14:57:49.848Z',
    'eupubconsent-v2': 'CQOq1pgQOq1pgAcABBENBiFwAAAAAAAAAChQAAAAAAChIAYAygF5gTAHQAwBlALzAmAOAAgSEJQAQF5lIAYAygF5gTAA.YAAAAAAAAAAA',
    'OneTrustGroupsConsent': '%2CC0048%2CC0001%2C',
    'FRONTONE_SESSID': 'uim3dg95re0gh6j1p6jnc30adj',
    'sap-closed': '1',
    'tc_eff_params': '',
    'tc_ab': '1',
    'aaaaaaaaa944fac35b02f4d9a99619247b88ad463_cs': '',
    'tc_cj_v2': '%5Ecl_%5Dny%5B%5D%5D_mmZZZZZZKQNLPOONPSSJKZZZ%5D777m_iZZZ%2C2%7B%29%2FZZZKQNMLOJOSNKMQZZZ%5D777%5Ecl_%5Dny%5B%5D%5D_mmZZZZZZKQNMPROPSPJMRZZZ%5D',
    'cf_clearance': 'ejQ63F_1s06TNPQ7ARE1hYyun_ngF5WZ4HM.KyqVwWY-1743685936-1.2.1.1-W8hQPeNII6esIHjsPj7mz__mVqGsfGX.4Em.5k5VJq17i1ECsSPwpJ9PbKaIEPYtAZ7IeajQ7BgsgU7SCaKU9c.9eU2rdBxHL_OpYOiShsFZratV5nPQ7ngFo1nSSNapiTi209Z3bQhHwElT_XXZmtY6z6FGVJIGKiWBs7wsB335RvPO1ZNg8M1SvxNOi1w0w4xyCl73oLfq671G3mvr_gs40kp_YzX9pZWwsppILZK9SML.CWqDdrCu_2toPyZjHKCi3ol8gISXaqo.CLZxoIPRrfCq32k2TZuSP7t3XwrPKueKH4h8oeWIsf.DUTBxLb2HLnlrZiv7mV19FR2OrR_14UUtNod97D0.b8ueJQ0S8WyY5__K4MeuWQgvtYay',
    'pageCounterCrfOne': '26',
    'OptanonConsent': 'isGpcEnabled=0&datestamp=Thu+Apr+03+2025+15%3A12%3A25+GMT%2B0200+(heure+d%E2%80%99%C3%A9t%C3%A9+d%E2%80%99Europe+centrale)&version=202310.2.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=92a3e744-b25d-4e54-a023-8625a83bd02f&interactionCount=1&landingPath=NotLandingPage&groups=C0048%3A1%2CC0001%3A1%2CC0040%3A0%2CC0032%3A0%2CC0025%3A0%2CC0020%3A0%2CC0037%3A0%2CC0039%3A0%2CC0036%3A0%2CC0041%3A0%2CC0042%3A0%2CC0044%3A0%2CC0043%3A0%2CC0045%3A0%2CC0049%3A0%2CC0047%3A0%2CC0023%3A0%2CC0056%3A0%2CC0038%3A0%2CC0082%3A0%2CC0026%3A0%2CC0177%3A0%2CC0113%3A0%2CC0089%3A0%2CC0092%3A0%2CC0190%3A0%2CC0166%3A0%2CC0222%3A0%2CC0223%3A0%2CC0231%3A0%2CC0263%3A0%2CC0004%3A0%2CC0022%3A0%2CC0054%3A0%2CC0179%3A0%2CC0146%3A0%2CC0052%3A0%2CC0034%3A0%2CC0063%3A0%2CC0157%3A0%2CC0003%3A0%2CC0212%3A0%2CC0081%3A0%2CC0051%3A0%2CC0136%3A0%2CC0135%3A0%2CC0007%3A0%2CV2STACK42%3A0&geolocation=FR%3BPAC&AwaitingReconsent=false',
    'carrefour_counter': '1743685946227%7C137739566618166%7Cp0%7Ce0%7Cv1%7Cc254.41%7CServerSide',
    '__cfwaitingroom_www': '',
    '__cf_bm': 'BByi_xj9ONCPRpRHJMDhjHRffHavDyWDeQshA0gSWSg-1743685942-1.0.1.1-jJ0Sq2CIRrtApfY.8TNmjqWdy1.ad7Wq8r28Mnyd_4UgPfQNor.hKjKJXv_njkp8PIYKamddi548_T7K84s.tF7dEse8Oghz.qdefDY4mag',
}

headers = {
    'accept': 'application/json, text/plain, */*',
    'accept-language': 'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7',
    'priority': 'u=1, i',
    'referer': 'https://www.carrefour.fr/r/cremerie/laits',
    'sec-ch-ua': '"Chromium";v="134", "Not:A-Brand";v="24", "Google Chrome";v="134"',
    'sec-ch-ua-arch': '"x86"',
    'sec-ch-ua-bitness': '"64"',
    'sec-ch-ua-full-version': '"134.0.6998.178"',
    'sec-ch-ua-full-version-list': '"Chromium";v="134.0.6998.178", "Not:A-Brand";v="24.0.0.0", "Google Chrome";v="134.0.6998.178"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-model': '""',
    'sec-ch-ua-platform': '"Windows"',
    'sec-ch-ua-platform-version': '"10.0.0"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest',
    # 'cookie': 'tc_cj_v2_cmp=; tc_cj_v2_med=; tc_ts=40; FRONTONE_ONLINE=1745247464; FRONTONE_SESSION_ID=fe0e97616cc0dc73679f62b16fa7c577b2d86018; CAID=202503221557457366701354; OptanonAlertBoxClosed=2025-03-22T14:57:49.848Z; eupubconsent-v2=CQOq1pgQOq1pgAcABBENBiFwAAAAAAAAAChQAAAAAAChIAYAygF5gTAHQAwBlALzAmAOAAgSEJQAQF5lIAYAygF5gTAA.YAAAAAAAAAAA; OneTrustGroupsConsent=%2CC0048%2CC0001%2C; FRONTONE_SESSID=uim3dg95re0gh6j1p6jnc30adj; sap-closed=1; tc_eff_params=; tc_ab=1; aaaaaaaaa944fac35b02f4d9a99619247b88ad463_cs=; tc_cj_v2=%5Ecl_%5Dny%5B%5D%5D_mmZZZZZZKQNLPOONPSSJKZZZ%5D777m_iZZZ%2C2%7B%29%2FZZZKQNMLOJOSNKMQZZZ%5D777%5Ecl_%5Dny%5B%5D%5D_mmZZZZZZKQNMPROPSPJMRZZZ%5D; cf_clearance=ejQ63F_1s06TNPQ7ARE1hYyun_ngF5WZ4HM.KyqVwWY-1743685936-1.2.1.1-W8hQPeNII6esIHjsPj7mz__mVqGsfGX.4Em.5k5VJq17i1ECsSPwpJ9PbKaIEPYtAZ7IeajQ7BgsgU7SCaKU9c.9eU2rdBxHL_OpYOiShsFZratV5nPQ7ngFo1nSSNapiTi209Z3bQhHwElT_XXZmtY6z6FGVJIGKiWBs7wsB335RvPO1ZNg8M1SvxNOi1w0w4xyCl73oLfq671G3mvr_gs40kp_YzX9pZWwsppILZK9SML.CWqDdrCu_2toPyZjHKCi3ol8gISXaqo.CLZxoIPRrfCq32k2TZuSP7t3XwrPKueKH4h8oeWIsf.DUTBxLb2HLnlrZiv7mV19FR2OrR_14UUtNod97D0.b8ueJQ0S8WyY5__K4MeuWQgvtYay; pageCounterCrfOne=26; OptanonConsent=isGpcEnabled=0&datestamp=Thu+Apr+03+2025+15%3A12%3A25+GMT%2B0200+(heure+d%E2%80%99%C3%A9t%C3%A9+d%E2%80%99Europe+centrale)&version=202310.2.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=92a3e744-b25d-4e54-a023-8625a83bd02f&interactionCount=1&landingPath=NotLandingPage&groups=C0048%3A1%2CC0001%3A1%2CC0040%3A0%2CC0032%3A0%2CC0025%3A0%2CC0020%3A0%2CC0037%3A0%2CC0039%3A0%2CC0036%3A0%2CC0041%3A0%2CC0042%3A0%2CC0044%3A0%2CC0043%3A0%2CC0045%3A0%2CC0049%3A0%2CC0047%3A0%2CC0023%3A0%2CC0056%3A0%2CC0038%3A0%2CC0082%3A0%2CC0026%3A0%2CC0177%3A0%2CC0113%3A0%2CC0089%3A0%2CC0092%3A0%2CC0190%3A0%2CC0166%3A0%2CC0222%3A0%2CC0223%3A0%2CC0231%3A0%2CC0263%3A0%2CC0004%3A0%2CC0022%3A0%2CC0054%3A0%2CC0179%3A0%2CC0146%3A0%2CC0052%3A0%2CC0034%3A0%2CC0063%3A0%2CC0157%3A0%2CC0003%3A0%2CC0212%3A0%2CC0081%3A0%2CC0051%3A0%2CC0136%3A0%2CC0135%3A0%2CC0007%3A0%2CV2STACK42%3A0&geolocation=FR%3BPAC&AwaitingReconsent=false; carrefour_counter=1743685946227%7C137739566618166%7Cp0%7Ce0%7Cv1%7Cc254.41%7CServerSide; __cfwaitingroom_www=; __cf_bm=BByi_xj9ONCPRpRHJMDhjHRffHavDyWDeQshA0gSWSg-1743685942-1.0.1.1-jJ0Sq2CIRrtApfY.8TNmjqWdy1.ad7Wq8r28Mnyd_4UgPfQNor.hKjKJXv_njkp8PIYKamddi548_T7K84s.tF7dEse8Oghz.qdefDY4mag',
}

params = {
    'noRedirect': '0',
    'page': '2',
}

response = requests.get('https://www.carrefour.fr/r/cremerie/laits', params=params, cookies=cookies, headers=headers)

# %%
#Loop to get all the page
import time
response_1 = []
for x in range(1,11):
    params = {
    'noRedirect': '0',
    'page': str(x) ,
    }
    response = requests.get(
    'https://www.carrefour.fr/r/cremerie/laits',
    params=params,
    cookies=cookies,
    headers=headers,
    )
    response_1.append(response.json())
    time.sleep(2)

print(response_1)
# Out:
# [{'data': [{'type': 'product', 'id': 'product-3560071138660', 'attributes': {'ean': '3560071138660', 'cdbase': '6394709', 'title': 'Lait Demi-Ecreme Stérilisé UHT de Montagne CARREFOUR', 'brand': None, 'slug': 'lait-demi-ecreme-sterilise-uht-de-montagne-carrefour', 'businessType': 'food', 'offerServiceId': '0261-150-6', 'uri': 'cremerie/laits/lait-demi-ecreme', 'categories': [{'id': '36993', 'code': 'R00F00SF00', 'slug': 'cremerie', 'label': 'Crèmerie et Produits laitiers', 'uri': 'cremerie', 'type': 'RAYON', 'level': 1, 'sellerId': None}, {'id': '29297', 'code': 'R00F00SF00', 'slug': 'laits', 'label': 'Laits', 'uri': 'cremerie/laits', 'type': 'RAYON', 'level': 2, 'sellerId': None}, {'id': '29298', 'code': 'R00F00SF00', 'slug': 'lait-demi-ecreme', 'label': 'Lait demi-écrémé', 'uri': 'cremerie/laits/lait-demi-ecreme', 'type': 'RAYON', 'level': 3, 'sellerId': None}], 'topCategoryName': 'Crèmerie et Produits laitiers', 'images': {'formats': {'largest': '540x540', 'common': ['43x43', '200x200', '540x540', '1500x1500']}, 'paths': ['https://media.carrefour.fr/medias/06573f86027e35b1ae86cf11fc4f10eb/p_FORMAT/3560071138660-photosite-20171121-161812-0.jpg']}, 'isDonation': False, 'isBestSeller': False, 'traceability': None, 'keyFeatures': [], 'moreOffers': {'count': 0, 'bestOfferId': None, 'bestOfferPrice': None, 'hasNonFoodDeliveryOffer': False, 'isRexEligible': False, 'withdrawalDelivery': {'exists': False, 'expressWithdrawalEligibility': {'global': False, 'inCurrentStore': False}}, 'hasCarrefourPlus': False}, 'offers': {'3560071138660': {'0261-150-6': {'type': 'offer', 'subType': 'carrefour', 'id': '0261-150-6', 'attributes': {'availability': {'indispensable': False, 'purchasable': True, 'stopped': False, 'suspended': False, 'suspensionReason': None, 'hasLowQuantity': False}, 'preorder': None, 'price': {'price': 7.84, 'taxMessage': '', 'unitOfMeasure': 'L', 'perUnit': 0.98, 'perUnitLabel': '0.98 € / L'}, 'ordering': {'min': 1, 'step': 1, 'max': 10}, 'offerServiceId': '0261-150-6', 'highlightLabel': None, 'freshness': {'value': 10, 'period': 'day'}, 'marketplace': None, 'ean': '3560071138660', 'promotion': None, 'promotions': [{'type': 'rd_offre_pass', 'label': '-15% Mardi PASS', 'message': 'promotion.rd_offre_pass', 'isLoyalty': True, 'isPromo': False, 'isPrixBarre': False, 'isPrixForce': False, 'isVuEnCatalogue': False, 'isCrescendo': False, 'isClubActive': False, 'promotionParts': [], 'progression': {'current': None, 'total': None, 'completed': None}, 'bestQuantity': 1, 'messageArgs': {'quantity': 1, 'discountAmount': 1.18, 'discountedPrice': 7.84, 'initialPrice': 7.84, 'discountedPricePerUnit': None, 'startDate': '2025-01-01T00:00:00+0100', 'endDate': '2026-12-31T23:59:00+0100'}, 'promoStartDate': '2025-01-01T00:00:00+0100', 'promoEndDate': '2026-12-31T23:59:00+0100', 'mixableGtins': [], 'isPriceAlreadyDiscounted': False, 'mandateId': ['1120250000004776'], 'isDisplayed': False}], 'variableWeight': False, 'isRexEligible': False, 'expressWithdrawalEligibility': {'global': False, 'inCurrentStore': False}, 'isNonFoodDelivery': False, 'isRelayPointEligible': False, 'description': None, 'shopReturnPolicy': None, 'bundle': {'label': None}, 'isNew': False, 'isInnovation': False, 'isAlternativeCheaper': False, 'isDigitalCard': False, 'isWholesale': False, 'isClcv': False, 'isZiqy': False, 'isHealthy': False, 'isPhysicalStoreOffer': False, 'isExpressDelivery': False, 'isRecoverable': False, 'guarantees': []}, 'meta': {'cta': 'buy'}, 'links': {'self': ''}}}}, 'packaging': 'le pack de 8 briques de 1L', 'deliveryModalities': [], 'flags': [], 'clubs': [], 'origin': '', 'format': 'Format Standard', 'nutriscore': None, 'customerReviews': {'average': 5, 'count': 1, 'rates': None}, 'variants': [], 'weightsAndMeasures': [], 'guarantee_general_document': 'https://static-cms.carrefour.fr/sites/default/files/documents/garanties-carrefour-plus-document-information-cgv.pdf'}, 'relationships': {'substitution': None}, 'meta': {'recommendation': None, 'cta ...

# %%
#Get the relevant columns and extract the price/kg
import pandas as pd

df_1 = pd.DataFrame()  # Initialize an empty DataFrame

for item in response_1:  # Loop through each JSON object
    try:
        # Ensure 'data' exists and extract it safely
        df_data = pd.DataFrame(item.get('data', []))  
        
        # Ensure 'attributes' exists before normalizing
        if 'attributes' in df_data:
            df_product = pd.json_normalize(df_data['attributes'])
        else:
            print("Warning: 'attributes' key missing in data.")
            continue  # Skip this item if 'attributes' is missing

        price_unit = []
        for x in df_product.get("ean", []):  # Use .get() to avoid KeyError
            try:
                ean_index = df_product[df_product["ean"] == x].index[0]
                price_column = f"offers.{x}.0261-150-6.attributes.price.perUnitLabel"

                # Check if the column exists before accessing
                if price_column in df_product.columns:
                    price_unit_variable = df_product.loc[ean_index, price_column]
                else:
                    price_unit_variable = None  # Default if price column missing

                price_unit.append(price_unit_variable)
            except Exception as e:
                print(f"Error processing EAN {x}: {e}")
                price_unit.append(None)  # Append None for failed entries

        price = []
        for x in df_product.get("ean", []):  # Use .get() to avoid KeyError
            try:
                ean_index = df_product[df_product["ean"] == x].index[0]
                price_column = f"offers.{x}.0261-150-6.attributes.price.price"

                # Check if the column exists before accessing
                if price_column in df_product.columns:
                    price_variable = df_product.loc[ean_index, price_column]
                else:
                    price_variable = None  # Default if price column missing

                price.append(price_variable)
            except Exception as e:
                print(f"Error processing EAN {x}: {e}")
                price.append(None)  # Append None for failed entries

        # Select relevant columns safely
        try:
            df_final = df_product[["title", "slug", "topCategoryName", "origin"]].copy()
        except KeyError as e:
            print(f"Missing column error: {e}")
            continue  # Skip this item if required columns are missing

        # Add price_unit column
        df_final["price_unit"] = price_unit
        df_final["price"] = price

        # Concatenate safely
        df_1 = pd.concat([df_1, df_final], ignore_index=True)

    except Exception as e:
        print(f"Error processing item: {e}")
        continue  # Skip the item on error

# Print the final DataFrame
print(df_1)
# Out:
# Warning: 'attributes' key missing in data.
#                                                  title  \
# 0    Lait Demi-Ecreme Stérilisé UHT de Montagne CAR...
# 1                    Caffè Latte  Cappuccino    LACTEL
# 2                      Caffè Latte  Classico    LACTEL
# 3                Lait Vitaminé 1,0% MG Vita'Vie LACTEL
# 4                Lait demi-écrémé Grandlait Bio CANDIA
# ..                                                 ...
# 254        Boisson Cacaotée Bio Aux Céréales - Okakao
# 255        Boisson Cacaotée Bio Aux Céréales - Okakao
# 256        Boisson Cacaotée Bio Aux Céréales - Okakao
# 257        Boisson Cacaotée Bio Aux Céréales - Okakao
# 258              Kaiku - Lait Entier Sans Lactose 1 L
#
#                                                   slug  \
# 0    lait-demi-ecreme-sterilise-uht-de-montagne-car...
# 1                        caffe-latte-cappuccino-lactel
# 2                          caffe-latte-classico-lactel
# 3                 lait-vitamine-1-0-mg-vita-vie-lactel
# 4                lait-demi-ecreme-grandlait-bio-candia
# ..                                                 ...
# 254           boisson-cacaotee-bio-aux-cereales-okakao
# 255           boisson-cacaotee-bio-aux-cereales-okakao
# 256           boisson-cacaotee-bio-aux-cereales-okakao
# 257           boisson-cacaotee-bio-aux-cereales-okakao
# 258                 kaiku-lait-entier-sans-lactose-1-l
#
#                    topCategoryName   origin  price_unit  price
# 0    Crèmerie et Produits laitiers           0.98 € / L   7.84
# 1    Crèmerie et Produits laitiers           3.48 € / L   2.99
# 2    Crèmerie et Produits laitiers           3.48 € / L   2.99
# 3    Crèmerie et Produits laitiers           1.18 € / L   7.08
# 4                  Bio et Ecologie           1.45 € / L  11.60
# ..                             ...      ...         ...    ...
# 254  Crèmerie et Produits laitiers   FRANCE        None    NaN
# 255  Crèmerie et Produits laitiers   FRANCE        None    NaN
# 256  Crèmerie et Produits laitiers   FRANCE        None    NaN
# 257  Crèmerie et Produits laitiers   FRANCE        None    NaN
# 258  Crèmerie et Produits laitiers  ESPAGNE        None    NaN
#
# [259 rows x 6 columns]

# %%
df_1.head()
# Out:
#                                                title  \
# 0  Lait Demi-Ecreme Stérilisé UHT de Montagne CAR...
# 1                  Caffè Latte  Cappuccino    LACTEL
# 2                    Caffè Latte  Classico    LACTEL
# 3              Lait Vitaminé 1,0% MG Vita'Vie LACTEL
# 4              Lait demi-écrémé Grandlait Bio CANDIA
#
#                                                 slug  \
# 0  lait-demi-ecreme-sterilise-uht-de-montagne-car...
# 1                      caffe-latte-cappuccino-lactel
# 2                        caffe-latte-classico-lactel
# 3               lait-vitamine-1-0-mg-vita-vie-lactel
# 4              lait-demi-ecreme-grandlait-bio-candia
#
#                  topCategoryName origin  price_unit  price
# 0  Crèmerie et Produits laitiers         0.98 € / L   7.84
# 1  Crèmerie et Produits laitiers         3.48 € / L   2.99
# 2  Crèmerie et Produits laitiers         3.48 € / L   2.99
# 3  Crèmerie et Produits laitiers         1.18 € / L   7.08
# 4                Bio et Ecologie         1.45 € / L  11.60

# %%
df_1.to_csv("lait.csv", index=False)
