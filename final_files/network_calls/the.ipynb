# %%
import requests

cookies = {
    'tc_cj_v2_cmp': '',
    'tc_cj_v2_med': '',
    'tc_ts': '40',
    'FRONTONE_ONLINE': '1745247464',
    'FRONTONE_SESSION_ID': 'fe0e97616cc0dc73679f62b16fa7c577b2d86018',
    'CAID': '202503221557457366701354',
    'OptanonAlertBoxClosed': '2025-03-22T14:57:49.848Z',
    'eupubconsent-v2': 'CQOq1pgQOq1pgAcABBENBiFwAAAAAAAAAChQAAAAAAChIAYAygF5gTAHQAwBlALzAmAOAAgSEJQAQF5lIAYAygF5gTAA.YAAAAAAAAAAA',
    'OneTrustGroupsConsent': '%2CC0048%2CC0001%2C',
    'FRONTONE_SESSID': 'uim3dg95re0gh6j1p6jnc30adj',
    'sap-closed': '1',
    'tc_eff_params': '',
    'tc_ab': '1',
    'aaaaaaaaa944fac35b02f4d9a99619247b88ad463_cs': '',
    'tc_cj_v2': '%5Ecl_%5Dny%5B%5D%5D_mmZZZZZZKQNLPOONPSSJKZZZ%5D777m_iZZZ%2C2%7B%29%2FZZZKQNMLOJOSNKMQZZZ%5D777%5Ecl_%5Dny%5B%5D%5D_mmZZZZZZKQNMPRQOMPKQLZZZ%5D',
    'cf_clearance': 'smAocnl9OmY68Oegn3pHmMrVXG20LcGiaNxffTUlUN4-1743687855-1.2.1.1-EOFi.PjPdhPrma1ibi3a0MVnfjkdnqGQrNV3yPbOjaKskGrtg6pUwjclm2FfjY55iCr0SD21Z5kIfKX5l8hxHm1pIDUUSroAshiCAdwJNzl71vOggvs.z1RZltymFKU6ghKWL7ThL.nVODoQkm_SgZeDByfoBCfawf3aoHd.leAeNstl4MTqRt8H7Gd9zj4S8stx8uzt8AgmhCYxncMxYaB.yP7MTjuqMsqliESwbatVHj6YERrc5X5QeMYEicZg6wjzlcq_nV_NTS9roIWjDBKMzKQFnKCiek9q4mHXGDzYcx.AGNIoNP.OZ5.W3qKas_76oa8lkMOON5tRZE_i7rpz3pm4E4dKYiW4BSGHzE1jdD6bYBF.QINBsIljFJeA',
    'pageCounterCrfOne': '33',
    'OptanonConsent': 'isGpcEnabled=0&datestamp=Thu+Apr+03+2025+15%3A44%3A38+GMT%2B0200+(heure+d%E2%80%99%C3%A9t%C3%A9+d%E2%80%99Europe+centrale)&version=202310.2.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=92a3e744-b25d-4e54-a023-8625a83bd02f&interactionCount=1&landingPath=NotLandingPage&groups=C0048%3A1%2CC0001%3A1%2CC0040%3A0%2CC0032%3A0%2CC0025%3A0%2CC0020%3A0%2CC0037%3A0%2CC0039%3A0%2CC0036%3A0%2CC0041%3A0%2CC0042%3A0%2CC0044%3A0%2CC0043%3A0%2CC0045%3A0%2CC0049%3A0%2CC0047%3A0%2CC0023%3A0%2CC0056%3A0%2CC0038%3A0%2CC0082%3A0%2CC0026%3A0%2CC0177%3A0%2CC0113%3A0%2CC0089%3A0%2CC0092%3A0%2CC0190%3A0%2CC0166%3A0%2CC0222%3A0%2CC0223%3A0%2CC0231%3A0%2CC0263%3A0%2CC0004%3A0%2CC0022%3A0%2CC0054%3A0%2CC0179%3A0%2CC0146%3A0%2CC0052%3A0%2CC0034%3A0%2CC0063%3A0%2CC0157%3A0%2CC0003%3A0%2CC0212%3A0%2CC0081%3A0%2CC0051%3A0%2CC0136%3A0%2CC0135%3A0%2CC0007%3A0%2CV2STACK42%3A0&geolocation=FR%3BPAC&AwaitingReconsent=false',
    '__cf_bm': 'J4K2bHHzel6tktbAzpSWOHzhNXpPDLJ8.m3wBHUvpYU-1743687874-1.0.1.1-IQn2DxzRHFLUxMrgREGccOkwaKBYtgC5b9k4I2rSKZvDy2rcoNNCpCC3l73B9Rz.DckpPLDwX6V2ULHTgyTUVynpiNbCXFE_XY3gX4f3b0g',
    'carrefour_counter': '1743687882145%7C137739566618166%7Cp0%7Ce0%7Cv1%7Cc254.41%7CServerSide',
    '__cfwaitingroom_www': '',
}

headers = {
    'accept': 'application/json, text/plain, */*',
    'accept-language': 'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7',
    'priority': 'u=1, i',
    'referer': 'https://www.carrefour.fr/r/epicerie-sucree/boissons-chaudes?noRedirect=1&page=3',
    'sec-ch-ua': '"Chromium";v="134", "Not:A-Brand";v="24", "Google Chrome";v="134"',
    'sec-ch-ua-arch': '"x86"',
    'sec-ch-ua-bitness': '"64"',
    'sec-ch-ua-full-version': '"134.0.6998.178"',
    'sec-ch-ua-full-version-list': '"Chromium";v="134.0.6998.178", "Not:A-Brand";v="24.0.0.0", "Google Chrome";v="134.0.6998.178"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-model': '""',
    'sec-ch-ua-platform': '"Windows"',
    'sec-ch-ua-platform-version': '"10.0.0"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.
}

params = {
    'page': '3',
    'noRedirect': '1',
}

response = requests.get(
    'https://www.carrefour.fr/r/epicerie-sucree/boissons-chaudes',
    params=params,
    cookies=cookies,
    headers=headers,
)

# %%
#Loop to get all the page
import time
response_1 = []
for x in range(1,23):
    params = {
    'noRedirect': '0',
    'page': str(x) ,
    }
    response = requests.get(
    'https://www.carrefour.fr/r/epicerie-sucree/boissons-chaudes',
    params=params,
    cookies=cookies,
    headers=headers,
    )
    response_1.append(response.json())
    time.sleep(2)

print(response_1)
# Out:
# [{'data': [{'type': 'product', 'id': 'product-3042062209134', 'attributes': {'ean': '3042062209134', 'cdbase': '7680607', 'title': 'Infusion Après-repas citron LA TISANIERE', 'brand': None, 'slug': 'infusion-apres-repas-citron-la-tisaniere', 'businessType': 'food', 'offerServiceId': '0261-150-6', 'uri': 'dietetique-preferences-alimentaires/nutrition-dietetique/selection-nutrition-bien-etre', 'categories': [{'id': '2183', 'code': 'R00F00SF00', 'slug': 'epicerie-sucree', 'label': 'Epicerie sucrée', 'uri': 'epicerie-sucree', 'type': 'RAYON', 'level': 1, 'sellerId': None}, {'id': '2184', 'code': 'R00F00SF00', 'slug': 'boissons-chaudes', 'label': 'Thés, Infusions et Boissons chaudes', 'uri': 'epicerie-sucree/boissons-chaudes', 'type': 'RAYON', 'level': 2, 'sellerId': None}, {'id': '2200', 'code': 'R00F00SF00', 'slug': 'infusions', 'label': 'Infusions', 'uri': 'epicerie-sucree/boissons-chaudes/infusions', 'type': 'RAYON', 'level': 3, 'sellerId': None}, {'id': '2202', 'code': 'R00F00SF00', 'slug': 'infusions-detox-et-bien-etre', 'label': 'Infusions bien-être', 'uri': 'epicerie-sucree/boissons-chaudes/infusions/infusions-detox-et-bien-etre', 'type': 'RAYON', 'level': 4, 'sellerId': None}], 'topCategoryName': 'Epicerie sucrée', 'images': {'formats': {'largest': '540x540', 'common': ['43x43', '200x200', '540x540', '1500x1500']}, 'paths': ['https://media.carrefour.fr/medias/6e14e436f4d24f8fb9527297227bd456/p_FORMAT/03042062209134_H1N1_s09.jpeg', 'https://media.carrefour.fr/medias/c642405cacc949dea735d790ed13bc2c/p_FORMAT/03042062209134_C0L1_s10.jpeg']}, 'isDonation': False, 'isBestSeller': False, 'traceability': None, 'keyFeatures': [], 'moreOffers': {'count': 0, 'bestOfferId': None, 'bestOfferPrice': None, 'hasNonFoodDeliveryOffer': False, 'isRexEligible': False, 'withdrawalDelivery': {'exists': False, 'expressWithdrawalEligibility': {'global': False, 'inCurrentStore': False}}, 'hasCarrefourPlus': False}, 'offers': {'3042062209134': {'0261-150-6': {'type': 'offer', 'subType': 'carrefour', 'id': '0261-150-6', 'attributes': {'availability': {'indispensable': False, 'purchasable': True, 'stopped': False, 'suspended': False, 'suspensionReason': None, 'hasLowQuantity': False}, 'preorder': None, 'price': {'price': 2.99, 'taxMessage': '', 'unitOfMeasure': 'KG', 'perUnit': 65.67, 'perUnitLabel': '65.67 € / KG'}, 'ordering': {'min': 1, 'step': 1, 'max': 50}, 'offerServiceId': '0261-150-6', 'highlightLabel': {'type': 'promotion', 'key': 'product.label.promotion'}, 'freshness': None, 'marketplace': None, 'ean': '3042062209134', 'promotion': {'type': 'promo', 'label': 'PROMO : 34%', 'message': 'promotion.promo', 'isLoyalty': False, 'isPromo': True, 'isPrixBarre': True, 'isPrixForce': False, 'isVuEnCatalogue': False, 'isCrescendo': False, 'isClubActive': False, 'promotionParts': [], 'progression': {'current': None, 'total': None, 'completed': None}, 'bestQuantity': 1, 'messageArgs': {'quantity': 1, 'discountAmount': 1.02, 'discountedPrice': 1.97, 'initialPrice': 2.99, 'discountedPricePerUnit': None, 'startDate': '2025-03-31T00:00:00+0200', 'endDate': '2025-04-15T23:59:00+0200'}, 'promoStartDate': '2025-03-31T00:00:00+0200', 'promoEndDate': '2025-04-15T23:59:00+0200', 'mixableGtins': [], 'isPriceAlreadyDiscounted': True, 'mandateId': ['1120250000023328'], 'isDisplayed': True}, 'promotions': [{'type': 'promo', 'label': 'PROMO : 34%', 'message': 'promotion.promo', 'isLoyalty': False, 'isPromo': True, 'isPrixBarre': True, 'isPrixForce': False, 'isVuEnCatalogue': False, 'isCrescendo': False, 'isClubActive': False, 'promotionParts': [], 'progression': {'current': None, 'total': None, 'completed': None}, 'bestQuantity': 1, 'messageArgs': {'quantity': 1, 'discountAmount': 1.02, 'discountedPrice': 1.97, 'initialPrice': 2.99, 'discountedPricePerUnit': None, 'startDate': '2025-03-31T00:00:00+0200', 'endDate': '2025-04-15T23:59:00+0200'}, 'promoStartDate': '2025-03-31T00:00:00+0200', 'promoEndDate': '2025-04-15T23:59:00+0200', 'mixableGtins': [], 'isPriceAlread ...

# %%
#Get the relevant columns and extract the price/kg
import pandas as pd

df_1 = pd.DataFrame()  # Initialize an empty DataFrame

for item in response_1:  # Loop through each JSON object
    try:
        # Ensure 'data' exists and extract it safely
        df_data = pd.DataFrame(item.get('data', []))  
        
        # Ensure 'attributes' exists before normalizing
        if 'attributes' in df_data:
            df_product = pd.json_normalize(df_data['attributes'])
        else:
            print("Warning: 'attributes' key missing in data.")
            continue  # Skip this item if 'attributes' is missing

        price_unit = []
        for x in df_product.get("ean", []):  # Use .get() to avoid KeyError
            try:
                ean_index = df_product[df_product["ean"] == x].index[0]
                price_column = f"offers.{x}.0261-150-6.attributes.price.perUnitLabel"

                # Check if the column exists before accessing
                if price_column in df_product.columns:
                    price_unit_variable = df_product.loc[ean_index, price_column]
                else:
                    price_unit_variable = None  # Default if price column missing

                price_unit.append(price_unit_variable)
            except Exception as e:
                print(f"Error processing EAN {x}: {e}")
                price_unit.append(None)  # Append None for failed entries

        price = []
        for x in df_product.get("ean", []):  # Use .get() to avoid KeyError
            try:
                ean_index = df_product[df_product["ean"] == x].index[0]
                price_column = f"offers.{x}.0261-150-6.attributes.price.price"

                # Check if the column exists before accessing
                if price_column in df_product.columns:
                    price_variable = df_product.loc[ean_index, price_column]
                else:
                    price_variable = None  # Default if price column missing

                price.append(price_variable)
            except Exception as e:
                print(f"Error processing EAN {x}: {e}")
                price.append(None)  # Append None for failed entries

        # Select relevant columns safely
        try:
            df_final = df_product[["title", "slug", "topCategoryName", "origin"]].copy()
        except KeyError as e:
            print(f"Missing column error: {e}")
            continue  # Skip this item if required columns are missing

        # Add price_unit column
        df_final["price_unit"] = price_unit
        df_final["price"] = price

        # Concatenate safely
        df_1 = pd.concat([df_1, df_final], ignore_index=True)

    except Exception as e:
        print(f"Error processing item: {e}")
        continue  # Skip the item on error

# Print the final DataFrame
print(df_1)
# Out:
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_15400\2298180388.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_1 = pd.concat([df_1, df_final], ignore_index=True)
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_15400\2298180388.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_1 = pd.concat([df_1, df_final], ignore_index=True)
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_15400\2298180388.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_1 = pd.concat([df_1, df_final], ignore_index=True)
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_15400\2298180388.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_1 = pd.concat([df_1, df_final], ignore_index=True)
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_15400\2298180388.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_1 = pd.concat([df_1, df_final], ignore_index=True)
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_15400\2298180388.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_1 = pd.concat([df_1, df_final], ignore_index=True)
#                                               title  \
# 0          Infusion Après-repas citron LA TISANIERE
# 1    Chocolat en poudre goût extra chocolat NESQUIK
# 2     Thé noir English Breakfast CARREFOUR CLASSIC'
# 3          Thé vert menthe douce  Bio CARREFOUR BIO
# 4               Thé vert menthe CARREFOUR SENSATION
# ..                                              ...
# 655            Tisane De Ginkgo Biloba Bio - 100 G
# 656                     Tisane Verveine Bio - 15 G
# 657                 Tisane De Cannelle Bio - 170 G
# 658             Tisane D'harpagophytum Bio - 300 G
# 659                               Fleur D'hibiscus
#
#                                                slug  topCategoryName origin  \
# 0          infusion-apres-repas-citron-la-tisaniere  Epicerie sucrée
# 1    chocolat-en-poudre-gout-extra-chocolat-nesquik  Epicerie sucrée
# 2      the-noir-english-breakfast-carrefour-classic  Epicerie sucrée
# 3           the-vert-menthe-douce-bio-carrefour-bio  Epicerie sucrée
# 4               the-vert-menthe-carrefour-sensation  Epicerie sucrée
# ..                                              ...              ...    ...
# 655               tisane-de-ginkgo-biloba-bio-100-g  Epicerie sucrée
# 656                        tisane-verveine-bio-15-g  Epicerie sucrée
# 657                    tisane-de-cannelle-bio-170-g  Epicerie sucrée
# 658                tisane-d-harpagophytum-bio-300-g  Epicerie sucrée
# 659                                fleur-d-hibiscus  Epicerie sucrée
#
#        price_unit  price
# 0    65.67 € / KG   2.99
# 1     8.75 € / KG   5.25
# 2      0.03 € / U   0.85
# 3    48.44 € / KG   1.55
# 4    20.25 € / KG   0.81
# ..            ...    ...
# 655          None    NaN
# 656          None    NaN
# 657          None    NaN
# 658          None    NaN
# 659          None    NaN
#
# [660 rows x 6 columns]
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_15400\2298180388.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_1 = pd.concat([df_1, df_final], ignore_index=True)
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_15400\2298180388.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_1 = pd.concat([df_1, df_final], ignore_index=True)
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_15400\2298180388.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_1 = pd.concat([df_1, df_final], ignore_index=True)

# %%
df_1.to_csv("the.csv", index=False)
