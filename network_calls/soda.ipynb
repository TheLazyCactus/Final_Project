# %%
import requests

cookies = {
    'tc_cj_v2_cmp': '',
    'tc_cj_v2_med': '',
    'tc_ts': '40',
    'FRONTONE_ONLINE': '1745247464',
    'FRONTONE_SESSION_ID': 'fe0e97616cc0dc73679f62b16fa7c577b2d86018',
    'CAID': '202503221557457366701354',
    'OptanonAlertBoxClosed': '2025-03-22T14:57:49.848Z',
    'eupubconsent-v2': 'CQOq1pgQOq1pgAcABBENBiFwAAAAAAAAAChQAAAAAAChIAYAygF5gTAHQAwBlALzAmAOAAgSEJQAQF5lIAYAygF5gTAA.YAAAAAAAAAAA',
    'OneTrustGroupsConsent': '%2CC0048%2CC0001%2C',
    'FRONTONE_SESSID': 'uim3dg95re0gh6j1p6jnc30adj',
    'sap-closed': '1',
    'tc_eff_params': '',
    'tc_ab': '1',
    'aaaaaaaaa944fac35b02f4d9a99619247b88ad463_cs': '',
    'cf_clearance': 'ejQ63F_1s06TNPQ7ARE1hYyun_ngF5WZ4HM.KyqVwWY-1743685936-1.2.1.1-W8hQPeNII6esIHjsPj7mz__mVqGsfGX.4Em.5k5VJq17i1ECsSPwpJ9PbKaIEPYtAZ7IeajQ7BgsgU7SCaKU9c.9eU2rdBxHL_OpYOiShsFZratV5nPQ7ngFo1nSSNapiTi209Z3bQhHwElT_XXZmtY6z6FGVJIGKiWBs7wsB335RvPO1ZNg8M1SvxNOi1w0w4xyCl73oLfq671G3mvr_gs40kp_YzX9pZWwsppILZK9SML.CWqDdrCu_2toPyZjHKCi3ol8gISXaqo.CLZxoIPRrfCq32k2TZuSP7t3XwrPKueKH4h8oeWIsf.DUTBxLb2HLnlrZiv7mV19FR2OrR_14UUtNod97D0.b8ueJQ0S8WyY5__K4MeuWQgvtYay',
    'tc_cj_v2': '%5Ecl_%5Dny%5B%5D%5D_mmZZZZZZKQNLPOONPSSJKZZZ%5D777m_iZZZ%2C2%7B%29%2FZZZKQNMLOJOSNKMQZZZ%5D777%5Ecl_%5Dny%5B%5D%5D_mmZZZZZZKQNMPRQLOPSNRZZZ%5D',
    'pageCounterCrfOne': '31',
    'carrefour_counter': '1743687257685%7C137739566618166%7Cp0%7Ce0%7Cv1%7Cc254.41%7CServerSide',
    'OptanonConsent': 'isGpcEnabled=0&datestamp=Thu+Apr+03+2025+15%3A34%3A18+GMT%2B0200+(heure+d%E2%80%99%C3%A9t%C3%A9+d%E2%80%99Europe+centrale)&version=202310.2.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=92a3e744-b25d-4e54-a023-8625a83bd02f&interactionCount=1&landingPath=NotLandingPage&groups=C0048%3A1%2CC0001%3A1%2CC0040%3A0%2CC0032%3A0%2CC0025%3A0%2CC0020%3A0%2CC0037%3A0%2CC0039%3A0%2CC0036%3A0%2CC0041%3A0%2CC0042%3A0%2CC0044%3A0%2CC0043%3A0%2CC0045%3A0%2CC0049%3A0%2CC0047%3A0%2CC0023%3A0%2CC0056%3A0%2CC0038%3A0%2CC0082%3A0%2CC0026%3A0%2CC0177%3A0%2CC0113%3A0%2CC0089%3A0%2CC0092%3A0%2CC0190%3A0%2CC0166%3A0%2CC0222%3A0%2CC0223%3A0%2CC0231%3A0%2CC0263%3A0%2CC0004%3A0%2CC0022%3A0%2CC0054%3A0%2CC0179%3A0%2CC0146%3A0%2CC0052%3A0%2CC0034%3A0%2CC0063%3A0%2CC0157%3A0%2CC0003%3A0%2CC0212%3A0%2CC0081%3A0%2CC0051%3A0%2CC0136%3A0%2CC0135%3A0%2CC0007%3A0%2CV2STACK42%3A0&geolocation=FR%3BPAC&AwaitingReconsent=false',
    '__cf_bm': '32sbbXuy8HaPVSHaLsx3L9wb2EyQItq83OoKsTYjKWg-1743687254-1.0.1.1-8f86J3ZZVAbY.6MOY3OVfE1LSDlp_GrHPSpEErI4pGYtCRI.DSZ2zJjN5qhT7uOKys1bQZcvDLn8CGSKcJiOEWYqc3eWlEvYo.SjitkCZ.g',
    '__cfwaitingroom_www': '',
}

headers = {
    'accept': 'application/json, text/plain, */*',
    'accept-language': 'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7',
    'priority': 'u=1, i',
    'referer': 'https://www.carrefour.fr/r/boissons/colas-thes-glaces-et-soft-drinks',
    'sec-ch-ua': '"Chromium";v="134", "Not:A-Brand";v="24", "Google Chrome";v="134"',
    'sec-ch-ua-arch': '"x86"',
    'sec-ch-ua-bitness': '"64"',
    'sec-ch-ua-full-version': '"134.0.6998.178"',
    'sec-ch-ua-full-version-list': '"Chromium";v="134.0.6998.178", "Not:A-Brand";v="24.0.0.0", "Google Chrome";v="134.0.6998.178"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-model': '""',
    'sec-ch-ua-platform': '"Windows"',
    'sec-ch-ua-platform-version': '"10.0.0"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest',
    # 'cookie': 'tc_cj_v2_cmp=; tc_cj_v2_med=; tc_ts=40; FRONTONE_ONLINE=1745247464; FRONTONE_SESSION_ID=fe0e97616cc0dc73679f62b16fa7c577b2d86018; CAID=202503221557457366701354; OptanonAlertBoxClosed=2025-03-22T14:57:49.848Z; eupubconsent-v2=CQOq1pgQOq1pgAcABBENBiFwAAAAAAAAAChQAAAAAAChIAYAygF5gTAHQAwBlALzAmAOAAgSEJQAQF5lIAYAygF5gTAA.YAAAAAAAAAAA; OneTrustGroupsConsent=%2CC0048%2CC0001%2C; FRONTONE_SESSID=uim3dg95re0gh6j1p6jnc30adj; sap-closed=1; tc_eff_params=; tc_ab=1; aaaaaaaaa944fac35b02f4d9a99619247b88ad463_cs=; cf_clearance=ejQ63F_1s06TNPQ7ARE1hYyun_ngF5WZ4HM.KyqVwWY-1743685936-1.2.1.1-W8hQPeNII6esIHjsPj7mz__mVqGsfGX.4Em.5k5VJq17i1ECsSPwpJ9PbKaIEPYtAZ7IeajQ7BgsgU7SCaKU9c.9eU2rdBxHL_OpYOiShsFZratV5nPQ7ngFo1nSSNapiTi209Z3bQhHwElT_XXZmtY6z6FGVJIGKiWBs7wsB335RvPO1ZNg8M1SvxNOi1w0w4xyCl73oLfq671G3mvr_gs40kp_YzX9pZWwsppILZK9SML.CWqDdrCu_2toPyZjHKCi3ol8gISXaqo.CLZxoIPRrfCq32k2TZuSP7t3XwrPKueKH4h8oeWIsf.DUTBxLb2HLnlrZiv7mV19FR2OrR_14UUtNod97D0.b8ueJQ0S8WyY5__K4MeuWQgvtYay; tc_cj_v2=%5Ecl_%5Dny%5B%5D%5D_mmZZZZZZKQNLPOONPSSJKZZZ%5D777m_iZZZ%2C2%7B%29%2FZZZKQNMLOJOSNKMQZZZ%5D777%5Ecl_%5Dny%5B%5D%5D_mmZZZZZZKQNMPRQLOPSNRZZZ%5D; pageCounterCrfOne=31; carrefour_counter=1743687257685%7C137739566618166%7Cp0%7Ce0%7Cv1%7Cc254.41%7CServerSide; OptanonConsent=isGpcEnabled=0&datestamp=Thu+Apr+03+2025+15%3A34%3A18+GMT%2B0200+(heure+d%E2%80%99%C3%A9t%C3%A9+d%E2%80%99Europe+centrale)&version=202310.2.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=92a3e744-b25d-4e54-a023-8625a83bd02f&interactionCount=1&landingPath=NotLandingPage&groups=C0048%3A1%2CC0001%3A1%2CC0040%3A0%2CC0032%3A0%2CC0025%3A0%2CC0020%3A0%2CC0037%3A0%2CC0039%3A0%2CC0036%3A0%2CC0041%3A0%2CC0042%3A0%2CC0044%3A0%2CC0043%3A0%2CC0045%3A0%2CC0049%3A0%2CC0047%3A0%2CC0023%3A0%2CC0056%3A0%2CC0038%3A0%2CC0082%3A0%2CC0026%3A0%2CC0177%3A0%2CC0113%3A0%2CC0089%3A0%2CC0092%3A0%2CC0190%3A0%2CC0166%3A0%2CC0222%3A0%2CC0223%3A0%2CC0231%3A0%2CC0263%3A0%2CC0004%3A0%2CC0022%3A0%2CC0054%3A0%2CC0179%3A0%2CC0146%3A0%2CC0052%3A0%2CC0034%3A0%2CC0063%3A0%2CC0157%3A0%2CC0003%3A0%2CC0212%3A0%2CC0081%3A0%2CC0051%3A0%2CC0136%3A0%2CC0135%3A0%2CC0007%3A0%2CV2STACK42%3A0&geolocation=FR%3BPAC&AwaitingReconsent=false; __cf_bm=32sbbXuy8HaPVSHaLsx3L9wb2EyQItq83OoKsTYjKWg-1743687254-1.0.1.1-8f86J3ZZVAbY.6MOY3OVfE1LSDlp_GrHPSpEErI4pGYtCRI.DSZ2zJjN5qhT7uOKys1bQZcvDLn8CGSKcJiOEWYqc3eWlEvYo.SjitkCZ.g; __cfwaitingroom_www=',
}

params = {
    'noRedirect': '0',
    'page': '2',
}

response = requests.get(
    'https://www.carrefour.fr/r/boissons/colas-thes-glaces-et-soft-drinks',
    params=params,
    cookies=cookies,
    headers=headers,
)

# %%
#Loop to get all the page
import time
response_1 = []
for x in range(1,14):
    params = {
    'noRedirect': '0',
    'page': str(x) ,
    }
    response = requests.get(
    'https://www.carrefour.fr/r/boissons/colas-thes-glaces-et-soft-drinks',
    params=params,
    cookies=cookies,
    headers=headers,
    )
    response_1.append(response.json())
    time.sleep(2)

print(response_1)
# Out:
# [{'data': [{'type': 'product', 'id': 'product-5449000296078', 'attributes': {'ean': '5449000296078', 'cdbase': '7201179', 'title': 'Soda sans sucres COCA-COLA', 'brand': None, 'slug': 'soda-sans-sucres-coca-cola', 'businessType': 'food', 'offerServiceId': '0261-150-6', 'uri': 'grands-formats', 'categories': [{'id': '27070', 'code': 'R00F00SF00', 'slug': 'boissons', 'label': 'Boissons', 'uri': 'boissons', 'type': 'RAYON', 'level': 1, 'sellerId': None}, {'id': '27073', 'code': 'R00F00SF00', 'slug': 'colas-thes-glaces-et-soft-drinks', 'label': 'Colas, Thés glacés, Sirops et Sodas', 'uri': 'boissons/colas-thes-glaces-et-soft-drinks', 'type': 'RAYON', 'level': 2, 'sellerId': None}, {'id': '27098', 'code': 'R00F00SF00', 'slug': 'colas', 'label': 'Colas', 'uri': 'boissons/colas-thes-glaces-et-soft-drinks/colas', 'type': 'RAYON', 'level': 3, 'sellerId': None}], 'topCategoryName': 'Boissons', 'images': {'formats': {'largest': '540x540', 'common': ['43x43', '200x200', '540x540', '1500x1500']}, 'paths': ['https://media.carrefour.fr/medias/99b718b6425d4ca1b8e01bd95e0c7669/p_FORMAT/05449000296078_A1N1_s02.jpeg']}, 'isDonation': False, 'isBestSeller': False, 'traceability': None, 'keyFeatures': [], 'moreOffers': {'count': 0, 'bestOfferId': None, 'bestOfferPrice': None, 'hasNonFoodDeliveryOffer': False, 'isRexEligible': False, 'withdrawalDelivery': {'exists': False, 'expressWithdrawalEligibility': {'global': False, 'inCurrentStore': False}}, 'hasCarrefourPlus': False}, 'offers': {'5449000296078': {'0261-150-6': {'type': 'offer', 'subType': 'carrefour', 'id': '0261-150-6', 'attributes': {'availability': {'indispensable': False, 'purchasable': True, 'stopped': False, 'suspended': False, 'suspensionReason': None, 'hasLowQuantity': False}, 'preorder': None, 'price': {'price': 6.95, 'taxMessage': '', 'unitOfMeasure': 'L', 'perUnit': 1.76, 'perUnitLabel': '1.76 € / L'}, 'ordering': {'min': 1, 'step': 1, 'max': 10}, 'offerServiceId': '0261-150-6', 'highlightLabel': {'type': 'promotion', 'key': 'product.label.promotion'}, 'freshness': None, 'marketplace': None, 'ean': '5449000296078', 'promotion': {'type': 'ri', 'label': '2 achetés = 2,5€ de remise', 'message': 'promotion.ri', 'isLoyalty': False, 'isPromo': False, 'isPrixBarre': False, 'isPrixForce': False, 'isVuEnCatalogue': False, 'isCrescendo': False, 'isClubActive': False, 'promotionParts': [], 'progression': {'current': None, 'total': None, 'completed': None}, 'bestQuantity': 2, 'messageArgs': {'quantity': 2, 'discountAmount': 2.5, 'discountedPrice': 11.4, 'initialPrice': 13.9, 'discountedPricePerUnit': None, 'startDate': '2025-03-31T00:00:00+0200', 'endDate': '2025-04-15T23:59:00+0200'}, 'promoStartDate': '2025-03-31T00:00:00+0200', 'promoEndDate': '2025-04-15T23:59:00+0200', 'mixableGtins': [], 'isPriceAlreadyDiscounted': True, 'mandateId': ['1120250000028972'], 'isDisplayed': True}, 'promotions': [{'type': 'ri', 'label': '2 achetés = 2,5€ de remise', 'message': 'promotion.ri', 'isLoyalty': False, 'isPromo': False, 'isPrixBarre': False, 'isPrixForce': False, 'isVuEnCatalogue': False, 'isCrescendo': False, 'isClubActive': False, 'promotionParts': [], 'progression': {'current': None, 'total': None, 'completed': None}, 'bestQuantity': 2, 'messageArgs': {'quantity': 2, 'discountAmount': 2.5, 'discountedPrice': 11.4, 'initialPrice': 13.9, 'discountedPricePerUnit': None, 'startDate': '2025-03-31T00:00:00+0200', 'endDate': '2025-04-15T23:59:00+0200'}, 'promoStartDate': '2025-03-31T00:00:00+0200', 'promoEndDate': '2025-04-15T23:59:00+0200', 'mixableGtins': [], 'isPriceAlreadyDiscounted': True, 'mandateId': ['1120250000028972'], 'isDisplayed': True}], 'variableWeight': False, 'isRexEligible': False, 'expressWithdrawalEligibility': {'global': False, 'inCurrentStore': False}, 'isNonFoodDelivery': False, 'isRelayPointEligible': False, 'description': None, 'shopReturnPolicy': None, 'bundle': {'label': None}, 'isNew': False, 'isInnovation': False, 'isAlternativeCheaper': False, 'isDigitalCard': False, 'isW ...

# %%
#Loop to get all the page
import time
response_2 = []
for x in range(14,26):
    params = {
    'noRedirect': '0',
    'page': str(x) ,
    }
    response = requests.get(
    'https://www.carrefour.fr/r/boissons/colas-thes-glaces-et-soft-drinks',
    params=params,
    cookies=cookies,
    headers=headers,
    )
    response_2.append(response.json())
    time.sleep(2)

print(response_2)
# Out:
# [{'data': [{'type': 'product', 'id': 'product-3124480186799', 'attributes': {'ean': '3124480186799', 'cdbase': '6213148', 'title': 'Boisson aux fruits saveur Pomme Cassis Framboise OASIS', 'brand': None, 'slug': 'boisson-aux-fruits-saveur-pomme-cassis-framboise-oasis', 'businessType': 'food', 'offerServiceId': '0261-150-6', 'uri': 'boissons/colas-thes-glaces-et-soft-drinks/boissons-plates-aux-fruits', 'categories': [{'id': '27070', 'code': 'R00F00SF00', 'slug': 'boissons', 'label': 'Boissons', 'uri': 'boissons', 'type': 'RAYON', 'level': 1, 'sellerId': None}, {'id': '27073', 'code': 'R00F00SF00', 'slug': 'colas-thes-glaces-et-soft-drinks', 'label': 'Colas, Thés glacés, Sirops et Sodas', 'uri': 'boissons/colas-thes-glaces-et-soft-drinks', 'type': 'RAYON', 'level': 2, 'sellerId': None}, {'id': '27102', 'code': 'R00F00SF00', 'slug': 'boissons-plates-aux-fruits', 'label': 'Boissons plates aux fruits', 'uri': 'boissons/colas-thes-glaces-et-soft-drinks/boissons-plates-aux-fruits', 'type': 'RAYON', 'level': 3, 'sellerId': None}], 'topCategoryName': 'Boissons', 'images': {'formats': {'largest': '540x540', 'common': ['43x43', '200x200', '540x540', '1500x1500']}, 'paths': ['https://media.carrefour.fr/medias/673168f955ea4e6ea73f280c7eccd5a2/p_FORMAT/03124480186799_C1N1_s21.jpeg']}, 'isDonation': False, 'isBestSeller': False, 'traceability': None, 'keyFeatures': [], 'moreOffers': {'count': 0, 'bestOfferId': None, 'bestOfferPrice': None, 'hasNonFoodDeliveryOffer': False, 'isRexEligible': False, 'withdrawalDelivery': {'exists': False, 'expressWithdrawalEligibility': {'global': False, 'inCurrentStore': False}}, 'hasCarrefourPlus': False}, 'offers': {'3124480186799': {'0261-150-6': {'type': 'offer', 'subType': 'carrefour', 'id': '0261-150-6', 'attributes': {'availability': {'indispensable': False, 'purchasable': True, 'stopped': False, 'suspended': False, 'suspensionReason': None, 'hasLowQuantity': False}, 'preorder': None, 'price': {'price': 4.19, 'taxMessage': '', 'unitOfMeasure': 'L', 'perUnit': 2.12, 'perUnitLabel': '2.12 € / L'}, 'ordering': {'min': 1, 'step': 1, 'max': 10}, 'offerServiceId': '0261-150-6', 'highlightLabel': None, 'freshness': None, 'marketplace': None, 'ean': '3124480186799', 'promotion': None, 'promotions': [], 'variableWeight': False, 'isRexEligible': False, 'expressWithdrawalEligibility': {'global': False, 'inCurrentStore': False}, 'isNonFoodDelivery': False, 'isRelayPointEligible': False, 'description': None, 'shopReturnPolicy': None, 'bundle': {'label': None}, 'isNew': False, 'isInnovation': False, 'isAlternativeCheaper': False, 'isDigitalCard': False, 'isWholesale': False, 'isClcv': False, 'isZiqy': False, 'isHealthy': False, 'isPhysicalStoreOffer': False, 'isExpressDelivery': False, 'isRecoverable': False, 'guarantees': []}, 'meta': {'cta': 'buy'}, 'links': {'self': ''}}}}, 'packaging': 'le pack de 6 canettes de 33cL', 'deliveryModalities': [], 'flags': [], 'clubs': [], 'origin': '', 'format': '6x33cL', 'nutriscore': {'value': 'E', 'source': '', 'licence': ''}, 'customerReviews': {'average': 4.48, 'count': 106, 'rates': None}, 'variants': [], 'weightsAndMeasures': [], 'guarantee_general_document': 'https://static-cms.carrefour.fr/sites/default/files/documents/garanties-carrefour-plus-document-information-cgv.pdf'}, 'relationships': {'substitution': None}, 'meta': {'recommendation': None, 'cta': 'buy', 'features': {'deletable': False, 'swap': False, 'feedback': False, 'freshness': True}}, 'links': {'self': '/p/boisson-aux-fruits-saveur-pomme-cassis-framboise-oasis-3124480186799?t=27073', 'reviews': '/product/3124480186799/reviews'}}, {'type': 'product', 'id': 'product-3124480198464', 'attributes': {'ean': '3124480198464', 'cdbase': '7802155', 'title': 'Boisson aux Fruits Tropical OASIS', 'brand': None, 'slug': 'boisson-aux-fruits-tropical-oasis', 'businessType': 'food', 'offerServiceId': '0261-150-6', 'uri': 'boissons/colas-thes-glaces-et-soft-drinks/boissons-plates-aux-fruits', 'categories': [{'id': '27070', 'code ...

# %%
#Get the relevant columns and extract the price/kg
import pandas as pd

df_1 = pd.DataFrame()  # Initialize an empty DataFrame

for item in response_1:  # Loop through each JSON object
    try:
        # Ensure 'data' exists and extract it safely
        df_data = pd.DataFrame(item.get('data', []))  
        
        # Ensure 'attributes' exists before normalizing
        if 'attributes' in df_data:
            df_product = pd.json_normalize(df_data['attributes'])
        else:
            print("Warning: 'attributes' key missing in data.")
            continue  # Skip this item if 'attributes' is missing

        price_unit = []
        for x in df_product.get("ean", []):  # Use .get() to avoid KeyError
            try:
                ean_index = df_product[df_product["ean"] == x].index[0]
                price_column = f"offers.{x}.0261-150-6.attributes.price.perUnitLabel"

                # Check if the column exists before accessing
                if price_column in df_product.columns:
                    price_unit_variable = df_product.loc[ean_index, price_column]
                else:
                    price_unit_variable = None  # Default if price column missing

                price_unit.append(price_unit_variable)
            except Exception as e:
                print(f"Error processing EAN {x}: {e}")
                price_unit.append(None)  # Append None for failed entries

        price = []
        for x in df_product.get("ean", []):  # Use .get() to avoid KeyError
            try:
                ean_index = df_product[df_product["ean"] == x].index[0]
                price_column = f"offers.{x}.0261-150-6.attributes.price.price"

                # Check if the column exists before accessing
                if price_column in df_product.columns:
                    price_variable = df_product.loc[ean_index, price_column]
                else:
                    price_variable = None  # Default if price column missing

                price.append(price_variable)
            except Exception as e:
                print(f"Error processing EAN {x}: {e}")
                price.append(None)  # Append None for failed entries

        # Select relevant columns safely
        try:
            df_final = df_product[["title", "slug", "topCategoryName", "origin"]].copy()
        except KeyError as e:
            print(f"Missing column error: {e}")
            continue  # Skip this item if required columns are missing

        # Add price_unit column
        df_final["price_unit"] = price_unit
        df_final["price"] = price

        # Concatenate safely
        df_1 = pd.concat([df_1, df_final], ignore_index=True)

    except Exception as e:
        print(f"Error processing item: {e}")
        continue  # Skip the item on error

# Print the final DataFrame
print(df_1)
# Out:
#                                                  title  \
# 0                           Soda sans sucres COCA-COLA
# 1    Boisson aux fruits saveur Pomme Cassis Framboi...
# 2                 Thé glacé saveur Pêche OASIS ICE TEA
# 3                    Boisson aux fruits Tropical OASIS
# 4                Soda orange aux arômes naturels FANTA
# ..                                                 ...
# 385  Boisson citronnade pétillante saveur Citron, C...
# 386                    Boisson citronnade Citron PULCO
# 387                  Boisson aux fruits Tropical OASIS
# 388                  Boisson aux fruits Tropical OASIS
# 389                    Boisson aux fruits Orange OASIS
#
#                                                   slug topCategoryName origin  \
# 0                           soda-sans-sucres-coca-cola        Boissons
# 1    boisson-aux-fruits-saveur-pomme-cassis-framboi...        Boissons
# 2                 the-glace-saveur-peche-oasis-ice-tea        Boissons
# 3                    boisson-aux-fruits-tropical-oasis        Boissons
# 4                soda-orange-aux-aromes-naturels-fanta        Boissons
# ..                                                 ...             ...    ...
# 385  boisson-citronnade-petillante-saveur-citron-ca...        Boissons
# 386                    boisson-citronnade-citron-pulco        Boissons
# 387                  boisson-aux-fruits-tropical-oasis        Boissons
# 388                  boisson-aux-fruits-tropical-oasis        Boissons
# 389                    boisson-aux-fruits-orange-oasis        Boissons
#
#      price_unit  price
# 0    1.76 € / L   6.95
# 1    1.29 € / L   2.58
# 2    1.37 € / L   2.05
# 3    1.34 € / L   2.69
# 4    1.19 € / L   1.49
# ..          ...    ...
# 385  1.99 € / L   1.99
# 386  2.48 € / L   1.55
# 387  2.32 € / L   4.65
# 388  1.89 € / L   3.75
# 389  1.99 € / L   3.95
#
# [390 rows x 6 columns]

# %%
#Get the relevant columns and extract the price/kg
import pandas as pd

df_2 = pd.DataFrame()  # Initialize an empty DataFrame

for item in response_2:  # Loop through each JSON object
    try:
        # Ensure 'data' exists and extract it safely
        df_data = pd.DataFrame(item.get('data', []))  
        
        # Ensure 'attributes' exists before normalizing
        if 'attributes' in df_data:
            df_product = pd.json_normalize(df_data['attributes'])
        else:
            print("Warning: 'attributes' key missing in data.")
            continue  # Skip this item if 'attributes' is missing

        price_unit = []
        for x in df_product.get("ean", []):  # Use .get() to avoid KeyError
            try:
                ean_index = df_product[df_product["ean"] == x].index[0]
                price_column = f"offers.{x}.0261-150-6.attributes.price.perUnitLabel"

                # Check if the column exists before accessing
                if price_column in df_product.columns:
                    price_unit_variable = df_product.loc[ean_index, price_column]
                else:
                    price_unit_variable = None  # Default if price column missing

                price_unit.append(price_unit_variable)
            except Exception as e:
                print(f"Error processing EAN {x}: {e}")
                price_unit.append(None)  # Append None for failed entries

        price = []
        for x in df_product.get("ean", []):  # Use .get() to avoid KeyError
            try:
                ean_index = df_product[df_product["ean"] == x].index[0]
                price_column = f"offers.{x}.0261-150-6.attributes.price.price"

                # Check if the column exists before accessing
                if price_column in df_product.columns:
                    price_variable = df_product.loc[ean_index, price_column]
                else:
                    price_variable = None  # Default if price column missing

                price.append(price_variable)
            except Exception as e:
                print(f"Error processing EAN {x}: {e}")
                price.append(None)  # Append None for failed entries

        # Select relevant columns safely
        try:
            df_final = df_product[["title", "slug", "topCategoryName", "origin"]].copy()
        except KeyError as e:
            print(f"Missing column error: {e}")
            continue  # Skip this item if required columns are missing

        # Add price_unit column
        df_final["price_unit"] = price_unit
        df_final["price"] = price

        # Concatenate safely
        df_2 = pd.concat([df_2, df_final], ignore_index=True)

    except Exception as e:
        print(f"Error processing item: {e}")
        continue  # Skip the item on error

# Print the final DataFrame
print(df_2)
# Out:
#                                                  title  \
# 0    Boisson aux fruits saveur Pomme Cassis Framboi...
# 1                    Boisson aux Fruits Tropical OASIS
# 2      Boisson aux Fruits Pomme Cassis Framboise OASIS
# 3                    Boisson aux fruits Tropical OASIS
# 4        Boisson aux fruits Sans Sucres Tropical OASIS
# ..                                                 ...
# 335  Concentré  Lipton Green Ice Tea saveur Agrumes...
# 336              Soda Dr Pepper  - 6 Canettes De 33cl
# 337  Frize Limao - Boisson Gazeuse Du Portugal Au C...
# 338                         Lorina Limonade Pink 33cl
# 339  Lot 6x Sirop D'agave Bio - Cœur D'agave - Sque...
#
#                                                   slug topCategoryName  \
# 0    boisson-aux-fruits-saveur-pomme-cassis-framboi...        Boissons
# 1                    boisson-aux-fruits-tropical-oasis        Boissons
# 2      boisson-aux-fruits-pomme-cassis-framboise-oasis        Boissons
# 3                    boisson-aux-fruits-tropical-oasis        Boissons
# 4        boisson-aux-fruits-sans-sucres-tropical-oasis        Boissons
# ..                                                 ...             ...
# 335  concentre-lipton-green-ice-tea-saveur-agrumes-...        Boissons
# 336                  soda-dr-pepper-6-canettes-de-33cl        Boissons
# 337  frize-limao-boisson-gazeuse-du-portugal-au-cit...        Boissons
# 338                          lorina-limonade-pink-33cl        Boissons
# 339  lot-6x-sirop-d-agave-bio-coeur-d-agave-squeeze...        Boissons
#
#      origin  price_unit  price
# 0            2.12 € / L   4.19
# 1            2.02 € / L   7.98
# 2            1.79 € / L   7.10
# 3            3.36 € / L   6.05
# 4            1.50 € / L   2.25
# ..      ...         ...    ...
# 335     NaN        None    NaN
# 336                None    NaN
# 337                None    NaN
# 338  FRANCE        None    NaN
# 339                None    NaN
#
# [340 rows x 6 columns]
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_3804\2548600434.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_2 = pd.concat([df_2, df_final], ignore_index=True)
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_3804\2548600434.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_2 = pd.concat([df_2, df_final], ignore_index=True)

# %%
df = pd.concat([df_1, df_2], ignore_index=True)

# %%
df["slug"] = "soda"

# %%
df.to_csv("soda.csv", index=False)
