# %%
import requests

cookies = {
    'tc_cj_v2_cmp': '',
    'tc_cj_v2_med': '',
    'tc_ts': '40',
    'FRONTONE_ONLINE': '1745247464',
    'FRONTONE_SESSION_ID': 'fe0e97616cc0dc73679f62b16fa7c577b2d86018',
    'CAID': '202503221557457366701354',
    'OptanonAlertBoxClosed': '2025-03-22T14:57:49.848Z',
    'eupubconsent-v2': 'CQOq1pgQOq1pgAcABBENBiFwAAAAAAAAAChQAAAAAAChIAYAygF5gTAHQAwBlALzAmAOAAgSEJQAQF5lIAYAygF5gTAA.YAAAAAAAAAAA',
    'OneTrustGroupsConsent': '%2CC0048%2CC0001%2C',
    'FRONTONE_SESSID': 'uim3dg95re0gh6j1p6jnc30adj',
    'sap-closed': '1',
    'tc_eff_params': '',
    'tc_ab': '1',
    'aaaaaaaaa944fac35b02f4d9a99619247b88ad463_cs': '',
    'cf_chl_rc_i': '1',
    'cf_clearance': 'xK4P3RVaug6z7R3iwLrTNr5NHc4JPyII6Zr6PjdobY4-1743680121-1.2.1.1-pCZIro4fSU4AzvEvMzfHJlVQdLdUyQ.vlbppVCQgFqFXNZLKWH31YfREqcEjN8T5Bi1bLnRDm86dDkE3TqzSlwnR.p5xusa8LYtcPpPMIgNrwlL8db6.Qe7hnuHXGoBd7pa_gKP1tTkABwZ5XOscWrLrG.g0ghu5Cray3ibCXceIWrrA8BHYqiwz4KxoO2IOKhwZp0Wxvoly6zaXU9Of7Nz1Z_7HgMDfBv946emu0vwtTw43ulJVvmABDa9b2HPWzdPPB7Yy1L0xEj_GU9Wrk.nqu.EYRUQMrmTFudzxnqYvzh4cBtam8VuakxQoCpBZt6KknFw.euw220myr_49czw20DLAbt94IcquEcwBvyKvpTIUQsPIlEoSm8sFawBU',
    'tc_cj_v2': '%5Ecl_%5Dny%5B%5D%5D_mmZZZZZZKQNLPOONPSSJKZZZ%5D777m_iZZZ%2C2%7B%29%2FZZZKQNMLOJOSNKMQZZZ%5D777%5Ecl_%5Dny%5B%5D%5D_mmZZZZZZKQNMPRJRSMPSRZZZ%5D',
    'pageCounterCrfOne': '16',
    'OptanonConsent': 'isGpcEnabled=0&datestamp=Thu+Apr+03+2025+13%3A48%3A14+GMT%2B0200+(heure+d%E2%80%99%C3%A9t%C3%A9+d%E2%80%99Europe+centrale)&version=202310.2.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=92a3e744-b25d-4e54-a023-8625a83bd02f&interactionCount=1&landingPath=NotLandingPage&groups=C0048%3A1%2CC0001%3A1%2CC0040%3A0%2CC0032%3A0%2CC0025%3A0%2CC0020%3A0%2CC0037%3A0%2CC0039%3A0%2CC0036%3A0%2CC0041%3A0%2CC0042%3A0%2CC0044%3A0%2CC0043%3A0%2CC0045%3A0%2CC0049%3A0%2CC0047%3A0%2CC0023%3A0%2CC0056%3A0%2CC0038%3A0%2CC0082%3A0%2CC0026%3A0%2CC0177%3A0%2CC0113%3A0%2CC0089%3A0%2CC0092%3A0%2CC0190%3A0%2CC0166%3A0%2CC0222%3A0%2CC0223%3A0%2CC0231%3A0%2CC0263%3A0%2CC0004%3A0%2CC0022%3A0%2CC0054%3A0%2CC0179%3A0%2CC0146%3A0%2CC0052%3A0%2CC0034%3A0%2CC0063%3A0%2CC0157%3A0%2CC0003%3A0%2CC0212%3A0%2CC0081%3A0%2CC0051%3A0%2CC0136%3A0%2CC0135%3A0%2CC0007%3A0%2CV2STACK42%3A0&geolocation=FR%3BPAC&AwaitingReconsent=false',
    'carrefour_counter': '1743680895028%7C137739566618166%7Cp0%7Ce0%7Cv1%7Cc254.41%7CServerSide',
    '__cf_bm': 'rZPtG5yDD_S.lJ43e0BM6lkPOreBMeOzJZnouqejfOQ-1743680889-1.0.1.1-u2hpKPZ.UV1rVX8scEj_cG5i1FtGIHCq7sfEGOfZSu7eAiUdWdYe6KinmtXxl7OH6CpostZ8U5gOpVyc3lxbyQ2M8.Kk4m7hsQgIH3xyt84',
    '__cfwaitingroom_www': '',
}

headers = {
    'accept': 'application/json, text/plain, */*',
    'accept-language': 'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7',
    'priority': 'u=1, i',
    'referer': 'https://www.carrefour.fr/r/cremerie/fromages-coupe',
    'sec-ch-ua': '"Chromium";v="134", "Not:A-Brand";v="24", "Google Chrome";v="134"',
    'sec-ch-ua-arch': '"x86"',
    'sec-ch-ua-bitness': '"64"',
    'sec-ch-ua-full-version': '"134.0.6998.178"',
    'sec-ch-ua-full-version-list': '"Chromium";v="134.0.6998.178", "Not:A-Brand";v="24.0.0.0", "Google Chrome";v="134.0.6998.178"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-model': '""',
    'sec-ch-ua-platform': '"Windows"',
    'sec-ch-ua-platform-version': '"10.0.0"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest',
    # 'cookie': 'tc_cj_v2_cmp=; tc_cj_v2_med=; tc_ts=40; FRONTONE_ONLINE=1745247464; FRONTONE_SESSION_ID=fe0e97616cc0dc73679f62b16fa7c577b2d86018; CAID=202503221557457366701354; OptanonAlertBoxClosed=2025-03-22T14:57:49.848Z; eupubconsent-v2=CQOq1pgQOq1pgAcABBENBiFwAAAAAAAAAChQAAAAAAChIAYAygF5gTAHQAwBlALzAmAOAAgSEJQAQF5lIAYAygF5gTAA.YAAAAAAAAAAA; OneTrustGroupsConsent=%2CC0048%2CC0001%2C; FRONTONE_SESSID=uim3dg95re0gh6j1p6jnc30adj; sap-closed=1; tc_eff_params=; tc_ab=1; aaaaaaaaa944fac35b02f4d9a99619247b88ad463_cs=; cf_chl_rc_i=1; cf_clearance=xK4P3RVaug6z7R3iwLrTNr5NHc4JPyII6Zr6PjdobY4-1743680121-1.2.1.1-pCZIro4fSU4AzvEvMzfHJlVQdLdUyQ.vlbppVCQgFqFXNZLKWH31YfREqcEjN8T5Bi1bLnRDm86dDkE3TqzSlwnR.p5xusa8LYtcPpPMIgNrwlL8db6.Qe7hnuHXGoBd7pa_gKP1tTkABwZ5XOscWrLrG.g0ghu5Cray3ibCXceIWrrA8BHYqiwz4KxoO2IOKhwZp0Wxvoly6zaXU9Of7Nz1Z_7HgMDfBv946emu0vwtTw43ulJVvmABDa9b2HPWzdPPB7Yy1L0xEj_GU9Wrk.nqu.EYRUQMrmTFudzxnqYvzh4cBtam8VuakxQoCpBZt6KknFw.euw220myr_49czw20DLAbt94IcquEcwBvyKvpTIUQsPIlEoSm8sFawBU; tc_cj_v2=%5Ecl_%5Dny%5B%5D%5D_mmZZZZZZKQNLPOONPSSJKZZZ%5D777m_iZZZ%2C2%7B%29%2FZZZKQNMLOJOSNKMQZZZ%5D777%5Ecl_%5Dny%5B%5D%5D_mmZZZZZZKQNMPRJRSMPSRZZZ%5D; pageCounterCrfOne=16; OptanonConsent=isGpcEnabled=0&datestamp=Thu+Apr+03+2025+13%3A48%3A14+GMT%2B0200+(heure+d%E2%80%99%C3%A9t%C3%A9+d%E2%80%99Europe+centrale)&version=202310.2.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=92a3e744-b25d-4e54-a023-8625a83bd02f&interactionCount=1&landingPath=NotLandingPage&groups=C0048%3A1%2CC0001%3A1%2CC0040%3A0%2CC0032%3A0%2CC0025%3A0%2CC0020%3A0%2CC0037%3A0%2CC0039%3A0%2CC0036%3A0%2CC0041%3A0%2CC0042%3A0%2CC0044%3A0%2CC0043%3A0%2CC0045%3A0%2CC0049%3A0%2CC0047%3A0%2CC0023%3A0%2CC0056%3A0%2CC0038%3A0%2CC0082%3A0%2CC0026%3A0%2CC0177%3A0%2CC0113%3A0%2CC0089%3A0%2CC0092%3A0%2CC0190%3A0%2CC0166%3A0%2CC0222%3A0%2CC0223%3A0%2CC0231%3A0%2CC0263%3A0%2CC0004%3A0%2CC0022%3A0%2CC0054%3A0%2CC0179%3A0%2CC0146%3A0%2CC0052%3A0%2CC0034%3A0%2CC0063%3A0%2CC0157%3A0%2CC0003%3A0%2CC0212%3A0%2CC0081%3A0%2CC0051%3A0%2CC0136%3A0%2CC0135%3A0%2CC0007%3A0%2CV2STACK42%3A0&geolocation=FR%3BPAC&AwaitingReconsent=false; carrefour_counter=1743680895028%7C137739566618166%7Cp0%7Ce0%7Cv1%7Cc254.41%7CServerSide; __cf_bm=rZPtG5yDD_S.lJ43e0BM6lkPOreBMeOzJZnouqejfOQ-1743680889-1.0.1.1-u2hpKPZ.UV1rVX8scEj_cG5i1FtGIHCq7sfEGOfZSu7eAiUdWdYe6KinmtXxl7OH6CpostZ8U5gOpVyc3lxbyQ2M8.Kk4m7hsQgIH3xyt84; __cfwaitingroom_www=',
}

params = {
    'noRedirect': '0',
    'page': '2',
}

response = requests.get('https://www.carrefour.fr/r/cremerie/fromages-coupe', params=params, cookies=cookies, headers=headers)

# %%
#Loop to get all the page
import time
response_cheese_1 = []
for x in range(1,11):
    params = {
    'noRedirect': '0',
    'page': str(x) ,
    }
    response = requests.get(
    'https://www.carrefour.fr/r/cremerie/fromages-coupe',
    params=params,
    cookies=cookies,
    headers=headers,
    )
    response_cheese_1.append(response.json())
    time.sleep(2)

print(response_cheese_1)
# Out:
# [{'data': [{'type': 'product', 'id': 'product-3560070993475', 'attributes': {'ean': '3560070993475', 'cdbase': '5678755', 'title': 'Plateau de Fromages Roquefort AOP,Brie AOP,Cantal AOP,Saint-Marcellin IGP,Rocamadours AOP REFLETS DE FRANCE', 'brand': None, 'slug': 'plateau-de-fromages-roquefort-aop-brie-aop-cantal-aop-saint-marcellin-igp-rocamadours-aop-reflets-de', 'businessType': 'food', 'offerServiceId': '0261-150-6', 'uri': 'cremerie/fromages-coupe/plateau-aperitif', 'categories': [{'id': '36993', 'code': 'R00F00SF00', 'slug': 'cremerie', 'label': 'Crèmerie et Produits laitiers', 'uri': 'cremerie', 'type': 'RAYON', 'level': 1, 'sellerId': None}, {'id': '28276', 'code': 'R00F00SF00', 'slug': 'fromages-coupe', 'label': 'Fromages à la coupe', 'uri': 'cremerie/fromages-coupe', 'type': 'RAYON', 'level': 2, 'sellerId': None}, {'id': '31221', 'code': 'R00F00SF00', 'slug': 'plateau-aperitif', 'label': 'Plateaux de fromages', 'uri': 'cremerie/fromages-coupe/plateau-aperitif', 'type': 'RAYON', 'level': 3, 'sellerId': None}], 'topCategoryName': 'Crèmerie et Produits laitiers', 'images': {'formats': {'largest': '540x540', 'common': ['43x43', '200x200', '540x540', '1500x1500']}, 'paths': ['https://media.carrefour.fr/medias/1551b85dc9293b10aee0112482af25c1/p_FORMAT/3560070993475-photosite-20171219-161446-0.jpg', 'https://media.carrefour.fr/medias/eabe59cc9b873546a61b1195e41a8592/p_FORMAT/3560070993475-photosite-20171219-161446-7.jpg']}, 'isDonation': False, 'isBestSeller': False, 'traceability': None, 'keyFeatures': [], 'moreOffers': {'count': 0, 'bestOfferId': None, 'bestOfferPrice': None, 'hasNonFoodDeliveryOffer': False, 'isRexEligible': False, 'withdrawalDelivery': {'exists': False, 'expressWithdrawalEligibility': {'global': False, 'inCurrentStore': False}}, 'hasCarrefourPlus': False}, 'offers': {'3560070993475': {'0261-150-6': {'type': 'offer', 'subType': 'carrefour', 'id': '0261-150-6', 'attributes': {'availability': {'indispensable': False, 'purchasable': True, 'stopped': False, 'suspended': False, 'suspensionReason': None, 'hasLowQuantity': False}, 'preorder': None, 'price': {'price': 14.49, 'taxMessage': '', 'unitOfMeasure': 'KG', 'perUnit': 20.7, 'perUnitLabel': '20.70 € / KG'}, 'ordering': {'min': 1, 'step': 1, 'max': 50}, 'offerServiceId': '0261-150-6', 'highlightLabel': {'type': 'promotion', 'value': 'Vu en catalogue'}, 'freshness': {'value': 5, 'period': 'day'}, 'marketplace': None, 'ean': '3560070993475', 'promotion': {'type': 'ta', 'label': 'Vu en catalogue', 'message': 'promotion.ta', 'isLoyalty': False, 'isPromo': False, 'isPrixBarre': False, 'isPrixForce': False, 'isVuEnCatalogue': True, 'isCrescendo': False, 'isClubActive': False, 'promotionParts': [], 'progression': {'current': None, 'total': None, 'completed': None}, 'bestQuantity': 1, 'messageArgs': {'quantity': 1, 'discountAmount': 0, 'discountedPrice': 14.49, 'initialPrice': 14.49, 'discountedPricePerUnit': None, 'startDate': '2025-04-01T00:00:00+0200', 'endDate': '2025-04-14T23:59:00+0200'}, 'promoStartDate': '2025-04-01T00:00:00+0200', 'promoEndDate': '2025-04-14T23:59:00+0200', 'mixableGtins': [], 'isPriceAlreadyDiscounted': True, 'mandateId': ['2025000631432'], 'isDisplayed': True}, 'promotions': [{'type': 'ta', 'label': 'Vu en catalogue', 'message': 'promotion.ta', 'isLoyalty': False, 'isPromo': False, 'isPrixBarre': False, 'isPrixForce': False, 'isVuEnCatalogue': True, 'isCrescendo': False, 'isClubActive': False, 'promotionParts': [], 'progression': {'current': None, 'total': None, 'completed': None}, 'bestQuantity': 1, 'messageArgs': {'quantity': 1, 'discountAmount': 0, 'discountedPrice': 14.49, 'initialPrice': 14.49, 'discountedPricePerUnit': None, 'startDate': '2025-04-01T00:00:00+0200', 'endDate': '2025-04-14T23:59:00+0200'}, 'promoStartDate': '2025-04-01T00:00:00+0200', 'promoEndDate': '2025-04-14T23:59:00+0200', 'mixableGtins': [], 'isPriceAlreadyDiscounted': True, 'mandateId': ['2025000631432'], 'isDisplayed': True}], 'variableWeight': False, 'isRex ...

# %%
#Get the relevant columns and extract the price/kg
import pandas as pd

df_cheese_1 = pd.DataFrame()  # Initialize an empty DataFrame

for item in response_cheese_1:  # Loop through each JSON object
    try:
        # Ensure 'data' exists and extract it safely
        df_data = pd.DataFrame(item.get('data', []))  
        
        # Ensure 'attributes' exists before normalizing
        if 'attributes' in df_data:
            df_product = pd.json_normalize(df_data['attributes'])
        else:
            print("Warning: 'attributes' key missing in data.")
            continue  # Skip this item if 'attributes' is missing

        price_unit = []
        for x in df_product.get("ean", []):  # Use .get() to avoid KeyError
            try:
                ean_index = df_product[df_product["ean"] == x].index[0]
                price_column = f"offers.{x}.0261-150-6.attributes.price.perUnitLabel"

                # Check if the column exists before accessing
                if price_column in df_product.columns:
                    price_unit_variable = df_product.loc[ean_index, price_column]
                else:
                    price_unit_variable = None  # Default if price column missing

                price_unit.append(price_unit_variable)
            except Exception as e:
                print(f"Error processing EAN {x}: {e}")
                price_unit.append(None)  # Append None for failed entries

        price = []
        for x in df_product.get("ean", []):  # Use .get() to avoid KeyError
            try:
                ean_index = df_product[df_product["ean"] == x].index[0]
                price_column = f"offers.{x}.0261-150-6.attributes.price.price"

                # Check if the column exists before accessing
                if price_column in df_product.columns:
                    price_variable = df_product.loc[ean_index, price_column]
                else:
                    price_variable = None  # Default if price column missing

                price.append(price_variable)
            except Exception as e:
                print(f"Error processing EAN {x}: {e}")
                price.append(None)  # Append None for failed entries

        # Select relevant columns safely
        try:
            df_final = df_product[["title", "slug", "topCategoryName", "origin"]].copy()
        except KeyError as e:
            print(f"Missing column error: {e}")
            continue  # Skip this item if required columns are missing

        # Add price_unit column
        df_final["price_unit"] = price_unit
        df_final["price"] = price

        # Concatenate safely
        df_cheese_1 = pd.concat([df_cheese_1, df_final], ignore_index=True)

    except Exception as e:
        print(f"Error processing item: {e}")
        continue  # Skip the item on error

# Print the final DataFrame
print(df_cheese_1)
# Out:
#                                                  title  \
# 0    Plateau de Fromages Roquefort AOP,Brie AOP,Can...
# 1                                         Fromage Brie
# 2    Fromage Comté AOP 12 mois affinage REFLETS DE ...
# 3                 Fromage Comté AOP 18 mois d'affinage
# 4        Fromage Morbier AOP FILIERE QUALITE CARREFOUR
# ..                                                 ...
# 295              Fromage Morbier AOP REFLETS DE FRANCE
# 296                                Fromage Morbier AOP
# 297                        Fromage Chaource AOP LINCET
# 298                         Fromage Saint Nectaire AOP
# 299                          Fromage Tomme de montagne
#
#                                                   slug  \
# 0    plateau-de-fromages-roquefort-aop-brie-aop-can...
# 1                                         fromage-brie
# 2    fromage-comte-aop-12-mois-affinage-reflets-de-...
# 3                 fromage-comte-aop-18-mois-d-affinage
# 4        fromage-morbier-aop-filiere-qualite-carrefour
# ..                                                 ...
# 295              fromage-morbier-aop-reflets-de-france
# 296                                fromage-morbier-aop
# 297                        fromage-chaource-aop-lincet
# 298                         fromage-saint-nectaire-aop
# 299                          fromage-tomme-de-montagne
#
#                    topCategoryName origin    price_unit  price
# 0    Crèmerie et Produits laitiers         20.70 € / KG  14.49
# 1    Crèmerie et Produits laitiers         10.00 € / KG   2.00
# 2    Crèmerie et Produits laitiers         23.50 € / KG   5.40
# 3    Crèmerie et Produits laitiers          6.32 € / KG   1.45
# 4    Crèmerie et Produits laitiers          3.97 € / KG   0.99
# ..                             ...    ...           ...    ...
# 295  Crèmerie et Produits laitiers          4.20 € / KG   1.00
# 296  Crèmerie et Produits laitiers         18.75 € / KG   3.00
# 297  Crèmerie et Produits laitiers         17.40 € / KG   4.35
# 298  Crèmerie et Produits laitiers         12.50 € / KG   2.50
# 299  Crèmerie et Produits laitiers         19.90 € / KG   4.17
#
# [300 rows x 6 columns]

# %%
#change slug for fromage
df_cheese_1["slug"] = "fromage"

# %%
df_cheese_1.to_csv("cheese_2.csv", index=False)
