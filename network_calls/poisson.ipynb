# %%
import requests

cookies = {
    'tc_cj_v2_cmp': '',
    'tc_cj_v2_med': '',
    'tc_ts': '40',
    'FRONTONE_ONLINE': '1745247464',
    'FRONTONE_SESSION_ID': 'fe0e97616cc0dc73679f62b16fa7c577b2d86018',
    'CAID': '202503221557457366701354',
    'OptanonAlertBoxClosed': '2025-03-22T14:57:49.848Z',
    'eupubconsent-v2': 'CQOq1pgQOq1pgAcABBENBiFwAAAAAAAAAChQAAAAAAChIAYAygF5gTAHQAwBlALzAmAOAAgSEJQAQF5lIAYAygF5gTAA.YAAAAAAAAAAA',
    'OneTrustGroupsConsent': '%2CC0048%2CC0001%2C',
    'FRONTONE_SESSID': 'uim3dg95re0gh6j1p6jnc30adj',
    'sap-closed': '1',
    'tc_eff_params': '',
    'tc_ab': '1',
    'aaaaaaaaa944fac35b02f4d9a99619247b88ad463_cs': '',
    'cf_clearance': 'ejQ63F_1s06TNPQ7ARE1hYyun_ngF5WZ4HM.KyqVwWY-1743685936-1.2.1.1-W8hQPeNII6esIHjsPj7mz__mVqGsfGX.4Em.5k5VJq17i1ECsSPwpJ9PbKaIEPYtAZ7IeajQ7BgsgU7SCaKU9c.9eU2rdBxHL_OpYOiShsFZratV5nPQ7ngFo1nSSNapiTi209Z3bQhHwElT_XXZmtY6z6FGVJIGKiWBs7wsB335RvPO1ZNg8M1SvxNOi1w0w4xyCl73oLfq671G3mvr_gs40kp_YzX9pZWwsppILZK9SML.CWqDdrCu_2toPyZjHKCi3ol8gISXaqo.CLZxoIPRrfCq32k2TZuSP7t3XwrPKueKH4h8oeWIsf.DUTBxLb2HLnlrZiv7mV19FR2OrR_14UUtNod97D0.b8ueJQ0S8WyY5__K4MeuWQgvtYay',
    'tc_cj_v2': '%5Ecl_%5Dny%5B%5D%5D_mmZZZZZZKQNLPOONPSSJKZZZ%5D777m_iZZZ%2C2%7B%29%2FZZZKQNMLOJOSNKMQZZZ%5D777%5Ecl_%5Dny%5B%5D%5D_mmZZZZZZKQNMPRPOSSQQKZZZ%5D',
    'pageCounterCrfOne': '30',
    'OptanonConsent': 'isGpcEnabled=0&datestamp=Thu+Apr+03+2025+15%3A23%3A21+GMT%2B0200+(heure+d%E2%80%99%C3%A9t%C3%A9+d%E2%80%99Europe+centrale)&version=202310.2.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=92a3e744-b25d-4e54-a023-8625a83bd02f&interactionCount=1&landingPath=NotLandingPage&groups=C0048%3A1%2CC0001%3A1%2CC0040%3A0%2CC0032%3A0%2CC0025%3A0%2CC0020%3A0%2CC0037%3A0%2CC0039%3A0%2CC0036%3A0%2CC0041%3A0%2CC0042%3A0%2CC0044%3A0%2CC0043%3A0%2CC0045%3A0%2CC0049%3A0%2CC0047%3A0%2CC0023%3A0%2CC0056%3A0%2CC0038%3A0%2CC0082%3A0%2CC0026%3A0%2CC0177%3A0%2CC0113%3A0%2CC0089%3A0%2CC0092%3A0%2CC0190%3A0%2CC0166%3A0%2CC0222%3A0%2CC0223%3A0%2CC0231%3A0%2CC0263%3A0%2CC0004%3A0%2CC0022%3A0%2CC0054%3A0%2CC0179%3A0%2CC0146%3A0%2CC0052%3A0%2CC0034%3A0%2CC0063%3A0%2CC0157%3A0%2CC0003%3A0%2CC0212%3A0%2CC0081%3A0%2CC0051%3A0%2CC0136%3A0%2CC0135%3A0%2CC0007%3A0%2CV2STACK42%3A0&geolocation=FR%3BPAC&AwaitingReconsent=false',
    '__cfwaitingroom_www': '',
    'carrefour_counter': '1743686610729%7C137739566618166%7Cp0%7Ce0%7Cv1%7Cc254.41%7CServerSide',
    '__cf_bm': 'NyOc.0a7rFqFBOFZxwskWB_YqSbBfJECQ4xhSmBzDH4-1743686605-1.0.1.1-sKUvMEJ11VU3bu1YzfxcPUjZe2z5g8ncLBmGWJrcdbCzKuC6eOKaie_YN_1Jni0yRyMvFRhAv7hgIqZB7lgs3dYfbu01CsVu7qsSIhHXfXA',
}

headers = {
    'accept': 'application/json, text/plain, */*',
    'accept-language': 'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7',
    'priority': 'u=1, i',
    'referer': 'https://www.carrefour.fr/r/viandes-et-poissons/poissonnerie',
    'sec-ch-ua': '"Chromium";v="134", "Not:A-Brand";v="24", "Google Chrome";v="134"',
    'sec-ch-ua-arch': '"x86"',
    'sec-ch-ua-bitness': '"64"',
    'sec-ch-ua-full-version': '"134.0.6998.178"',
    'sec-ch-ua-full-version-list': '"Chromium";v="134.0.6998.178", "Not:A-Brand";v="24.0.0.0", "Google Chrome";v="134.0.6998.178"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-model': '""',
    'sec-ch-ua-platform': '"Windows"',
    'sec-ch-ua-platform-version': '"10.0.0"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest',
    # 'cookie': 'tc_cj_v2_cmp=; tc_cj_v2_med=; tc_ts=40; FRONTONE_ONLINE=1745247464; FRONTONE_SESSION_ID=fe0e97616cc0dc73679f62b16fa7c577b2d86018; CAID=202503221557457366701354; OptanonAlertBoxClosed=2025-03-22T14:57:49.848Z; eupubconsent-v2=CQOq1pgQOq1pgAcABBENBiFwAAAAAAAAAChQAAAAAAChIAYAygF5gTAHQAwBlALzAmAOAAgSEJQAQF5lIAYAygF5gTAA.YAAAAAAAAAAA; OneTrustGroupsConsent=%2CC0048%2CC0001%2C; FRONTONE_SESSID=uim3dg95re0gh6j1p6jnc30adj; sap-closed=1; tc_eff_params=; tc_ab=1; aaaaaaaaa944fac35b02f4d9a99619247b88ad463_cs=; cf_clearance=ejQ63F_1s06TNPQ7ARE1hYyun_ngF5WZ4HM.KyqVwWY-1743685936-1.2.1.1-W8hQPeNII6esIHjsPj7mz__mVqGsfGX.4Em.5k5VJq17i1ECsSPwpJ9PbKaIEPYtAZ7IeajQ7BgsgU7SCaKU9c.9eU2rdBxHL_OpYOiShsFZratV5nPQ7ngFo1nSSNapiTi209Z3bQhHwElT_XXZmtY6z6FGVJIGKiWBs7wsB335RvPO1ZNg8M1SvxNOi1w0w4xyCl73oLfq671G3mvr_gs40kp_YzX9pZWwsppILZK9SML.CWqDdrCu_2toPyZjHKCi3ol8gISXaqo.CLZxoIPRrfCq32k2TZuSP7t3XwrPKueKH4h8oeWIsf.DUTBxLb2HLnlrZiv7mV19FR2OrR_14UUtNod97D0.b8ueJQ0S8WyY5__K4MeuWQgvtYay; tc_cj_v2=%5Ecl_%5Dny%5B%5D%5D_mmZZZZZZKQNLPOONPSSJKZZZ%5D777m_iZZZ%2C2%7B%29%2FZZZKQNMLOJOSNKMQZZZ%5D777%5Ecl_%5Dny%5B%5D%5D_mmZZZZZZKQNMPRPOSSQQKZZZ%5D; pageCounterCrfOne=30; OptanonConsent=isGpcEnabled=0&datestamp=Thu+Apr+03+2025+15%3A23%3A21+GMT%2B0200+(heure+d%E2%80%99%C3%A9t%C3%A9+d%E2%80%99Europe+centrale)&version=202310.2.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=92a3e744-b25d-4e54-a023-8625a83bd02f&interactionCount=1&landingPath=NotLandingPage&groups=C0048%3A1%2CC0001%3A1%2CC0040%3A0%2CC0032%3A0%2CC0025%3A0%2CC0020%3A0%2CC0037%3A0%2CC0039%3A0%2CC0036%3A0%2CC0041%3A0%2CC0042%3A0%2CC0044%3A0%2CC0043%3A0%2CC0045%3A0%2CC0049%3A0%2CC0047%3A0%2CC0023%3A0%2CC0056%3A0%2CC0038%3A0%2CC0082%3A0%2CC0026%3A0%2CC0177%3A0%2CC0113%3A0%2CC0089%3A0%2CC0092%3A0%2CC0190%3A0%2CC0166%3A0%2CC0222%3A0%2CC0223%3A0%2CC0231%3A0%2CC0263%3A0%2CC0004%3A0%2CC0022%3A0%2CC0054%3A0%2CC0179%3A0%2CC0146%3A0%2CC0052%3A0%2CC0034%3A0%2CC0063%3A0%2CC0157%3A0%2CC0003%3A0%2CC0212%3A0%2CC0081%3A0%2CC0051%3A0%2CC0136%3A0%2CC0135%3A0%2CC0007%3A0%2CV2STACK42%3A0&geolocation=FR%3BPAC&AwaitingReconsent=false; __cfwaitingroom_www=; carrefour_counter=1743686610729%7C137739566618166%7Cp0%7Ce0%7Cv1%7Cc254.41%7CServerSide; __cf_bm=NyOc.0a7rFqFBOFZxwskWB_YqSbBfJECQ4xhSmBzDH4-1743686605-1.0.1.1-sKUvMEJ11VU3bu1YzfxcPUjZe2z5g8ncLBmGWJrcdbCzKuC6eOKaie_YN_1Jni0yRyMvFRhAv7hgIqZB7lgs3dYfbu01CsVu7qsSIhHXfXA',
}

params = {
    'noRedirect': '0',
    'page': '2',
}

response = requests.get(
    'https://www.carrefour.fr/r/viandes-et-poissons/poissonnerie',
    params=params,
    cookies=cookies,
    headers=headers,
)

# %%
#Loop to get all the page
import time
response_mer_1 = []
for x in range(1,13):
    params = {
    'noRedirect': '0',
    'page': str(x) ,
    }
    response = requests.get(
    'https://www.carrefour.fr/r/viandes-et-poissons/poissonnerie',
    params=params,
    cookies=cookies,
    headers=headers,
    )
    response_mer_1.append(response.json())
    time.sleep(2)

print(response_mer_1)
# Out:
# [{'data': [{'type': 'product', 'id': 'product-3523680495470', 'attributes': {'ean': '3523680495470', 'cdbase': '7665863', 'title': 'Filet de saumon ASC CARREFOUR LE MARCHE', 'brand': None, 'slug': 'filet-de-saumon-asc-carrefour-le-marche', 'businessType': 'food', 'offerServiceId': '0261-150-6', 'uri': 'ramadan/plats/plats', 'categories': [{'id': '1921', 'code': 'R00F00SF00', 'slug': 'viandes-et-poissons', 'label': 'Viandes et Poissons', 'uri': 'viandes-et-poissons', 'type': 'RAYON', 'level': 1, 'sellerId': None}, {'id': '1938', 'code': 'R00F00SF00', 'slug': 'poissonnerie', 'label': 'Poissonnerie', 'uri': 'viandes-et-poissons/poissonnerie', 'type': 'RAYON', 'level': 2, 'sellerId': None}, {'id': '1941', 'code': 'R00F00SF00', 'slug': 'filets-et-paves', 'label': 'Filets et pavés', 'uri': 'viandes-et-poissons/poissonnerie/filets-et-paves', 'type': 'RAYON', 'level': 3, 'sellerId': None}, {'id': '28431', 'code': 'R00F00SF00', 'slug': 'saumons-et-truites', 'label': 'Saumons et Truites', 'uri': 'viandes-et-poissons/poissonnerie/filets-et-paves/saumons-et-truites', 'type': 'RAYON', 'level': 4, 'sellerId': None}], 'topCategoryName': 'Viandes et Poissons', 'images': {'formats': {'largest': '540x540', 'common': ['43x43', '200x200', '540x540', '1500x1500']}, 'paths': ['https://media.carrefour.fr/medias/9a7cdebc9c4638a889d1352433ae1a15/p_FORMAT/3523680495470-0.jpg']}, 'isDonation': False, 'isBestSeller': False, 'traceability': None, 'keyFeatures': [], 'moreOffers': {'count': 0, 'bestOfferId': None, 'bestOfferPrice': None, 'hasNonFoodDeliveryOffer': False, 'isRexEligible': False, 'withdrawalDelivery': {'exists': False, 'expressWithdrawalEligibility': {'global': False, 'inCurrentStore': False}}, 'hasCarrefourPlus': False}, 'offers': {'3523680495470': {'0261-150-6': {'type': 'offer', 'subType': 'carrefour', 'id': '0261-150-6', 'attributes': {'availability': {'indispensable': False, 'purchasable': True, 'stopped': False, 'suspended': False, 'suspensionReason': None, 'hasLowQuantity': False}, 'preorder': None, 'price': {'price': 12.99, 'taxMessage': '', 'unitOfMeasure': 'KG', 'perUnit': 20.78, 'perUnitLabel': '20.78 € / KG'}, 'ordering': {'min': 1, 'step': 1, 'max': 50}, 'offerServiceId': '0261-150-6', 'highlightLabel': {'type': 'promotion', 'key': 'product.label.promotion'}, 'freshness': {'value': 1, 'period': 'day'}, 'marketplace': None, 'ean': '3523680495470', 'promotion': {'type': 'promo', 'label': 'PROMO : 20%', 'message': 'promotion.promo', 'isLoyalty': False, 'isPromo': True, 'isPrixBarre': True, 'isPrixForce': False, 'isVuEnCatalogue': False, 'isCrescendo': False, 'isClubActive': False, 'promotionParts': [], 'progression': {'current': None, 'total': None, 'completed': None}, 'bestQuantity': 1, 'messageArgs': {'quantity': 1, 'discountAmount': 2.6, 'discountedPrice': 10.39, 'initialPrice': 12.99, 'discountedPricePerUnit': None, 'startDate': '2025-04-01T00:00:00+0200', 'endDate': '2025-04-07T23:59:00+0200'}, 'promoStartDate': '2025-04-01T00:00:00+0200', 'promoEndDate': '2025-04-07T23:59:00+0200', 'mixableGtins': [], 'isPriceAlreadyDiscounted': True, 'mandateId': ['1120250000023945'], 'isDisplayed': True}, 'promotions': [{'type': 'promo', 'label': 'PROMO : 20%', 'message': 'promotion.promo', 'isLoyalty': False, 'isPromo': True, 'isPrixBarre': True, 'isPrixForce': False, 'isVuEnCatalogue': False, 'isCrescendo': False, 'isClubActive': False, 'promotionParts': [], 'progression': {'current': None, 'total': None, 'completed': None}, 'bestQuantity': 1, 'messageArgs': {'quantity': 1, 'discountAmount': 2.6, 'discountedPrice': 10.39, 'initialPrice': 12.99, 'discountedPricePerUnit': None, 'startDate': '2025-04-01T00:00:00+0200', 'endDate': '2025-04-07T23:59:00+0200'}, 'promoStartDate': '2025-04-01T00:00:00+0200', 'promoEndDate': '2025-04-07T23:59:00+0200', 'mixableGtins': [], 'isPriceAlreadyDiscounted': True, 'mandateId': ['1120250000023945'], 'isDisplayed': True}], 'variableWeight': False, 'isRexEligible': False, 'expressWithdrawalEligibility': {'glob ...

# %%
#Get the relevant columns and extract the price/kg
import pandas as pd

df_mer_1 = pd.DataFrame()  # Initialize an empty DataFrame

for item in response_mer_1:  # Loop through each JSON object
    try:
        # Ensure 'data' exists and extract it safely
        df_data = pd.DataFrame(item.get('data', []))  
        
        # Ensure 'attributes' exists before normalizing
        if 'attributes' in df_data:
            df_product = pd.json_normalize(df_data['attributes'])
        else:
            print("Warning: 'attributes' key missing in data.")
            continue  # Skip this item if 'attributes' is missing

        price_unit = []
        for x in df_product.get("ean", []):  # Use .get() to avoid KeyError
            try:
                ean_index = df_product[df_product["ean"] == x].index[0]
                price_column = f"offers.{x}.0261-150-6.attributes.price.perUnitLabel"

                # Check if the column exists before accessing
                if price_column in df_product.columns:
                    price_unit_variable = df_product.loc[ean_index, price_column]
                else:
                    price_unit_variable = None  # Default if price column missing

                price_unit.append(price_unit_variable)
            except Exception as e:
                print(f"Error processing EAN {x}: {e}")
                price_unit.append(None)  # Append None for failed entries

        price = []
        for x in df_product.get("ean", []):  # Use .get() to avoid KeyError
            try:
                ean_index = df_product[df_product["ean"] == x].index[0]
                price_column = f"offers.{x}.0261-150-6.attributes.price.price"

                # Check if the column exists before accessing
                if price_column in df_product.columns:
                    price_variable = df_product.loc[ean_index, price_column]
                else:
                    price_variable = None  # Default if price column missing

                price.append(price_variable)
            except Exception as e:
                print(f"Error processing EAN {x}: {e}")
                price.append(None)  # Append None for failed entries

        # Select relevant columns safely
        try:
            df_final = df_product[["title", "slug", "topCategoryName", "origin"]].copy()
        except KeyError as e:
            print(f"Missing column error: {e}")
            continue  # Skip this item if required columns are missing

        # Add price_unit column
        df_final["price_unit"] = price_unit
        df_final["price"] = price

        # Concatenate safely
        df_mer_1 = pd.concat([df_mer_1, df_final], ignore_index=True)

    except Exception as e:
        print(f"Error processing item: {e}")
        continue  # Skip the item on error

# Print the final DataFrame
print(df_mer_1)
# Out:
#                                                  title  \
# 0              Filet de saumon ASC CARREFOUR LE MARCHE
# 1    Filets de colin d'Alaska MSC panés  CARREFOUR ...
# 2                             Morue Séchée Prédécoupée
# 3    Crevettes décortiquées nature CARREFOUR LE MARCHE
# 4     Crevettes entières cuite ASC CARREFOUR LE MARCHE
# ..                                                 ...
# 329  Huîtres Marennes Oléron N°3 IGP Label Rouge PO...
# 330                             Huîtres plates grosses
# 331                        Huîtres plates très grosses
# 332                                 Noix de St-Jacques
# 333  Pavé de saumon avec peau sans arêtes ASC  FILI...
#
#                                                   slug      topCategoryName  \
# 0              filet-de-saumon-asc-carrefour-le-marche  Viandes et Poissons
# 1    filets-de-colin-d-alaska-msc-panes-carrefour-l...  Viandes et Poissons
# 2                             morue-sechee-predecoupee  Viandes et Poissons
# 3    crevettes-decortiquees-nature-carrefour-le-marche  Viandes et Poissons
# 4     crevettes-entieres-cuite-asc-carrefour-le-marche  Viandes et Poissons
# ..                                                 ...                  ...
# 329  huitres-marennes-oleron-n03-igp-label-rouge-po...  Viandes et Poissons
# 330                             huitres-plates-grosses  Viandes et Poissons
# 331                        huitres-plates-tres-grosses  Viandes et Poissons
# 332                                 noix-de-st-jacques  Viandes et Poissons
# 333  pave-de-saumon-avec-peau-sans-aretes-asc-filie...  Viandes et Poissons
#
#                   origin    price_unit  price
# 0                NORVÈGE  20.78 € / KG  12.99
# 1                 FRANCE  14.50 € / KG   3.19
# 2    ATLANTIQUE NORD EST  17.99 € / KG   7.19
# 3                 FRANCE  35.90 € / KG   3.59
# 4               EQUATEUR   9.98 € / KG   4.99
# ..                   ...           ...    ...
# 329               FRANCE  16.50 € / KG  32.99
# 330               FRANCE  21.10 € / KG  18.99
# 331               FRANCE  22.60 € / KG  25.99
# 332               ECOSSE   7.70 € / KG   1.54
# 333              NORVÈGE  27.06 € / KG  12.99
#
# [334 rows x 6 columns]

# %%
df_mer_1.to_csv("poisson.csv", index=False)
