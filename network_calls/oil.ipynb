# %%
import requests

cookies = {
    'tc_cj_v2_cmp': '',
    'tc_cj_v2_med': '',
    'tc_ts': '40',
    'FRONTONE_ONLINE': '1745247464',
    'FRONTONE_SESSION_ID': 'fe0e97616cc0dc73679f62b16fa7c577b2d86018',
    'CAID': '202503221557457366701354',
    'OptanonAlertBoxClosed': '2025-03-22T14:57:49.848Z',
    'eupubconsent-v2': 'CQOq1pgQOq1pgAcABBENBiFwAAAAAAAAAChQAAAAAAChIAYAygF5gTAHQAwBlALzAmAOAAgSEJQAQF5lIAYAygF5gTAA.YAAAAAAAAAAA',
    'OneTrustGroupsConsent': '%2CC0048%2CC0001%2C',
    'FRONTONE_SESSID': 'uim3dg95re0gh6j1p6jnc30adj',
    'sap-closed': '1',
    'tc_eff_params': '',
    'tc_ab': '1',
    'aaaaaaaaa944fac35b02f4d9a99619247b88ad463_cs': '',
    'cf_clearance': 'ejQ63F_1s06TNPQ7ARE1hYyun_ngF5WZ4HM.KyqVwWY-1743685936-1.2.1.1-W8hQPeNII6esIHjsPj7mz__mVqGsfGX.4Em.5k5VJq17i1ECsSPwpJ9PbKaIEPYtAZ7IeajQ7BgsgU7SCaKU9c.9eU2rdBxHL_OpYOiShsFZratV5nPQ7ngFo1nSSNapiTi209Z3bQhHwElT_XXZmtY6z6FGVJIGKiWBs7wsB335RvPO1ZNg8M1SvxNOi1w0w4xyCl73oLfq671G3mvr_gs40kp_YzX9pZWwsppILZK9SML.CWqDdrCu_2toPyZjHKCi3ol8gISXaqo.CLZxoIPRrfCq32k2TZuSP7t3XwrPKueKH4h8oeWIsf.DUTBxLb2HLnlrZiv7mV19FR2OrR_14UUtNod97D0.b8ueJQ0S8WyY5__K4MeuWQgvtYay',
    'tc_cj_v2': '%5Ecl_%5Dny%5B%5D%5D_mmZZZZZZKQNLPOONPSSJKZZZ%5D777m_iZZZ%2C2%7B%29%2FZZZKQNMLOJOSNKMQZZZ%5D777%5Ecl_%5Dny%5B%5D%5D_mmZZZZZZKQNMPRPOSSQQKZZZ%5D',
    'pageCounterCrfOne': '30',
    'OptanonConsent': 'isGpcEnabled=0&datestamp=Thu+Apr+03+2025+15%3A23%3A21+GMT%2B0200+(heure+d%E2%80%99%C3%A9t%C3%A9+d%E2%80%99Europe+centrale)&version=202310.2.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=92a3e744-b25d-4e54-a023-8625a83bd02f&interactionCount=1&landingPath=NotLandingPage&groups=C0048%3A1%2CC0001%3A1%2CC0040%3A0%2CC0032%3A0%2CC0025%3A0%2CC0020%3A0%2CC0037%3A0%2CC0039%3A0%2CC0036%3A0%2CC0041%3A0%2CC0042%3A0%2CC0044%3A0%2CC0043%3A0%2CC0045%3A0%2CC0049%3A0%2CC0047%3A0%2CC0023%3A0%2CC0056%3A0%2CC0038%3A0%2CC0082%3A0%2CC0026%3A0%2CC0177%3A0%2CC0113%3A0%2CC0089%3A0%2CC0092%3A0%2CC0190%3A0%2CC0166%3A0%2CC0222%3A0%2CC0223%3A0%2CC0231%3A0%2CC0263%3A0%2CC0004%3A0%2CC0022%3A0%2CC0054%3A0%2CC0179%3A0%2CC0146%3A0%2CC0052%3A0%2CC0034%3A0%2CC0063%3A0%2CC0157%3A0%2CC0003%3A0%2CC0212%3A0%2CC0081%3A0%2CC0051%3A0%2CC0136%3A0%2CC0135%3A0%2CC0007%3A0%2CV2STACK42%3A0&geolocation=FR%3BPAC&AwaitingReconsent=false',
    'carrefour_counter': '1743686602055%7C137739566618166%7Cp0%7Ce0%7Cv1%7Cc254.41%7CServerSide',
    '__cf_bm': 'QiFztyvFyYZmLyWMN7iLV3Jvacb.D8iajUy16r6qYuk-1743686598-1.0.1.1-HjzvT0wDgZi008.QAhU0c9Rb8wkhJDbSsaS_DMbID2J33aCA1Q6oQtmfPrv.s7gCOe5.3.zqMSTnF12CFnQuLUW2VBeNykwcBR5ZYW9MM_I',
    '__cfwaitingroom_www': '',
}

headers = {
    'accept': 'application/json, text/plain, */*',
    'accept-language': 'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7',
    'priority': 'u=1, i',
    'referer': 'https://www.carrefour.fr/r/epicerie-salee/huiles-vinaigres-et-vinaigrettes',
    'sec-ch-ua': '"Chromium";v="134", "Not:A-Brand";v="24", "Google Chrome";v="134"',
    'sec-ch-ua-arch': '"x86"',
    'sec-ch-ua-bitness': '"64"',
    'sec-ch-ua-full-version': '"134.0.6998.178"',
    'sec-ch-ua-full-version-list': '"Chromium";v="134.0.6998.178", "Not:A-Brand";v="24.0.0.0", "Google Chrome";v="134.0.6998.178"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-model': '""',
    'sec-ch-ua-platform': '"Windows"',
    'sec-ch-ua-platform-version': '"10.0.0"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest',
    # 'cookie': 'tc_cj_v2_cmp=; tc_cj_v2_med=; tc_ts=40; FRONTONE_ONLINE=1745247464; FRONTONE_SESSION_ID=fe0e97616cc0dc73679f62b16fa7c577b2d86018; CAID=202503221557457366701354; OptanonAlertBoxClosed=2025-03-22T14:57:49.848Z; eupubconsent-v2=CQOq1pgQOq1pgAcABBENBiFwAAAAAAAAAChQAAAAAAChIAYAygF5gTAHQAwBlALzAmAOAAgSEJQAQF5lIAYAygF5gTAA.YAAAAAAAAAAA; OneTrustGroupsConsent=%2CC0048%2CC0001%2C; FRONTONE_SESSID=uim3dg95re0gh6j1p6jnc30adj; sap-closed=1; tc_eff_params=; tc_ab=1; aaaaaaaaa944fac35b02f4d9a99619247b88ad463_cs=; cf_clearance=ejQ63F_1s06TNPQ7ARE1hYyun_ngF5WZ4HM.KyqVwWY-1743685936-1.2.1.1-W8hQPeNII6esIHjsPj7mz__mVqGsfGX.4Em.5k5VJq17i1ECsSPwpJ9PbKaIEPYtAZ7IeajQ7BgsgU7SCaKU9c.9eU2rdBxHL_OpYOiShsFZratV5nPQ7ngFo1nSSNapiTi209Z3bQhHwElT_XXZmtY6z6FGVJIGKiWBs7wsB335RvPO1ZNg8M1SvxNOi1w0w4xyCl73oLfq671G3mvr_gs40kp_YzX9pZWwsppILZK9SML.CWqDdrCu_2toPyZjHKCi3ol8gISXaqo.CLZxoIPRrfCq32k2TZuSP7t3XwrPKueKH4h8oeWIsf.DUTBxLb2HLnlrZiv7mV19FR2OrR_14UUtNod97D0.b8ueJQ0S8WyY5__K4MeuWQgvtYay; tc_cj_v2=%5Ecl_%5Dny%5B%5D%5D_mmZZZZZZKQNLPOONPSSJKZZZ%5D777m_iZZZ%2C2%7B%29%2FZZZKQNMLOJOSNKMQZZZ%5D777%5Ecl_%5Dny%5B%5D%5D_mmZZZZZZKQNMPRPOSSQQKZZZ%5D; pageCounterCrfOne=30; OptanonConsent=isGpcEnabled=0&datestamp=Thu+Apr+03+2025+15%3A23%3A21+GMT%2B0200+(heure+d%E2%80%99%C3%A9t%C3%A9+d%E2%80%99Europe+centrale)&version=202310.2.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=92a3e744-b25d-4e54-a023-8625a83bd02f&interactionCount=1&landingPath=NotLandingPage&groups=C0048%3A1%2CC0001%3A1%2CC0040%3A0%2CC0032%3A0%2CC0025%3A0%2CC0020%3A0%2CC0037%3A0%2CC0039%3A0%2CC0036%3A0%2CC0041%3A0%2CC0042%3A0%2CC0044%3A0%2CC0043%3A0%2CC0045%3A0%2CC0049%3A0%2CC0047%3A0%2CC0023%3A0%2CC0056%3A0%2CC0038%3A0%2CC0082%3A0%2CC0026%3A0%2CC0177%3A0%2CC0113%3A0%2CC0089%3A0%2CC0092%3A0%2CC0190%3A0%2CC0166%3A0%2CC0222%3A0%2CC0223%3A0%2CC0231%3A0%2CC0263%3A0%2CC0004%3A0%2CC0022%3A0%2CC0054%3A0%2CC0179%3A0%2CC0146%3A0%2CC0052%3A0%2CC0034%3A0%2CC0063%3A0%2CC0157%3A0%2CC0003%3A0%2CC0212%3A0%2CC0081%3A0%2CC0051%3A0%2CC0136%3A0%2CC0135%3A0%2CC0007%3A0%2CV2STACK42%3A0&geolocation=FR%3BPAC&AwaitingReconsent=false; carrefour_counter=1743686602055%7C137739566618166%7Cp0%7Ce0%7Cv1%7Cc254.41%7CServerSide; __cf_bm=QiFztyvFyYZmLyWMN7iLV3Jvacb.D8iajUy16r6qYuk-1743686598-1.0.1.1-HjzvT0wDgZi008.QAhU0c9Rb8wkhJDbSsaS_DMbID2J33aCA1Q6oQtmfPrv.s7gCOe5.3.zqMSTnF12CFnQuLUW2VBeNykwcBR5ZYW9MM_I; __cfwaitingroom_www=',
}

params = {
    'noRedirect': '0',
    'page': '2',
}

response = requests.get(
    'https://www.carrefour.fr/r/epicerie-salee/huiles-vinaigres-et-vinaigrettes',
    params=params,
    cookies=cookies,
    headers=headers,
)

# %%
#Loop to get all the page
import time
response_1 = []
for x in range(1,23):
    params = {
    'noRedirect': '0',
    'page': str(x) ,
    }
    response = requests.get(
    'https://www.carrefour.fr/r/epicerie-salee/huiles-vinaigres-et-vinaigrettes',
    params=params,
    cookies=cookies,
    headers=headers,
    )
    response_1.append(response.json())
    time.sleep(2)

print(response_1)
# Out:
# [{'data': [{'type': 'product', 'id': 'product-3270190008279', 'attributes': {'ean': '3270190008279', 'cdbase': '0843701', 'title': "Huile d'olive vierge extra CARREFOUR EXTRA", 'brand': None, 'slug': 'huile-d-olive-vierge-extra-carrefour-extra', 'businessType': 'food', 'offerServiceId': '0261-150-6', 'uri': 'epicerie-salee/huiles-vinaigres-et-vinaigrettes/huiles-dolive', 'categories': [{'id': '2112', 'code': 'R00F00SF00', 'slug': 'epicerie-salee', 'label': 'Epicerie salée', 'uri': 'epicerie-salee', 'type': 'RAYON', 'level': 1, 'sellerId': None}, {'id': '2157', 'code': 'R00F00SF00', 'slug': 'huiles-vinaigres-et-vinaigrettes', 'label': 'Huiles, Vinaigres et Vinaigrettes', 'uri': 'epicerie-salee/huiles-vinaigres-et-vinaigrettes', 'type': 'RAYON', 'level': 2, 'sellerId': None}, {'id': '2159', 'code': 'R00F00SF00', 'slug': 'huiles-dolive', 'label': "Huiles d'olive", 'uri': 'epicerie-salee/huiles-vinaigres-et-vinaigrettes/huiles-dolive', 'type': 'RAYON', 'level': 3, 'sellerId': None}], 'topCategoryName': 'Epicerie salée', 'images': {'formats': {'largest': '540x540', 'common': ['43x43', '200x200', '540x540', '1500x1500']}, 'paths': ['https://media.carrefour.fr/medias/94bc743d69b13404adcfac07b9951c6b/p_FORMAT/3270190008279-0.jpg', 'https://media.carrefour.fr/medias/cc8e209c8a18367aa1df90a2c464c033/p_FORMAT/3270190008279-7.jpg']}, 'isDonation': False, 'isBestSeller': False, 'traceability': None, 'keyFeatures': [], 'moreOffers': {'count': 0, 'bestOfferId': None, 'bestOfferPrice': None, 'hasNonFoodDeliveryOffer': False, 'isRexEligible': False, 'withdrawalDelivery': {'exists': False, 'expressWithdrawalEligibility': {'global': False, 'inCurrentStore': False}}, 'hasCarrefourPlus': False}, 'offers': {'3270190008279': {'0261-150-6': {'type': 'offer', 'subType': 'carrefour', 'id': '0261-150-6', 'attributes': {'availability': {'indispensable': False, 'purchasable': True, 'stopped': False, 'suspended': False, 'suspensionReason': None, 'hasLowQuantity': False}, 'preorder': None, 'price': {'price': 5.95, 'taxMessage': '', 'unitOfMeasure': 'L', 'perUnit': 11.9, 'perUnitLabel': '11.90 € / L'}, 'ordering': {'min': 1, 'step': 1, 'max': 50}, 'offerServiceId': '0261-150-6', 'highlightLabel': {'type': 'promotion', 'key': 'product.label.promotion'}, 'freshness': None, 'marketplace': None, 'ean': '3270190008279', 'promotion': {'type': 'ri', 'label': '2 achetés = 11,2€', 'message': 'promotion.ri', 'isLoyalty': False, 'isPromo': False, 'isPrixBarre': False, 'isPrixForce': False, 'isVuEnCatalogue': False, 'isCrescendo': False, 'isClubActive': False, 'promotionParts': [], 'progression': {'current': None, 'total': None, 'completed': None}, 'bestQuantity': 2, 'messageArgs': {'quantity': 2, 'discountAmount': 0.7, 'discountedPrice': 11.2, 'initialPrice': 11.9, 'discountedPricePerUnit': None, 'startDate': '2025-03-24T00:00:00+0100', 'endDate': '2025-04-08T23:59:00+0200'}, 'promoStartDate': '2025-03-24T00:00:00+0100', 'promoEndDate': '2025-04-08T23:59:00+0200', 'mixableGtins': [], 'isPriceAlreadyDiscounted': True, 'mandateId': ['1120250000024924'], 'isDisplayed': True}, 'promotions': [{'type': 'ri', 'label': '2 achetés = 11,2€', 'message': 'promotion.ri', 'isLoyalty': False, 'isPromo': False, 'isPrixBarre': False, 'isPrixForce': False, 'isVuEnCatalogue': False, 'isCrescendo': False, 'isClubActive': False, 'promotionParts': [], 'progression': {'current': None, 'total': None, 'completed': None}, 'bestQuantity': 2, 'messageArgs': {'quantity': 2, 'discountAmount': 0.7, 'discountedPrice': 11.2, 'initialPrice': 11.9, 'discountedPricePerUnit': None, 'startDate': '2025-03-24T00:00:00+0100', 'endDate': '2025-04-08T23:59:00+0200'}, 'promoStartDate': '2025-03-24T00:00:00+0100', 'promoEndDate': '2025-04-08T23:59:00+0200', 'mixableGtins': [], 'isPriceAlreadyDiscounted': True, 'mandateId': ['1120250000024924'], 'isDisplayed': True}], 'variableWeight': False, 'isRexEligible': False, 'expressWithdrawalEligibility': {'global': False, 'inCurrentStore': False}, 'isNonFoodDelivery': Fa ...

# %%
#Get the relevant columns and extract the price/kg
import pandas as pd

df_1 = pd.DataFrame()  # Initialize an empty DataFrame

for item in response_1:  # Loop through each JSON object
    try:
        # Ensure 'data' exists and extract it safely
        df_data = pd.DataFrame(item.get('data', []))  
        
        # Ensure 'attributes' exists before normalizing
        if 'attributes' in df_data:
            df_product = pd.json_normalize(df_data['attributes'])
        else:
            print("Warning: 'attributes' key missing in data.")
            continue  # Skip this item if 'attributes' is missing

        price_unit = []
        for x in df_product.get("ean", []):  # Use .get() to avoid KeyError
            try:
                ean_index = df_product[df_product["ean"] == x].index[0]
                price_column = f"offers.{x}.0261-150-6.attributes.price.perUnitLabel"

                # Check if the column exists before accessing
                if price_column in df_product.columns:
                    price_unit_variable = df_product.loc[ean_index, price_column]
                else:
                    price_unit_variable = None  # Default if price column missing

                price_unit.append(price_unit_variable)
            except Exception as e:
                print(f"Error processing EAN {x}: {e}")
                price_unit.append(None)  # Append None for failed entries

        price = []
        for x in df_product.get("ean", []):  # Use .get() to avoid KeyError
            try:
                ean_index = df_product[df_product["ean"] == x].index[0]
                price_column = f"offers.{x}.0261-150-6.attributes.price.price"

                # Check if the column exists before accessing
                if price_column in df_product.columns:
                    price_variable = df_product.loc[ean_index, price_column]
                else:
                    price_variable = None  # Default if price column missing

                price.append(price_variable)
            except Exception as e:
                print(f"Error processing EAN {x}: {e}")
                price.append(None)  # Append None for failed entries

        # Select relevant columns safely
        try:
            df_final = df_product[["title", "slug", "topCategoryName", "origin"]].copy()
        except KeyError as e:
            print(f"Missing column error: {e}")
            continue  # Skip this item if required columns are missing

        # Add price_unit column
        df_final["price_unit"] = price_unit
        df_final["price"] = price

        # Concatenate safely
        df_1 = pd.concat([df_1, df_final], ignore_index=True)

    except Exception as e:
        print(f"Error processing item: {e}")
        continue  # Skip the item on error

# Print the final DataFrame
print(df_1)
# Out:
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_16944\2298180388.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_1 = pd.concat([df_1, df_final], ignore_index=True)
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_16944\2298180388.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_1 = pd.concat([df_1, df_final], ignore_index=True)
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_16944\2298180388.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_1 = pd.concat([df_1, df_final], ignore_index=True)
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_16944\2298180388.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_1 = pd.concat([df_1, df_final], ignore_index=True)
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_16944\2298180388.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_1 = pd.concat([df_1, df_final], ignore_index=True)
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_16944\2298180388.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_1 = pd.concat([df_1, df_final], ignore_index=True)
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_16944\2298180388.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_1 = pd.concat([df_1, df_final], ignore_index=True)
#                                                  title  \
# 0           Huile d'olive vierge extra CARREFOUR EXTRA
# 1                    Huile d'olive vierge extra MONINI
# 2    Vinaigrette  Légère Huile de Sésame & Sauce So...
# 3                Huile de tournesol CARREFOUR CLASSIC'
# 4                             Huile de tournesol SIMPL
# ..                                                 ...
# 655      Dietisa - Vinaigre De Pomme Savildiet 750 Ml
# 656        Huile D'olive Bio Extra Vierge Non Filtrée
# 657  Huile Olive Extra Vierge Bio - Infusée À L'ail...
# 658  Huile Olive Extra Vierge Bio - Infusée À L'ora...
# 659  Huile Olive Extra Vierge Bio - Infusée À L'ail...
#
#                                                   slug topCategoryName  \
# 0           huile-d-olive-vierge-extra-carrefour-extra  Epicerie salée
# 1                    huile-d-olive-vierge-extra-monini  Epicerie salée
# 2    vinaigrette-legere-huile-de-sesame-sauce-soja-...  Epicerie salée
# 3                 huile-de-tournesol-carrefour-classic  Epicerie salée
# 4                             huile-de-tournesol-simpl  Epicerie salée
# ..                                                 ...             ...
# 655         dietisa-vinaigre-de-pomme-savildiet-750-ml  Epicerie salée
# 656         huile-d-olive-bio-extra-vierge-non-filtree  Epicerie salée
# 657  huile-olive-extra-vierge-bio-infusee-a-l-ail-e...  Epicerie salée
# 658  huile-olive-extra-vierge-bio-infusee-a-l-orang...  Epicerie salée
# 659  huile-olive-extra-vierge-bio-infusee-a-l-ail-noir  Epicerie salée
#
#                origin   price_unit  price
# 0    UNION EUROPEENNE  11.90 € / L   5.95
# 1              ITALIE  17.19 € / L  12.89
# 2                       7.75 € / L   2.79
# 3                       1.99 € / L   1.99
# 4                       1.79 € / L   1.79
# ..                ...          ...    ...
# 655           ESPAGNE         None    NaN
# 656           ESPAGNE         None    NaN
# 657           ESPAGNE         None    NaN
# 658           ESPAGNE         None    NaN
# 659           ESPAGNE         None    NaN
#
# [660 rows x 6 columns]
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_16944\2298180388.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_1 = pd.concat([df_1, df_final], ignore_index=True)
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_16944\2298180388.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_1 = pd.concat([df_1, df_final], ignore_index=True)

# %%
df_1.to_csv("oil.csv", index=False)
