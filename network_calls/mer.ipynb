# %%
import requests

cookies = {
    'tc_cj_v2_cmp': '',
    'tc_cj_v2_med': '',
    'tc_ts': '40',
    'FRONTONE_ONLINE': '1745247464',
    'FRONTONE_SESSION_ID': 'fe0e97616cc0dc73679f62b16fa7c577b2d86018',
    'CAID': '202503221557457366701354',
    'OptanonAlertBoxClosed': '2025-03-22T14:57:49.848Z',
    'eupubconsent-v2': 'CQOq1pgQOq1pgAcABBENBiFwAAAAAAAAAChQAAAAAAChIAYAygF5gTAHQAwBlALzAmAOAAgSEJQAQF5lIAYAygF5gTAA.YAAAAAAAAAAA',
    'OneTrustGroupsConsent': '%2CC0048%2CC0001%2C',
    'FRONTONE_SESSID': 'uim3dg95re0gh6j1p6jnc30adj',
    'sap-closed': '1',
    'tc_eff_params': '',
    'tc_ab': '1',
    'aaaaaaaaa944fac35b02f4d9a99619247b88ad463_cs': '',
    'cf_clearance': 'ejQ63F_1s06TNPQ7ARE1hYyun_ngF5WZ4HM.KyqVwWY-1743685936-1.2.1.1-W8hQPeNII6esIHjsPj7mz__mVqGsfGX.4Em.5k5VJq17i1ECsSPwpJ9PbKaIEPYtAZ7IeajQ7BgsgU7SCaKU9c.9eU2rdBxHL_OpYOiShsFZratV5nPQ7ngFo1nSSNapiTi209Z3bQhHwElT_XXZmtY6z6FGVJIGKiWBs7wsB335RvPO1ZNg8M1SvxNOi1w0w4xyCl73oLfq671G3mvr_gs40kp_YzX9pZWwsppILZK9SML.CWqDdrCu_2toPyZjHKCi3ol8gISXaqo.CLZxoIPRrfCq32k2TZuSP7t3XwrPKueKH4h8oeWIsf.DUTBxLb2HLnlrZiv7mV19FR2OrR_14UUtNod97D0.b8ueJQ0S8WyY5__K4MeuWQgvtYay',
    'tc_cj_v2': '%5Ecl_%5Dny%5B%5D%5D_mmZZZZZZKQNLPOONPSSJKZZZ%5D777m_iZZZ%2C2%7B%29%2FZZZKQNMLOJOSNKMQZZZ%5D777%5Ecl_%5Dny%5B%5D%5D_mmZZZZZZKQNMPRPKPKQJNZZZ%5D',
    'pageCounterCrfOne': '27',
    'OptanonConsent': 'isGpcEnabled=0&datestamp=Thu+Apr+03+2025+15%3A16%3A02+GMT%2B0200+(heure+d%E2%80%99%C3%A9t%C3%A9+d%E2%80%99Europe+centrale)&version=202310.2.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=92a3e744-b25d-4e54-a023-8625a83bd02f&interactionCount=1&landingPath=NotLandingPage&groups=C0048%3A1%2CC0001%3A1%2CC0040%3A0%2CC0032%3A0%2CC0025%3A0%2CC0020%3A0%2CC0037%3A0%2CC0039%3A0%2CC0036%3A0%2CC0041%3A0%2CC0042%3A0%2CC0044%3A0%2CC0043%3A0%2CC0045%3A0%2CC0049%3A0%2CC0047%3A0%2CC0023%3A0%2CC0056%3A0%2CC0038%3A0%2CC0082%3A0%2CC0026%3A0%2CC0177%3A0%2CC0113%3A0%2CC0089%3A0%2CC0092%3A0%2CC0190%3A0%2CC0166%3A0%2CC0222%3A0%2CC0223%3A0%2CC0231%3A0%2CC0263%3A0%2CC0004%3A0%2CC0022%3A0%2CC0054%3A0%2CC0179%3A0%2CC0146%3A0%2CC0052%3A0%2CC0034%3A0%2CC0063%3A0%2CC0157%3A0%2CC0003%3A0%2CC0212%3A0%2CC0081%3A0%2CC0051%3A0%2CC0136%3A0%2CC0135%3A0%2CC0007%3A0%2CV2STACK42%3A0&geolocation=FR%3BPAC&AwaitingReconsent=false',
    'carrefour_counter': '1743686163079%7C137739566618166%7Cp0%7Ce0%7Cv1%7Cc254.41%7CServerSide',
    '__cf_bm': 't7FvOkL2pcHNqvJPazLfqklEEv3ysWXH6N1nrJ6E3ew-1743686159-1.0.1.1-qDDTqNumaCdovUaNQk2OHYkqYOVA0uG4A66G0tVGoHYM9JT9rzYOZN3lEPs5yQa77Q_BhJaT5FdIYKecLr_rffLzMGSeoYVJ0FoGOPnNwYs',
    '__cfwaitingroom_www': '',
}

headers = {
    'accept': 'application/json, text/plain, */*',
    'accept-language': 'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7',
    'priority': 'u=1, i',
    'referer': 'https://www.carrefour.fr/r/viandes-et-poissons/traiteur-mer',
    'sec-ch-ua': '"Chromium";v="134", "Not:A-Brand";v="24", "Google Chrome";v="134"',
    'sec-ch-ua-arch': '"x86"',
    'sec-ch-ua-bitness': '"64"',
    'sec-ch-ua-full-version': '"134.0.6998.178"',
    'sec-ch-ua-full-version-list': '"Chromium";v="134.0.6998.178", "Not:A-Brand";v="24.0.0.0", "Google Chrome";v="134.0.6998.178"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-model': '""',
    'sec-ch-ua-platform': '"Windows"',
    'sec-ch-ua-platform-version': '"10.0.0"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest',
    # 'cookie': 'tc_cj_v2_cmp=; tc_cj_v2_med=; tc_ts=40; FRONTONE_ONLINE=1745247464; FRONTONE_SESSION_ID=fe0e97616cc0dc73679f62b16fa7c577b2d86018; CAID=202503221557457366701354; OptanonAlertBoxClosed=2025-03-22T14:57:49.848Z; eupubconsent-v2=CQOq1pgQOq1pgAcABBENBiFwAAAAAAAAAChQAAAAAAChIAYAygF5gTAHQAwBlALzAmAOAAgSEJQAQF5lIAYAygF5gTAA.YAAAAAAAAAAA; OneTrustGroupsConsent=%2CC0048%2CC0001%2C; FRONTONE_SESSID=uim3dg95re0gh6j1p6jnc30adj; sap-closed=1; tc_eff_params=; tc_ab=1; aaaaaaaaa944fac35b02f4d9a99619247b88ad463_cs=; cf_clearance=ejQ63F_1s06TNPQ7ARE1hYyun_ngF5WZ4HM.KyqVwWY-1743685936-1.2.1.1-W8hQPeNII6esIHjsPj7mz__mVqGsfGX.4Em.5k5VJq17i1ECsSPwpJ9PbKaIEPYtAZ7IeajQ7BgsgU7SCaKU9c.9eU2rdBxHL_OpYOiShsFZratV5nPQ7ngFo1nSSNapiTi209Z3bQhHwElT_XXZmtY6z6FGVJIGKiWBs7wsB335RvPO1ZNg8M1SvxNOi1w0w4xyCl73oLfq671G3mvr_gs40kp_YzX9pZWwsppILZK9SML.CWqDdrCu_2toPyZjHKCi3ol8gISXaqo.CLZxoIPRrfCq32k2TZuSP7t3XwrPKueKH4h8oeWIsf.DUTBxLb2HLnlrZiv7mV19FR2OrR_14UUtNod97D0.b8ueJQ0S8WyY5__K4MeuWQgvtYay; tc_cj_v2=%5Ecl_%5Dny%5B%5D%5D_mmZZZZZZKQNLPOONPSSJKZZZ%5D777m_iZZZ%2C2%7B%29%2FZZZKQNMLOJOSNKMQZZZ%5D777%5Ecl_%5Dny%5B%5D%5D_mmZZZZZZKQNMPRPKPKQJNZZZ%5D; pageCounterCrfOne=27; OptanonConsent=isGpcEnabled=0&datestamp=Thu+Apr+03+2025+15%3A16%3A02+GMT%2B0200+(heure+d%E2%80%99%C3%A9t%C3%A9+d%E2%80%99Europe+centrale)&version=202310.2.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=92a3e744-b25d-4e54-a023-8625a83bd02f&interactionCount=1&landingPath=NotLandingPage&groups=C0048%3A1%2CC0001%3A1%2CC0040%3A0%2CC0032%3A0%2CC0025%3A0%2CC0020%3A0%2CC0037%3A0%2CC0039%3A0%2CC0036%3A0%2CC0041%3A0%2CC0042%3A0%2CC0044%3A0%2CC0043%3A0%2CC0045%3A0%2CC0049%3A0%2CC0047%3A0%2CC0023%3A0%2CC0056%3A0%2CC0038%3A0%2CC0082%3A0%2CC0026%3A0%2CC0177%3A0%2CC0113%3A0%2CC0089%3A0%2CC0092%3A0%2CC0190%3A0%2CC0166%3A0%2CC0222%3A0%2CC0223%3A0%2CC0231%3A0%2CC0263%3A0%2CC0004%3A0%2CC0022%3A0%2CC0054%3A0%2CC0179%3A0%2CC0146%3A0%2CC0052%3A0%2CC0034%3A0%2CC0063%3A0%2CC0157%3A0%2CC0003%3A0%2CC0212%3A0%2CC0081%3A0%2CC0051%3A0%2CC0136%3A0%2CC0135%3A0%2CC0007%3A0%2CV2STACK42%3A0&geolocation=FR%3BPAC&AwaitingReconsent=false; carrefour_counter=1743686163079%7C137739566618166%7Cp0%7Ce0%7Cv1%7Cc254.41%7CServerSide; __cf_bm=t7FvOkL2pcHNqvJPazLfqklEEv3ysWXH6N1nrJ6E3ew-1743686159-1.0.1.1-qDDTqNumaCdovUaNQk2OHYkqYOVA0uG4A66G0tVGoHYM9JT9rzYOZN3lEPs5yQa77Q_BhJaT5FdIYKecLr_rffLzMGSeoYVJ0FoGOPnNwYs; __cfwaitingroom_www=',
}

params = {
    'noRedirect': '0',
    'page': '2',
}

response = requests.get(
    'https://www.carrefour.fr/r/viandes-et-poissons/traiteur-mer',
    params=params,
    cookies=cookies,
    headers=headers,
)

# %%
#Loop to get all the page
import time
response_mer_1 = []
for x in range(1,13):
    params = {
    'noRedirect': '0',
    'page': str(x) ,
    }
    response = requests.get(
    'https://www.carrefour.fr/r/viandes-et-poissons/traiteur-mer',
    params=params,
    cookies=cookies,
    headers=headers,
    )
    response_mer_1.append(response.json())
    time.sleep(2)

print(response_mer_1)
# Out:
# [{'data': [{'type': 'product', 'id': 'product-3276170011840', 'attributes': {'ean': '3276170011840', 'cdbase': '5812463', 'title': 'Surimi bâtonnets saveur CORAYA', 'brand': None, 'slug': 'surimi-batonnets-saveur-coraya', 'businessType': 'food', 'offerServiceId': '0261-150-6', 'uri': 'viandes-et-poissons/traiteur-mer/surimis', 'categories': [{'id': '1921', 'code': 'R00F00SF00', 'slug': 'viandes-et-poissons', 'label': 'Viandes et Poissons', 'uri': 'viandes-et-poissons', 'type': 'RAYON', 'level': 1, 'sellerId': None}, {'id': '28418', 'code': 'R00F00SF00', 'slug': 'traiteur-mer', 'label': 'Traiteur de la mer', 'uri': 'viandes-et-poissons/traiteur-mer', 'type': 'RAYON', 'level': 2, 'sellerId': None}, {'id': '28425', 'code': 'R00F00SF00', 'slug': 'surimis', 'label': 'Surimis', 'uri': 'viandes-et-poissons/traiteur-mer/surimis', 'type': 'RAYON', 'level': 3, 'sellerId': None}], 'topCategoryName': 'Viandes et Poissons', 'images': {'formats': {'largest': '540x540', 'common': ['43x43', '200x200', '540x540', '1500x1500']}, 'paths': ['https://media.carrefour.fr/medias/1d714c3af3663aba9969de21b140c36a/p_FORMAT/3276170011840-photosite-20160624-104132-0.jpg']}, 'isDonation': False, 'isBestSeller': False, 'traceability': None, 'keyFeatures': [], 'moreOffers': {'count': 0, 'bestOfferId': None, 'bestOfferPrice': None, 'hasNonFoodDeliveryOffer': False, 'isRexEligible': False, 'withdrawalDelivery': {'exists': False, 'expressWithdrawalEligibility': {'global': False, 'inCurrentStore': False}}, 'hasCarrefourPlus': False}, 'offers': {'3276170011840': {'0261-150-6': {'type': 'offer', 'subType': 'carrefour', 'id': '0261-150-6', 'attributes': {'availability': {'indispensable': False, 'purchasable': True, 'stopped': False, 'suspended': False, 'suspensionReason': None, 'hasLowQuantity': False}, 'preorder': None, 'price': {'price': 3.59, 'taxMessage': '', 'unitOfMeasure': 'KG', 'perUnit': 7.98, 'perUnitLabel': '7.98 € / KG'}, 'ordering': {'min': 1, 'step': 1, 'max': 50}, 'offerServiceId': '0261-150-6', 'highlightLabel': {'type': 'promotion', 'key': 'product.label.promotion'}, 'freshness': {'value': 2, 'period': 'day'}, 'marketplace': None, 'ean': '3276170011840', 'promotion': {'type': 'ri', 'label': 'Le 2ème à -60%', 'message': 'promotion.ri', 'isLoyalty': False, 'isPromo': False, 'isPrixBarre': False, 'isPrixForce': False, 'isVuEnCatalogue': False, 'isCrescendo': False, 'isClubActive': False, 'promotionParts': [], 'progression': {'current': None, 'total': None, 'completed': None}, 'bestQuantity': 2, 'messageArgs': {'quantity': 2, 'discountAmount': 2.15, 'discountedPrice': 5.03, 'initialPrice': 7.18, 'discountedPricePerUnit': None, 'startDate': '2025-03-31T00:00:00+0200', 'endDate': '2025-04-28T23:59:00+0200'}, 'promoStartDate': '2025-03-31T00:00:00+0200', 'promoEndDate': '2025-04-28T23:59:00+0200', 'mixableGtins': [], 'isPriceAlreadyDiscounted': True, 'mandateId': ['1120250000024449'], 'isDisplayed': True}, 'promotions': [{'type': 'ri', 'label': 'Le 2ème à -60%', 'message': 'promotion.ri', 'isLoyalty': False, 'isPromo': False, 'isPrixBarre': False, 'isPrixForce': False, 'isVuEnCatalogue': False, 'isCrescendo': False, 'isClubActive': False, 'promotionParts': [], 'progression': {'current': None, 'total': None, 'completed': None}, 'bestQuantity': 2, 'messageArgs': {'quantity': 2, 'discountAmount': 2.15, 'discountedPrice': 5.03, 'initialPrice': 7.18, 'discountedPricePerUnit': None, 'startDate': '2025-03-31T00:00:00+0200', 'endDate': '2025-04-28T23:59:00+0200'}, 'promoStartDate': '2025-03-31T00:00:00+0200', 'promoEndDate': '2025-04-28T23:59:00+0200', 'mixableGtins': [], 'isPriceAlreadyDiscounted': True, 'mandateId': ['1120250000024449'], 'isDisplayed': True}], 'variableWeight': False, 'isRexEligible': False, 'expressWithdrawalEligibility': {'global': False, 'inCurrentStore': False}, 'isNonFoodDelivery': False, 'isRelayPointEligible': False, 'description': None, 'shopReturnPolicy': None, 'bundle': {'label': None}, 'isNew': False, 'isInnovation': True, 'isAlterna ...

# %%
#Loop to get all the page
import time
response_mer_2 = []
for x in range(13,25):
    params = {
    'noRedirect': '0',
    'page': str(x) ,
    }
    response = requests.get(
    'https://www.carrefour.fr/r/viandes-et-poissons/traiteur-mer',
    params=params,
    cookies=cookies,
    headers=headers,
    )
    response_mer_2.append(response.json())
    time.sleep(2)

print(response_mer_2)
# Out:
# [{'data': [{'type': 'product', 'id': 'product-3523680502208', 'attributes': {'ean': '3523680502208', 'cdbase': '7728553', 'title': 'Salade de choux SUSHI DAILY', 'brand': None, 'slug': 'salade-de-choux-sushi-daily', 'businessType': 'food', 'offerServiceId': '0261-150-6', 'uri': 'viandes-et-poissons/traiteur-mer/sushis', 'categories': [{'id': '1921', 'code': 'R00F00SF00', 'slug': 'viandes-et-poissons', 'label': 'Viandes et Poissons', 'uri': 'viandes-et-poissons', 'type': 'RAYON', 'level': 1, 'sellerId': None}, {'id': '28418', 'code': 'R00F00SF00', 'slug': 'traiteur-mer', 'label': 'Traiteur de la mer', 'uri': 'viandes-et-poissons/traiteur-mer', 'type': 'RAYON', 'level': 2, 'sellerId': None}, {'id': '28422', 'code': 'R00F00SF00', 'slug': 'sushis', 'label': 'Sushis', 'uri': 'viandes-et-poissons/traiteur-mer/sushis', 'type': 'RAYON', 'level': 3, 'sellerId': None}], 'topCategoryName': 'Viandes et Poissons', 'images': {'formats': {'largest': '540x540', 'common': ['43x43', '200x200', '540x540', '1500x1500']}, 'paths': ['https://media.carrefour.fr/medias/b58d8027cb3f3c91bf461dc7995be8ca/p_FORMAT/03523680502208-a1n1-s01.jpg']}, 'isDonation': False, 'isBestSeller': False, 'traceability': None, 'keyFeatures': [], 'moreOffers': {'count': 0, 'bestOfferId': None, 'bestOfferPrice': None, 'hasNonFoodDeliveryOffer': False, 'isRexEligible': False, 'withdrawalDelivery': {'exists': False, 'expressWithdrawalEligibility': {'global': False, 'inCurrentStore': False}}, 'hasCarrefourPlus': False}, 'offers': {'3523680502208': {'0261-150-6': {'type': 'offer', 'subType': 'carrefour', 'id': '0261-150-6', 'attributes': {'availability': {'indispensable': False, 'purchasable': True, 'stopped': False, 'suspended': False, 'suspensionReason': None, 'hasLowQuantity': False}, 'preorder': None, 'price': {'price': 2.2, 'taxMessage': '', 'unitOfMeasure': 'KG', 'perUnit': 19.47, 'perUnitLabel': '19.47 € / KG'}, 'ordering': {'min': 1, 'step': 1, 'max': 50}, 'offerServiceId': '0261-150-6', 'highlightLabel': None, 'freshness': None, 'marketplace': None, 'ean': '3523680502208', 'promotion': None, 'promotions': [], 'variableWeight': False, 'isRexEligible': False, 'expressWithdrawalEligibility': {'global': False, 'inCurrentStore': False}, 'isNonFoodDelivery': False, 'isRelayPointEligible': False, 'description': None, 'shopReturnPolicy': None, 'bundle': {'label': None}, 'isNew': False, 'isInnovation': False, 'isAlternativeCheaper': False, 'isDigitalCard': False, 'isWholesale': False, 'isClcv': False, 'isZiqy': False, 'isHealthy': False, 'isPhysicalStoreOffer': False, 'isExpressDelivery': False, 'isRecoverable': False, 'guarantees': []}, 'meta': {'cta': 'buy'}, 'links': {'self': ''}}}}, 'packaging': 'la barquette de 115g', 'deliveryModalities': [], 'flags': [], 'clubs': [], 'origin': 'FRANCE', 'format': '', 'nutriscore': None, 'customerReviews': {'average': None, 'count': None, 'rates': None}, 'variants': [], 'weightsAndMeasures': [], 'guarantee_general_document': 'https://static-cms.carrefour.fr/sites/default/files/documents/garanties-carrefour-plus-document-information-cgv.pdf'}, 'relationships': {'substitution': None}, 'meta': {'recommendation': None, 'cta': 'buy', 'features': {'deletable': False, 'swap': False, 'feedback': False, 'freshness': True}}, 'links': {'self': '/p/salade-de-choux-sushi-daily-3523680502208?t=28418', 'reviews': '/product/3523680502208/reviews'}}, {'type': 'product', 'id': 'product-3523680503311', 'attributes': {'ean': '3523680503311', 'cdbase': '7754180', 'title': 'Moules farcies à la persillade CARREFOUR LE MARCHE', 'brand': None, 'slug': 'moules-farcies-a-la-persillade-carrefour-le-marche', 'businessType': 'food', 'offerServiceId': '0261-150-6', 'uri': 'viandes-et-poissons/traiteur-mer/plats-prepares-mer', 'categories': [{'id': '1921', 'code': 'R00F00SF00', 'slug': 'viandes-et-poissons', 'label': 'Viandes et Poissons', 'uri': 'viandes-et-poissons', 'type': 'RAYON', 'level': 1, 'sellerId': None}, {'id': '28418', 'code': 'R00F00SF00', 'slug': 'traite ...

# %%
#Get the relevant columns and extract the price/kg
import pandas as pd

df_mer_1 = pd.DataFrame()  # Initialize an empty DataFrame

for item in response_mer_1:  # Loop through each JSON object
    try:
        # Ensure 'data' exists and extract it safely
        df_data = pd.DataFrame(item.get('data', []))  
        
        # Ensure 'attributes' exists before normalizing
        if 'attributes' in df_data:
            df_product = pd.json_normalize(df_data['attributes'])
        else:
            print("Warning: 'attributes' key missing in data.")
            continue  # Skip this item if 'attributes' is missing

        price_unit = []
        for x in df_product.get("ean", []):  # Use .get() to avoid KeyError
            try:
                ean_index = df_product[df_product["ean"] == x].index[0]
                price_column = f"offers.{x}.0261-150-6.attributes.price.perUnitLabel"

                # Check if the column exists before accessing
                if price_column in df_product.columns:
                    price_unit_variable = df_product.loc[ean_index, price_column]
                else:
                    price_unit_variable = None  # Default if price column missing

                price_unit.append(price_unit_variable)
            except Exception as e:
                print(f"Error processing EAN {x}: {e}")
                price_unit.append(None)  # Append None for failed entries

        price = []
        for x in df_product.get("ean", []):  # Use .get() to avoid KeyError
            try:
                ean_index = df_product[df_product["ean"] == x].index[0]
                price_column = f"offers.{x}.0261-150-6.attributes.price.price"

                # Check if the column exists before accessing
                if price_column in df_product.columns:
                    price_variable = df_product.loc[ean_index, price_column]
                else:
                    price_variable = None  # Default if price column missing

                price.append(price_variable)
            except Exception as e:
                print(f"Error processing EAN {x}: {e}")
                price.append(None)  # Append None for failed entries

        # Select relevant columns safely
        try:
            df_final = df_product[["title", "slug", "topCategoryName", "origin"]].copy()
        except KeyError as e:
            print(f"Missing column error: {e}")
            continue  # Skip this item if required columns are missing

        # Add price_unit column
        df_final["price_unit"] = price_unit
        df_final["price"] = price

        # Concatenate safely
        df_mer_1 = pd.concat([df_mer_1, df_final], ignore_index=True)

    except Exception as e:
        print(f"Error processing item: {e}")
        continue  # Skip the item on error

# Print the final DataFrame
print(df_mer_1)
# Out:
#                                title                             slug  \
# 0     Surimi bâtonnets saveur CORAYA   surimi-batonnets-saveur-coraya
# 1    Saumon fumé Le Norvège LABEYRIE  saumon-fume-le-norvege-labeyrie
# 2     Truite fumée REFLETS DE FRANCE   truite-fumee-reflets-de-france
# 3    Saumon fumé Atlantique LABEYRIE  saumon-fume-atlantique-labeyrie
# 4     Truite fumée REFLETS DE FRANCE   truite-fumee-reflets-de-france
# ..                               ...                              ...
# 355           Maki & you SUSHI DAILY             maki-you-sushi-daily
# 356    Menu 4 sans algue SUSHI DAILY    menu-4-sans-algue-sushi-daily
# 357    Menu 4 sans algue SUSHI DAILY    menu-4-sans-algue-sushi-daily
# 358      Maki California SUSHI DAILY      maki-california-sushi-daily
# 359           Dream roll SUSHI DAILY           dream-roll-sushi-daily
#
#          topCategoryName  origin    price_unit  price
# 0    Viandes et Poissons           7.98 € / KG   3.59
# 1    Viandes et Poissons          40.88 € / KG  10.99
# 2    Viandes et Poissons          45.42 € / KG   5.45
# 3    Viandes et Poissons          52.07 € / KG  15.10
# 4    Viandes et Poissons          41.90 € / KG   4.19
# ..                   ...     ...           ...    ...
# 355  Viandes et Poissons  FRANCE  35.62 € / KG  19.95
# 356  Viandes et Poissons  FRANCE  43.85 € / KG  19.95
# 357  Viandes et Poissons  FRANCE  46.04 € / KG  20.95
# 358  Viandes et Poissons  FRANCE  45.08 € / KG   5.95
# 359  Viandes et Poissons  FRANCE  50.00 € / KG   8.50
#
# [360 rows x 6 columns]

# %%
#Get the relevant columns and extract the price/kg
import pandas as pd

df_mer_2 = pd.DataFrame()  # Initialize an empty DataFrame

for item in response_mer_2:  # Loop through each JSON object
    try:
        # Ensure 'data' exists and extract it safely
        df_data = pd.DataFrame(item.get('data', []))  
        
        # Ensure 'attributes' exists before normalizing
        if 'attributes' in df_data:
            df_product = pd.json_normalize(df_data['attributes'])
        else:
            print("Warning: 'attributes' key missing in data.")
            continue  # Skip this item if 'attributes' is missing

        price_unit = []
        for x in df_product.get("ean", []):  # Use .get() to avoid KeyError
            try:
                ean_index = df_product[df_product["ean"] == x].index[0]
                price_column = f"offers.{x}.0261-150-6.attributes.price.perUnitLabel"

                # Check if the column exists before accessing
                if price_column in df_product.columns:
                    price_unit_variable = df_product.loc[ean_index, price_column]
                else:
                    price_unit_variable = None  # Default if price column missing

                price_unit.append(price_unit_variable)
            except Exception as e:
                print(f"Error processing EAN {x}: {e}")
                price_unit.append(None)  # Append None for failed entries

        price = []
        for x in df_product.get("ean", []):  # Use .get() to avoid KeyError
            try:
                ean_index = df_product[df_product["ean"] == x].index[0]
                price_column = f"offers.{x}.0261-150-6.attributes.price.price"

                # Check if the column exists before accessing
                if price_column in df_product.columns:
                    price_variable = df_product.loc[ean_index, price_column]
                else:
                    price_variable = None  # Default if price column missing

                price.append(price_variable)
            except Exception as e:
                print(f"Error processing EAN {x}: {e}")
                price.append(None)  # Append None for failed entries

        # Select relevant columns safely
        try:
            df_final = df_product[["title", "slug", "topCategoryName", "origin"]].copy()
        except KeyError as e:
            print(f"Missing column error: {e}")
            continue  # Skip this item if required columns are missing

        # Add price_unit column
        df_final["price_unit"] = price_unit
        df_final["price"] = price

        # Concatenate safely
        df_mer_2 = pd.concat([df_mer_2, df_final], ignore_index=True)

    except Exception as e:
        print(f"Error processing item: {e}")
        continue  # Skip the item on error

# Print the final DataFrame
print(df_mer_2)
# Out:
#                                                  title  \
# 0                          Salade de choux SUSHI DAILY
# 1    Moules farcies à la persillade CARREFOUR LE MA...
# 2                              Sushi assortiment SIMPL
# 3          Onigiri saumon teriyaki CARREFOUR LE MARCHE
# 4              Encornets géant à l'ail et persil frais
# ..                                                 ...
# 355     Soupe De Poisson À La Provençale - Beaumoulin
# 356  Bouillabaisse Artisanale En Conserve - Bocal 7...
# 357                     Bisque De Homard - Beaumoulin
# 358    Soupe De Poissons Pêche Bretonne - L'ile Bleue
# 359  Lot 6x Soupe De Poissons - Label Rouge - Boute...
#
#                                                   slug  \
# 0                          salade-de-choux-sushi-daily
# 1    moules-farcies-a-la-persillade-carrefour-le-ma...
# 2                              sushi-assortiment-simpl
# 3          onigiri-saumon-teriyaki-carrefour-le-marche
# 4              encornets-geant-a-l-ail-et-persil-frais
# ..                                                 ...
# 355        soupe-de-poisson-a-la-provencale-beaumoulin
# 356  bouillabaisse-artisanale-en-conserve-bocal-720...
# 357                        bisque-de-homard-beaumoulin
# 358       soupe-de-poissons-peche-bretonne-l-ile-bleue
# 359  lot-6x-soupe-de-poissons-label-rouge-bouteille...
#
#              topCategoryName  origin    price_unit  price
# 0        Viandes et Poissons  FRANCE  19.47 € / KG   2.20
# 1        Viandes et Poissons  FRANCE  59.70 € / KG   4.00
# 2        Viandes et Poissons  FRANCE  22.20 € / KG   8.79
# 3    Charcuterie et Traiteur  FRANCE  25.00 € / KG   2.50
# 4        Viandes et Poissons   PEROU  29.92 € / KG   3.59
# ..                       ...     ...           ...    ...
# 355      Viandes et Poissons  FRANCE          None    NaN
# 356      Viandes et Poissons                  None    NaN
# 357           Epicerie salée  FRANCE          None    NaN
# 358      Viandes et Poissons  FRANCE          None    NaN
# 359      Viandes et Poissons  FRANCE          None    NaN
#
# [360 rows x 6 columns]

# %%
df_mer = pd.concat([df_mer_1, df_mer_2], ignore_index=True)

# %%
df_mer.to_csv("mer.csv", index=False)
