# %%
import requests

cookies = {
    'tc_cj_v2_cmp': '',
    'tc_cj_v2_med': '',
    'tc_ts': '40',
    'FRONTONE_ONLINE': '1745247464',
    'FRONTONE_SESSION_ID': 'fe0e97616cc0dc73679f62b16fa7c577b2d86018',
    'CAID': '202503221557457366701354',
    'OptanonAlertBoxClosed': '2025-03-22T14:57:49.848Z',
    'eupubconsent-v2': 'CQOq1pgQOq1pgAcABBENBiFwAAAAAAAAAChQAAAAAAChIAYAygF5gTAHQAwBlALzAmAOAAgSEJQAQF5lIAYAygF5gTAA.YAAAAAAAAAAA',
    'OneTrustGroupsConsent': '%2CC0048%2CC0001%2C',
    'FRONTONE_SESSID': 'uim3dg95re0gh6j1p6jnc30adj',
    'sap-closed': '1',
    'tc_eff_params': '',
    'tc_ab': '1',
    'aaaaaaaaa944fac35b02f4d9a99619247b88ad463_cs': '',
    'cf_chl_rc_i': '1',
    'tc_cj_v2': '%5Ecl_%5Dny%5B%5D%5D_mmZZZZZZKQNLPOONPSSJKZZZ%5D777m_iZZZ%2C2%7B%29%2FZZZKQNMLOJOSNKMQZZZ%5D777%5Ecl_%5Dny%5B%5D%5D_mmZZZZZZKQNMPRKQRQOOJZZZ%5D',
    'cf_clearance': 'iAdgcdq9uVYSHLQkOFY84Qrlja3tKYvd1CbC4LoRSjE-1743682068-1.2.1.1-kNUAUOTviDK6.Gmz8b11GqRgGa1o3YVIodY2o6iSLvQTx7u9S_XsjVsAPpIQfEi5YCvyiGej0j8cfCit1ZAE6xLWShL4gtteCDIqqSnzbDhgMu7gGZNjLEROzl7bKEvgLaNHtSS073X7NXqo5qIjBosGfQaxfXPHv4baAIKkTZLoNRqPbIkWBhUuBsf_q3Jo.ObJPgzlfa5myu4EMbQYUSGNH2stQSe0FjprPKNueAxzoGDW3UUUxDbCbXzMgjv_VLn_mNOpmWa9Mw6cdgNjnrZhjpfuf.BxQ9hxvcbuuK_2gKrUtNVlc73tVn03eiLjQSCWbwY_BC.jFK3cM05GbZ.8YtMv1Jj_PeRpQCVROgY5AT0730cqc0sftA._KcVp',
    'pageCounterCrfOne': '19',
    'OptanonConsent': 'isGpcEnabled=0&datestamp=Thu+Apr+03+2025+14%3A07%3A57+GMT%2B0200+(heure+d%E2%80%99%C3%A9t%C3%A9+d%E2%80%99Europe+centrale)&version=202310.2.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=92a3e744-b25d-4e54-a023-8625a83bd02f&interactionCount=1&landingPath=NotLandingPage&groups=C0048%3A1%2CC0001%3A1%2CC0040%3A0%2CC0032%3A0%2CC0025%3A0%2CC0020%3A0%2CC0037%3A0%2CC0039%3A0%2CC0036%3A0%2CC0041%3A0%2CC0042%3A0%2CC0044%3A0%2CC0043%3A0%2CC0045%3A0%2CC0049%3A0%2CC0047%3A0%2CC0023%3A0%2CC0056%3A0%2CC0038%3A0%2CC0082%3A0%2CC0026%3A0%2CC0177%3A0%2CC0113%3A0%2CC0089%3A0%2CC0092%3A0%2CC0190%3A0%2CC0166%3A0%2CC0222%3A0%2CC0223%3A0%2CC0231%3A0%2CC0263%3A0%2CC0004%3A0%2CC0022%3A0%2CC0054%3A0%2CC0179%3A0%2CC0146%3A0%2CC0052%3A0%2CC0034%3A0%2CC0063%3A0%2CC0157%3A0%2CC0003%3A0%2CC0212%3A0%2CC0081%3A0%2CC0051%3A0%2CC0136%3A0%2CC0135%3A0%2CC0007%3A0%2CV2STACK42%3A0&geolocation=FR%3BPAC&AwaitingReconsent=false',
    'carrefour_counter': '1743682077979%7C137739566618166%7Cp0%7Ce0%7Cv1%7Cc254.41%7CServerSide',
    '__cf_bm': 'A5bEej4Z4YFWnHKZlWPj.haYRkJEokx.glzCpt0gv.U-1743682075-1.0.1.1-1FdUSYyWWYYARocSvLQ5muSzdH7HzZWmOmbBRS5sJoFwTI3J_Jk_5XqqUoExuqhx.BD61x.2chaBY5QIwnFfun9VvqGNOvdORACw0flYi1w',
    '__cfwaitingroom_www': '',
}

headers = {
    'accept': 'application/json, text/plain, */*',
    'accept-language': 'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7',
    'priority': 'u=1, i',
    'referer': 'https://www.carrefour.fr/r/cremerie/desserts-compotes?noRedirect=1&page=2',
    'sec-ch-ua': '"Chromium";v="134", "Not:A-Brand";v="24", "Google Chrome";v="134"',
    'sec-ch-ua-arch': '"x86"',
    'sec-ch-ua-bitness': '"64"',
    'sec-ch-ua-full-version': '"134.0.6998.178"',
    'sec-ch-ua-full-version-list': '"Chromium";v="134.0.6998.178", "Not:A-Brand";v="24.0.0.0", "Google Chrome";v="134.0.6998.178"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-model': '""',
    'sec-ch-ua-platform': '"Windows"',
    'sec-ch-ua-platform-version': '"10.0.0"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest',
    # 'cookie': 'tc_cj_v2_cmp=; tc_cj_v2_med=; tc_ts=40; FRONTONE_ONLINE=1745247464; FRONTONE_SESSION_ID=fe0e97616cc0dc73679f62b16fa7c577b2d86018; CAID=202503221557457366701354; OptanonAlertBoxClosed=2025-03-22T14:57:49.848Z; eupubconsent-v2=CQOq1pgQOq1pgAcABBENBiFwAAAAAAAAAChQAAAAAAChIAYAygF5gTAHQAwBlALzAmAOAAgSEJQAQF5lIAYAygF5gTAA.YAAAAAAAAAAA; OneTrustGroupsConsent=%2CC0048%2CC0001%2C; FRONTONE_SESSID=uim3dg95re0gh6j1p6jnc30adj; sap-closed=1; tc_eff_params=; tc_ab=1; aaaaaaaaa944fac35b02f4d9a99619247b88ad463_cs=; cf_chl_rc_i=1; tc_cj_v2=%5Ecl_%5Dny%5B%5D%5D_mmZZZZZZKQNLPOONPSSJKZZZ%5D777m_iZZZ%2C2%7B%29%2FZZZKQNMLOJOSNKMQZZZ%5D777%5Ecl_%5Dny%5B%5D%5D_mmZZZZZZKQNMPRKQRQOOJZZZ%5D; cf_clearance=iAdgcdq9uVYSHLQkOFY84Qrlja3tKYvd1CbC4LoRSjE-1743682068-1.2.1.1-kNUAUOTviDK6.Gmz8b11GqRgGa1o3YVIodY2o6iSLvQTx7u9S_XsjVsAPpIQfEi5YCvyiGej0j8cfCit1ZAE6xLWShL4gtteCDIqqSnzbDhgMu7gGZNjLEROzl7bKEvgLaNHtSS073X7NXqo5qIjBosGfQaxfXPHv4baAIKkTZLoNRqPbIkWBhUuBsf_q3Jo.ObJPgzlfa5myu4EMbQYUSGNH2stQSe0FjprPKNueAxzoGDW3UUUxDbCbXzMgjv_VLn_mNOpmWa9Mw6cdgNjnrZhjpfuf.BxQ9hxvcbuuK_2gKrUtNVlc73tVn03eiLjQSCWbwY_BC.jFK3cM05GbZ.8YtMv1Jj_PeRpQCVROgY5AT0730cqc0sftA._KcVp; pageCounterCrfOne=19; OptanonConsent=isGpcEnabled=0&datestamp=Thu+Apr+03+2025+14%3A07%3A57+GMT%2B0200+(heure+d%E2%80%99%C3%A9t%C3%A9+d%E2%80%99Europe+centrale)&version=202310.2.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=92a3e744-b25d-4e54-a023-8625a83bd02f&interactionCount=1&landingPath=NotLandingPage&groups=C0048%3A1%2CC0001%3A1%2CC0040%3A0%2CC0032%3A0%2CC0025%3A0%2CC0020%3A0%2CC0037%3A0%2CC0039%3A0%2CC0036%3A0%2CC0041%3A0%2CC0042%3A0%2CC0044%3A0%2CC0043%3A0%2CC0045%3A0%2CC0049%3A0%2CC0047%3A0%2CC0023%3A0%2CC0056%3A0%2CC0038%3A0%2CC0082%3A0%2CC0026%3A0%2CC0177%3A0%2CC0113%3A0%2CC0089%3A0%2CC0092%3A0%2CC0190%3A0%2CC0166%3A0%2CC0222%3A0%2CC0223%3A0%2CC0231%3A0%2CC0263%3A0%2CC0004%3A0%2CC0022%3A0%2CC0054%3A0%2CC0179%3A0%2CC0146%3A0%2CC0052%3A0%2CC0034%3A0%2CC0063%3A0%2CC0157%3A0%2CC0003%3A0%2CC0212%3A0%2CC0081%3A0%2CC0051%3A0%2CC0136%3A0%2CC0135%3A0%2CC0007%3A0%2CV2STACK42%3A0&geolocation=FR%3BPAC&AwaitingReconsent=false; carrefour_counter=1743682077979%7C137739566618166%7Cp0%7Ce0%7Cv1%7Cc254.41%7CServerSide; __cf_bm=A5bEej4Z4YFWnHKZlWPj.haYRkJEokx.glzCpt0gv.U-1743682075-1.0.1.1-1FdUSYyWWYYARocSvLQ5muSzdH7HzZWmOmbBRS5sJoFwTI3J_Jk_5XqqUoExuqhx.BD61x.2chaBY5QIwnFfun9VvqGNOvdORACw0flYi1w; __cfwaitingroom_www=',
}

params = {
    'noRedirect': '1',
    'page': '3',
}

response = requests.get('https://www.carrefour.fr/r/cremerie/desserts-compotes', params=params, cookies=cookies, headers=headers)

# %%
#Loop to get all the page
import time
response_1 = []
for x in range(1,18):
    params = {
    'noRedirect': '0',
    'page': str(x) ,
    }
    response = requests.get(
    'https://www.carrefour.fr/r/cremerie/desserts-compotes',
    params=params,
    cookies=cookies,
    headers=headers,
    )
    response_1.append(response.json())
    time.sleep(2)

print(response_1)
# Out:
# [{'data': [{'type': 'product', 'id': 'product-3023290052150', 'attributes': {'ean': '3023290052150', 'cdbase': '7141347', 'title': 'Mousse vanille feuilleté de mousse LA LAITIERE', 'brand': None, 'slug': 'mousse-vanille-feuillete-de-mousse-la-laitiere', 'businessType': 'food', 'offerServiceId': '0261-150-6', 'uri': 'cremerie/desserts-compotes/cremes-dessert-mousses-liegeois/mousses', 'categories': [{'id': '36993', 'code': 'R00F00SF00', 'slug': 'cremerie', 'label': 'Crèmerie et Produits laitiers', 'uri': 'cremerie', 'type': 'RAYON', 'level': 1, 'sellerId': None}, {'id': '36996', 'code': 'R00F00SF00', 'slug': 'desserts-compotes', 'label': 'Desserts et Compotes', 'uri': 'cremerie/desserts-compotes', 'type': 'RAYON', 'level': 2, 'sellerId': None}, {'id': '28232', 'code': 'R00F00SF00', 'slug': 'cremes-dessert-mousses-liegeois', 'label': 'Crèmes desserts, Mousses et Liégeois', 'uri': 'cremerie/desserts-compotes/cremes-dessert-mousses-liegeois', 'type': 'RAYON', 'level': 3, 'sellerId': None}, {'id': '28249', 'code': 'R00F00SF00', 'slug': 'mousses', 'label': 'Mousses', 'uri': 'cremerie/desserts-compotes/cremes-dessert-mousses-liegeois/mousses', 'type': 'RAYON', 'level': 4, 'sellerId': None}], 'topCategoryName': 'Crèmerie et Produits laitiers', 'images': {'formats': {'largest': '540x540', 'common': ['43x43', '200x200', '540x540', '1500x1500']}, 'paths': ['https://media.carrefour.fr/medias/072f4155bda046c7b980f88eb6ba7d53/p_FORMAT/03023290052150_C1L1_s02.png']}, 'isDonation': False, 'isBestSeller': False, 'traceability': None, 'keyFeatures': [], 'moreOffers': {'count': 0, 'bestOfferId': None, 'bestOfferPrice': None, 'hasNonFoodDeliveryOffer': False, 'isRexEligible': False, 'withdrawalDelivery': {'exists': False, 'expressWithdrawalEligibility': {'global': False, 'inCurrentStore': False}}, 'hasCarrefourPlus': False}, 'offers': {'3023290052150': {'0261-150-6': {'type': 'offer', 'subType': 'carrefour', 'id': '0261-150-6', 'attributes': {'availability': {'indispensable': False, 'purchasable': True, 'stopped': False, 'suspended': False, 'suspensionReason': None, 'hasLowQuantity': False}, 'preorder': None, 'price': {'price': 1.54, 'taxMessage': '', 'unitOfMeasure': 'KG', 'perUnit': 6.75, 'perUnitLabel': '6.75 € / KG'}, 'ordering': {'min': 1, 'step': 1, 'max': 50}, 'offerServiceId': '0261-150-6', 'highlightLabel': {'type': 'promotion', 'key': 'product.label.promotion'}, 'freshness': {'value': 5, 'period': 'day'}, 'marketplace': None, 'ean': '3023290052150', 'promotion': {'type': 'ri', 'label': 'Prenez en 3 = Payez en 2', 'message': 'promotion.ri', 'isLoyalty': False, 'isPromo': False, 'isPrixBarre': False, 'isPrixForce': False, 'isVuEnCatalogue': False, 'isCrescendo': False, 'isClubActive': False, 'promotionParts': [], 'progression': {'current': None, 'total': None, 'completed': None}, 'bestQuantity': 3, 'messageArgs': {'quantity': 3, 'discountAmount': 1.54, 'discountedPrice': 3.08, 'initialPrice': 4.62, 'discountedPricePerUnit': None, 'startDate': '2025-03-31T00:00:00+0200', 'endDate': '2025-04-28T23:59:00+0200'}, 'promoStartDate': '2025-03-31T00:00:00+0200', 'promoEndDate': '2025-04-28T23:59:00+0200', 'mixableGtins': [], 'isPriceAlreadyDiscounted': True, 'mandateId': ['1120250000024415'], 'isDisplayed': True}, 'promotions': [{'type': 'ri', 'label': 'Prenez en 3 = Payez en 2', 'message': 'promotion.ri', 'isLoyalty': False, 'isPromo': False, 'isPrixBarre': False, 'isPrixForce': False, 'isVuEnCatalogue': False, 'isCrescendo': False, 'isClubActive': False, 'promotionParts': [], 'progression': {'current': None, 'total': None, 'completed': None}, 'bestQuantity': 3, 'messageArgs': {'quantity': 3, 'discountAmount': 1.54, 'discountedPrice': 3.08, 'initialPrice': 4.62, 'discountedPricePerUnit': None, 'startDate': '2025-03-31T00:00:00+0200', 'endDate': '2025-04-28T23:59:00+0200'}, 'promoStartDate': '2025-03-31T00:00:00+0200', 'promoEndDate': '2025-04-28T23:59:00+0200', 'mixableGtins': [], 'isPriceAlreadyDiscounted': True, 'mandateId': ['1120250000024415 ...

# %%
#Get the relevant columns and extract the price/kg
import pandas as pd

df_1 = pd.DataFrame()  # Initialize an empty DataFrame

for item in response_1:  # Loop through each JSON object
    try:
        # Ensure 'data' exists and extract it safely
        df_data = pd.DataFrame(item.get('data', []))  
        
        # Ensure 'attributes' exists before normalizing
        if 'attributes' in df_data:
            df_product = pd.json_normalize(df_data['attributes'])
        else:
            print("Warning: 'attributes' key missing in data.")
            continue  # Skip this item if 'attributes' is missing

        price_unit = []
        for x in df_product.get("ean", []):  # Use .get() to avoid KeyError
            try:
                ean_index = df_product[df_product["ean"] == x].index[0]
                price_column = f"offers.{x}.0261-150-6.attributes.price.perUnitLabel"

                # Check if the column exists before accessing
                if price_column in df_product.columns:
                    price_unit_variable = df_product.loc[ean_index, price_column]
                else:
                    price_unit_variable = None  # Default if price column missing

                price_unit.append(price_unit_variable)
            except Exception as e:
                print(f"Error processing EAN {x}: {e}")
                price_unit.append(None)  # Append None for failed entries

        price = []
        for x in df_product.get("ean", []):  # Use .get() to avoid KeyError
            try:
                ean_index = df_product[df_product["ean"] == x].index[0]
                price_column = f"offers.{x}.0261-150-6.attributes.price.price"

                # Check if the column exists before accessing
                if price_column in df_product.columns:
                    price_variable = df_product.loc[ean_index, price_column]
                else:
                    price_variable = None  # Default if price column missing

                price.append(price_variable)
            except Exception as e:
                print(f"Error processing EAN {x}: {e}")
                price.append(None)  # Append None for failed entries

        # Select relevant columns safely
        try:
            df_final = df_product[["title", "slug", "topCategoryName", "origin"]].copy()
        except KeyError as e:
            print(f"Missing column error: {e}")
            continue  # Skip this item if required columns are missing

        # Add price_unit column
        df_final["price_unit"] = price_unit
        df_final["price"] = price

        # Concatenate safely
        df_1 = pd.concat([df_1, df_final], ignore_index=True)

    except Exception as e:
        print(f"Error processing item: {e}")
        continue  # Skip the item on error

# Print the final DataFrame
print(df_1)
# Out:
#                                                  title  \
# 0       Mousse vanille feuilleté de mousse LA LAITIERE
# 1              Yaourt Mamie Nova Gourmand Fondant Café
# 2            Dessert clafoutis aux cerises LA LAITIERE
# 3              Dessert pâtissier moka café BONNE MAMAN
# 4    Compote mangue morceaux sans sucres ajoutés CH...
# ..                                                 ...
# 505  Compote Pomme Fraise Sans Sucres Ajoutés Cœur ...
# 506                   Dessert Rhubarbe Morceaux ANDROS
# 507                    Compotes Pomme Châtaigne ANDROS
# 508   Dessert Liégeois Pomme Abricot Framboise  ANDROS
# 509                     Dessert Fraise Morceaux ANDROS
#
#                                                   slug  \
# 0       mousse-vanille-feuillete-de-mousse-la-laitiere
# 1              yaourt-mamie-nova-gourmand-fondant-cafe
# 2            dessert-clafoutis-aux-cerises-la-laitiere
# 3              dessert-patissier-moka-cafe-bonne-maman
# 4    compote-mangue-morceaux-sans-sucres-ajoutes-ch...
# ..                                                 ...
# 505  compote-pomme-fraise-sans-sucres-ajoutes-coeur...
# 506                   dessert-rhubarbe-morceaux-andros
# 507                    compotes-pomme-chataigne-andros
# 508    dessert-liegeois-pomme-abricot-framboise-andros
# 509                     dessert-fraise-morceaux-andros
#
#                    topCategoryName origin    price_unit  price
# 0    Crèmerie et Produits laitiers          6.75 € / KG   1.54
# 1    Crèmerie et Produits laitiers          4.15 € / KG   2.49
# 2    Crèmerie et Produits laitiers          7.79 € / KG   2.65
# 3    Crèmerie et Produits laitiers         11.90 € / KG   2.38
# 4    Crèmerie et Produits laitiers          7.08 € / KG   2.69
# ..                             ...    ...           ...    ...
# 505  Crèmerie et Produits laitiers          4.62 € / KG   1.85
# 506  Crèmerie et Produits laitiers          6.12 € / KG   2.45
# 507  Crèmerie et Produits laitiers          3.74 € / KG   2.99
# 508  Crèmerie et Produits laitiers          5.98 € / KG   2.39
# 509  Crèmerie et Produits laitiers          6.98 € / KG   2.79
#
# [510 rows x 6 columns]

# %%
df_1.to_csv("dessert.csv", index=False)
