# %% [markdown]
# # Volaille

# %%
import requests

cookies = {
    'tc_cj_v2_cmp': '',
    'tc_cj_v2_med': '',
    'tc_ts': '40',
    'FRONTONE_ONLINE': '1745247464',
    'FRONTONE_SESSION_ID': 'fe0e97616cc0dc73679f62b16fa7c577b2d86018',
    'CAID': '202503221557457366701354',
    'OptanonAlertBoxClosed': '2025-03-22T14:57:49.848Z',
    'eupubconsent-v2': 'CQOq1pgQOq1pgAcABBENBiFwAAAAAAAAAChQAAAAAAChIAYAygF5gTAHQAwBlALzAmAOAAgSEJQAQF5lIAYAygF5gTAA.YAAAAAAAAAAA',
    'OneTrustGroupsConsent': '%2CC0048%2CC0001%2C',
    'FRONTONE_SESSID': 'uim3dg95re0gh6j1p6jnc30adj',
    'sap-closed': '1',
    'tc_eff_params': '',
    'tc_ab': '1',
    'aaaaaaaaa944fac35b02f4d9a99619247b88ad463_cs': '',
    'tc_cj_v2': '%5Ecl_%5Dny%5B%5D%5D_mmZZZZZZKQNLPOONPSSJKZZZ%5D777m_iZZZ%2C2%7B%29%2FZZZKQNMLOJOSNKMQZZZ%5D777%5Ecl_%5Dny%5B%5D%5D_mmZZZZZZKQNMPRSKOROPOZZZ%5D',
    'cf_clearance': 'OCmDUft_rTyKaiE_7sUhR111t5ST3uJBsAzcy8x2YdU-1743689776-1.2.1.1-.qsgGuMmyFxlWfIewK9unhRBHKNrhVmX31gufOY29m1JnOaJZ7U0I0mR4JY340TNQpafjh3NkukvqeGzhGISsSttCheyFFSS4tO44ikAHXwtVvTZqlSzXzl.3J0V6ZApCw7UcUfXEsta9M15FL0ZmyQc_FJ.hdMSBGskvphWNFD5c6GrXvFjKZ0mJRFt_.mgC9CESoRefUHZP0qizU00xMfqtZCn7WS4q8h93klJCwio1xpzN7nirGl7p8pXHY9UKp2mMLona6Ew_wysu6VNfjG3hG9FGt2EtQ0QxS7J30UIWwz977ys26Z90S8JDivfKCyYIS2bRjV6k1zzmZqulkfrLtCM5Gn_pHQNNHkGg9OkWo8A2Il3RngZarH.9tWL',
    'pageCounterCrfOne': '36',
    'OptanonConsent': 'isGpcEnabled=0&datestamp=Thu+Apr+03+2025+16%3A16%3A24+GMT%2B0200+(heure+d%E2%80%99%C3%A9t%C3%A9+d%E2%80%99Europe+centrale)&version=202310.2.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=92a3e744-b25d-4e54-a023-8625a83bd02f&interactionCount=1&landingPath=NotLandingPage&groups=C0048%3A1%2CC0001%3A1%2CC0040%3A0%2CC0032%3A0%2CC0025%3A0%2CC0020%3A0%2CC0037%3A0%2CC0039%3A0%2CC0036%3A0%2CC0041%3A0%2CC0042%3A0%2CC0044%3A0%2CC0043%3A0%2CC0045%3A0%2CC0049%3A0%2CC0047%3A0%2CC0023%3A0%2CC0056%3A0%2CC0038%3A0%2CC0082%3A0%2CC0026%3A0%2CC0177%3A0%2CC0113%3A0%2CC0089%3A0%2CC0092%3A0%2CC0190%3A0%2CC0166%3A0%2CC0222%3A0%2CC0223%3A0%2CC0231%3A0%2CC0263%3A0%2CC0004%3A0%2CC0022%3A0%2CC0054%3A0%2CC0179%3A0%2CC0146%3A0%2CC0052%3A0%2CC0034%3A0%2CC0063%3A0%2CC0157%3A0%2CC0003%3A0%2CC0212%3A0%2CC0081%3A0%2CC0051%3A0%2CC0136%3A0%2CC0135%3A0%2CC0007%3A0%2CV2STACK42%3A0&geolocation=FR%3BPAC&AwaitingReconsent=false',
    '__cf_bm': 'O7iu_B3elAlvScvQCbjrvUOJS5g79er.RQopqf0gyk8-1743689779-1.0.1.1-g1UuluB1PxM27amj_O2ZMMBaaNgIk2UERIZ7BsNh0MUFtm8eW8LKZDkKd_z.a9SPtFGqqcWEUrNC9Xpd_7gvjtRcVK66dz6Qaimij7pURYY',
    'carrefour_counter': '1743689787154%7C137739566618166%7Cp0%7Ce0%7Cv1%7Cc254.41%7CServerSide',
    '__cfwaitingroom_www': '',
}

headers = {
    'accept': 'application/json, text/plain, */*',
    'accept-language': 'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7',
    'priority': 'u=1, i',
    'referer': 'https://www.carrefour.fr/r/viandes-et-poissons/volaille-et-rotisserie?noRedirect=1&page=3',
    'sec-ch-ua': '"Chromium";v="134", "Not:A-Brand";v="24", "Google Chrome";v="134"',
    'sec-ch-ua-arch': '"x86"',
    'sec-ch-ua-bitness': '"64"',
    'sec-ch-ua-full-version': '"134.0.6998.178"',
    'sec-ch-ua-full-version-list': '"Chromium";v="134.0.6998.178", "Not:A-Brand";v="24.0.0.0", "Google Chrome";v="134.0.6998.178"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-model': '""',
    'sec-ch-ua-platform': '"Windows"',
    'sec-ch-ua-platform-version': '"10.0.0"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest',
    # 'cookie': 'tc_cj_v2_cmp=; tc_cj_v2_med=; tc_ts=40; FRONTONE_ONLINE=1745247464; FRONTONE_SESSION_ID=fe0e97616cc0dc73679f62b16fa7c577b2d86018; CAID=202503221557457366701354; OptanonAlertBoxClosed=2025-03-22T14:57:49.848Z; eupubconsent-v2=CQOq1pgQOq1pgAcABBENBiFwAAAAAAAAAChQAAAAAAChIAYAygF5gTAHQAwBlALzAmAOAAgSEJQAQF5lIAYAygF5gTAA.YAAAAAAAAAAA; OneTrustGroupsConsent=%2CC0048%2CC0001%2C; FRONTONE_SESSID=uim3dg95re0gh6j1p6jnc30adj; sap-closed=1; tc_eff_params=; tc_ab=1; aaaaaaaaa944fac35b02f4d9a99619247b88ad463_cs=; tc_cj_v2=%5Ecl_%5Dny%5B%5D%5D_mmZZZZZZKQNLPOONPSSJKZZZ%5D777m_iZZZ%2C2%7B%29%2FZZZKQNMLOJOSNKMQZZZ%5D777%5Ecl_%5Dny%5B%5D%5D_mmZZZZZZKQNMPRSKOROPOZZZ%5D; cf_clearance=OCmDUft_rTyKaiE_7sUhR111t5ST3uJBsAzcy8x2YdU-1743689776-1.2.1.1-.qsgGuMmyFxlWfIewK9unhRBHKNrhVmX31gufOY29m1JnOaJZ7U0I0mR4JY340TNQpafjh3NkukvqeGzhGISsSttCheyFFSS4tO44ikAHXwtVvTZqlSzXzl.3J0V6ZApCw7UcUfXEsta9M15FL0ZmyQc_FJ.hdMSBGskvphWNFD5c6GrXvFjKZ0mJRFt_.mgC9CESoRefUHZP0qizU00xMfqtZCn7WS4q8h93klJCwio1xpzN7nirGl7p8pXHY9UKp2mMLona6Ew_wysu6VNfjG3hG9FGt2EtQ0QxS7J30UIWwz977ys26Z90S8JDivfKCyYIS2bRjV6k1zzmZqulkfrLtCM5Gn_pHQNNHkGg9OkWo8A2Il3RngZarH.9tWL; pageCounterCrfOne=36; OptanonConsent=isGpcEnabled=0&datestamp=Thu+Apr+03+2025+16%3A16%3A24+GMT%2B0200+(heure+d%E2%80%99%C3%A9t%C3%A9+d%E2%80%99Europe+centrale)&version=202310.2.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=92a3e744-b25d-4e54-a023-8625a83bd02f&interactionCount=1&landingPath=NotLandingPage&groups=C0048%3A1%2CC0001%3A1%2CC0040%3A0%2CC0032%3A0%2CC0025%3A0%2CC0020%3A0%2CC0037%3A0%2CC0039%3A0%2CC0036%3A0%2CC0041%3A0%2CC0042%3A0%2CC0044%3A0%2CC0043%3A0%2CC0045%3A0%2CC0049%3A0%2CC0047%3A0%2CC0023%3A0%2CC0056%3A0%2CC0038%3A0%2CC0082%3A0%2CC0026%3A0%2CC0177%3A0%2CC0113%3A0%2CC0089%3A0%2CC0092%3A0%2CC0190%3A0%2CC0166%3A0%2CC0222%3A0%2CC0223%3A0%2CC0231%3A0%2CC0263%3A0%2CC0004%3A0%2CC0022%3A0%2CC0054%3A0%2CC0179%3A0%2CC0146%3A0%2CC0052%3A0%2CC0034%3A0%2CC0063%3A0%2CC0157%3A0%2CC0003%3A0%2CC0212%3A0%2CC0081%3A0%2CC0051%3A0%2CC0136%3A0%2CC0135%3A0%2CC0007%3A0%2CV2STACK42%3A0&geolocation=FR%3BPAC&AwaitingReconsent=false; __cf_bm=O7iu_B3elAlvScvQCbjrvUOJS5g79er.RQopqf0gyk8-1743689779-1.0.1.1-g1UuluB1PxM27amj_O2ZMMBaaNgIk2UERIZ7BsNh0MUFtm8eW8LKZDkKd_z.a9SPtFGqqcWEUrNC9Xpd_7gvjtRcVK66dz6Qaimij7pURYY; carrefour_counter=1743689787154%7C137739566618166%7Cp0%7Ce0%7Cv1%7Cc254.41%7CServerSide; __cfwaitingroom_www=',
}

params = {
    'page': '3',
    'noRedirect': '1',
}

response = requests.get(
    'https://www.carrefour.fr/r/viandes-et-poissons/volaille-et-rotisserie',
    params=params,
    cookies=cookies,
    headers=headers,
)

# %%
#Loop to get all the page
import time
response_vollaile_1 = []
for x in range(1,12):
    params = {
    'noRedirect': '0',
    'page': str(x) ,
    }
    response = requests.get(
    'https://www.carrefour.fr/r/viandes-et-poissons/volaille-et-rotisserie',
    params=params,
    cookies=cookies,
    headers=headers,
    )
    response_vollaile_1.append(response.json())
    time.sleep(2)

print(response_vollaile_1)
# Out:
# [{'data': [{'type': 'product', 'id': 'product-3266980000134', 'attributes': {'ean': '3266980000134', 'cdbase': '0107794', 'title': 'Poulet jaune PAC Label Rouge FERMIERS DE LOUE', 'brand': None, 'slug': 'poulet-jaune-pac-label-rouge-fermiers-de-loue', 'businessType': 'food', 'offerServiceId': '0261-150-6', 'uri': 'viandes-et-poissons/volaille-et-rotisserie/poulets/poulets-entiers', 'categories': [{'id': '1921', 'code': 'R00F00SF00', 'slug': 'viandes-et-poissons', 'label': 'Viandes et Poissons', 'uri': 'viandes-et-poissons', 'type': 'RAYON', 'level': 1, 'sellerId': None}, {'id': '1931', 'code': 'R00F00SF00', 'slug': 'volaille-et-rotisserie', 'label': 'Volaille et Rôtisserie', 'uri': 'viandes-et-poissons/volaille-et-rotisserie', 'type': 'RAYON', 'level': 2, 'sellerId': None}, {'id': '28439', 'code': 'R00F00SF00', 'slug': 'poulets', 'label': 'Poulets', 'uri': 'viandes-et-poissons/volaille-et-rotisserie/poulets', 'type': 'RAYON', 'level': 3, 'sellerId': None}, {'id': '28440', 'code': 'R0
# ...

# %%
#Loop to get all the page
import time
response_vollaile_2 = []
for x in range(11,22):
    params = {
    'noRedirect': '0',
    'page': str(x) ,
    }
    response = requests.get(
    'https://www.carrefour.fr/r/viandes-et-poissons/volaille-et-rotisserie',
    params=params,
    cookies=cookies,
    headers=headers,
    )
    response_vollaile_2.append(response.json())
    time.sleep(2)

print(response_vollaile_2)
# Out:
# [{'data': [{'type': 'product', 'id': 'product-3276555413863', 'attributes': {'ean': '3276555413863', 'cdbase': '2150252', 'title': 'Demi poulet rôti', 'brand': None, 'slug': 'demi-poulet-roti', 'businessType': 'food', 'offerServiceId': '0261-150-6', 'uri': 'viandes-et-poissons/volaille-et-rotisserie/rotisserie', 'categories': [{'id': '1921', 'code': 'R00F00SF00', 'slug': 'viandes-et-poissons', 'label': 'Viandes et Poissons', 'uri': 'viandes-et-poissons', 'type': 'RAYON', 'level': 1, 'sellerId': None}, {'id': '1931', 'code': 'R00F00SF00', 'slug': 'volaille-et-rotisserie', 'label': 'Volaille et Rôtisserie', 'uri': 'viandes-et-poissons/volaille-et-rotisserie', 'type': 'RAYON', 'level': 2, 'sellerId': None}, {'id': '1932', 'code': 'R00F00SF00', 'slug': 'rotisserie', 'label': 'Rôtisserie', 'uri': 'viandes-et-poissons/volaille-et-rotisserie/rotisserie', 'type': 'RAYON', 'level': 3, 'sellerId': None}], 'topCategoryName': 'Viandes et Poissons', 'images': {'formats': {'largest': '540x540', 'c
# ...

# %%
#Get the relevant columns and extract the price/kg
import pandas as pd

df_vollaile_1 = pd.DataFrame()  # Initialize an empty DataFrame

for item in response_vollaile_1:  # Loop through each JSON object
    try:
        # Ensure 'data' exists and extract it safely
        df_data = pd.DataFrame(item.get('data', []))  
        
        # Ensure 'attributes' exists before normalizing
        if 'attributes' in df_data:
            df_product = pd.json_normalize(df_data['attributes'])
        else:
            print("Warning: 'attributes' key missing in data.")
            continue  # Skip this item if 'attributes' is missing

        price_unit = []
        for x in df_product.get("ean", []):  # Use .get() to avoid KeyError
            try:
                ean_index = df_product[df_product["ean"] == x].index[0]
                price_column = f"offers.{x}.0261-150-6.attributes.price.perUnitLabel"

                # Check if the column exists before accessing
                if price_column in df_product.columns:
                    price_unit_variable = df_product.loc[ean_index, price_column]
                else:
                    price_unit_variable = None  # Default if price column missing

                price_unit.append(price_unit_variable)
            except Exception as e:
                print(f"Error processing EAN {x}: {e}")
                price_unit.append(None)  # Append None for failed entries

        price = []
        for x in df_product.get("ean", []):  # Use .get() to avoid KeyError
            try:
                ean_index = df_product[df_product["ean"] == x].index[0]
                price_column = f"offers.{x}.0261-150-6.attributes.price.price"

                # Check if the column exists before accessing
                if price_column in df_product.columns:
                    price_variable = df_product.loc[ean_index, price_column]
                else:
                    price_variable = None  # Default if price column missing

                price.append(price_variable)
            except Exception as e:
                print(f"Error processing EAN {x}: {e}")
                price.append(None)  # Append None for failed entries

        # Select relevant columns safely
        try:
            df_final = df_product[["title", "slug", "topCategoryName", "origin"]].copy()
        except KeyError as e:
            print(f"Missing column error: {e}")
            continue  # Skip this item if required columns are missing

        # Add price_unit column
        df_final["price_unit"] = price_unit
        df_final["price"] = price

        # Concatenate safely
        df_vollaile_1 = pd.concat([df_vollaile_1, df_final], ignore_index=True)

    except Exception as e:
        print(f"Error processing item: {e}")
        continue  # Skip the item on error

# Print the final DataFrame
print(df_vollaile_1)
# Out:
#                                                  title  \
# 0        Poulet jaune PAC Label Rouge FERMIERS DE LOUE
# 1      Magret de canard du Sud-Ouest REFLETS DE FRANCE
# 2         Escalopes de dinde les milanaises LE GAULOIS
# 3     Escalopes de dinde Label Rouge  FERMIERS DE LOUE
# 4                          Filets de poulet MAITRE COQ
# ..                                                 ...
# 325  1/4 de poulet rôti certifié + pommes de terre ...
# 326                      Escalopes de dinde MAITRE COQ
# 327                              Cuisse de dinde SIMPL
# 328                           Escalopes de dinde SIMPL
# 329  Filets de dinde fermière Label Rouge FERMIERS ...
#
#                                                   slug      topCategoryName  \
# 0        poulet-jaune-pac-label-rouge-fermiers-de-loue  Viandes et Poissons
# 1      magret-de-canard-du-sud-ouest-reflets-de-france  Viandes et Poissons
# ...

# %%
#Get the relevant columns and extract the price/kg
import pandas as pd

df_vollaile_2 = pd.DataFrame()  # Initialize an empty DataFrame

for item in response_vollaile_2:  # Loop through each JSON object
    try:
        # Ensure 'data' exists and extract it safely
        df_data = pd.DataFrame(item.get('data', []))  
        
        # Ensure 'attributes' exists before normalizing
        if 'attributes' in df_data:
            df_product = pd.json_normalize(df_data['attributes'])
        else:
            print("Warning: 'attributes' key missing in data.")
            continue  # Skip this item if 'attributes' is missing

        price_unit = []
        for x in df_product.get("ean", []):  # Use .get() to avoid KeyError
            try:
                ean_index = df_product[df_product["ean"] == x].index[0]
                price_column = f"offers.{x}.0261-150-6.attributes.price.perUnitLabel"

                # Check if the column exists before accessing
                if price_column in df_product.columns:
                    price_unit_variable = df_product.loc[ean_index, price_column]
                else:
                    price_unit_variable = None  # Default if price column missing

                price_unit.append(price_unit_variable)
            except Exception as e:
                print(f"Error processing EAN {x}: {e}")
                price_unit.append(None)  # Append None for failed entries

        price = []
        for x in df_product.get("ean", []):  # Use .get() to avoid KeyError
            try:
                ean_index = df_product[df_product["ean"] == x].index[0]
                price_column = f"offers.{x}.0261-150-6.attributes.price.price"

                # Check if the column exists before accessing
                if price_column in df_product.columns:
                    price_variable = df_product.loc[ean_index, price_column]
                else:
                    price_variable = None  # Default if price column missing

                price.append(price_variable)
            except Exception as e:
                print(f"Error processing EAN {x}: {e}")
                price.append(None)  # Append None for failed entries

        # Select relevant columns safely
        try:
            df_final = df_product[["title", "slug", "topCategoryName", "origin"]].copy()
        except KeyError as e:
            print(f"Missing column error: {e}")
            continue  # Skip this item if required columns are missing

        # Add price_unit column
        df_final["price_unit"] = price_unit
        df_final["price"] = price

        # Concatenate safely
        df_vollaile_2 = pd.concat([df_vollaile_2, df_final], ignore_index=True)

    except Exception as e:
        print(f"Error processing item: {e}")
        continue  # Skip the item on error

# Print the final DataFrame
print(df_vollaile_2)
# Out:
#                                                  title  \
# 0                                     Demi poulet rôti
# 1                                     Demi poulet rôti
# 2                                    Poulet rôti Halal
# 3               Poulet rôti fermier blanc de Normandie
# 4                  Poulet fermier jaune d'Ardèche rôti
# ..                                                 ...
# 302             Cœurs De Canard Crus - Origine France
# 303         Lardons De Canard Séchés - Origine France
# 304  Gratounade De Canard Confit 350 G - Origine Fr...
# 305       Cou De Canard Confit 550 G - Origine France
# 306  Effiloché De Canard Confit Prêt À Cuire - Orig...
#
#                                                   slug      topCategoryName  \
# 0                                     demi-poulet-roti  Viandes et Poissons
# 1                                     demi-poulet-roti  Viandes et Poissons
# ...

# %%
df_vollaile = pd.concat([df_vollaile_1, df_vollaile_2], ignore_index=True)

# %%
df_vollaile
# Out:
#                                                  title  \
# 0        Poulet jaune PAC Label Rouge FERMIERS DE LOUE
# 1      Magret de canard du Sud-Ouest REFLETS DE FRANCE
# 2         Escalopes de dinde les milanaises LE GAULOIS
# 3     Escalopes de dinde Label Rouge  FERMIERS DE LOUE
# 4                          Filets de poulet MAITRE COQ
# ..                                                 ...
# 632             Cœurs De Canard Crus - Origine France
# 633         Lardons De Canard Séchés - Origine France
# 634  Gratounade De Canard Confit 350 G - Origine Fr...
# 635       Cou De Canard Confit 550 G - Origine France
# 636  Effiloché De Canard Confit Prêt À Cuire - Orig...
#
#                                                   slug      topCategoryName  \
# 0        poulet-jaune-pac-label-rouge-fermiers-de-loue  Viandes et Poissons
# 1      magret-de-canard-du-sud-ouest-reflets-de-france  Viandes et Poissons
# ...

# %%
df_vollaile.to_csv("vollaile.csv", index=False)
