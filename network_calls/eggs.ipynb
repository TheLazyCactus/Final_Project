# %%
import requests

cookies = {
    'tc_cj_v2_cmp': '',
    'tc_cj_v2_med': '',
    'tc_ts': '40',
    'FRONTONE_ONLINE': '1745247464',
    'FRONTONE_SESSION_ID': 'fe0e97616cc0dc73679f62b16fa7c577b2d86018',
    'CAID': '202503221557457366701354',
    'OptanonAlertBoxClosed': '2025-03-22T14:57:49.848Z',
    'eupubconsent-v2': 'CQOq1pgQOq1pgAcABBENBiFwAAAAAAAAAChQAAAAAAChIAYAygF5gTAHQAwBlALzAmAOAAgSEJQAQF5lIAYAygF5gTAA.YAAAAAAAAAAA',
    'OneTrustGroupsConsent': '%2CC0048%2CC0001%2C',
    'FRONTONE_SESSID': 'uim3dg95re0gh6j1p6jnc30adj',
    'sap-closed': '1',
    'tc_eff_params': '',
    'tc_ab': '1',
    'aaaaaaaaa944fac35b02f4d9a99619247b88ad463_cs': '',
    'cf_chl_rc_i': '1',
    'cf_clearance': 'iAdgcdq9uVYSHLQkOFY84Qrlja3tKYvd1CbC4LoRSjE-1743682068-1.2.1.1-kNUAUOTviDK6.Gmz8b11GqRgGa1o3YVIodY2o6iSLvQTx7u9S_XsjVsAPpIQfEi5YCvyiGej0j8cfCit1ZAE6xLWShL4gtteCDIqqSnzbDhgMu7gGZNjLEROzl7bKEvgLaNHtSS073X7NXqo5qIjBosGfQaxfXPHv4baAIKkTZLoNRqPbIkWBhUuBsf_q3Jo.ObJPgzlfa5myu4EMbQYUSGNH2stQSe0FjprPKNueAxzoGDW3UUUxDbCbXzMgjv_VLn_mNOpmWa9Mw6cdgNjnrZhjpfuf.BxQ9hxvcbuuK_2gKrUtNVlc73tVn03eiLjQSCWbwY_BC.jFK3cM05GbZ.8YtMv1Jj_PeRpQCVROgY5AT0730cqc0sftA._KcVp',
    'tc_cj_v2': '%5Ecl_%5Dny%5B%5D%5D_mmZZZZZZKQNLPOONPSSJKZZZ%5D777m_iZZZ%2C2%7B%29%2FZZZKQNMLOJOSNKMQZZZ%5D777%5Ecl_%5Dny%5B%5D%5D_mmZZZZZZKQNMPRLNOSLOOZZZ%5D',
    'pageCounterCrfOne': '20',
    'OptanonConsent': 'isGpcEnabled=0&datestamp=Thu+Apr+03+2025+14%3A14%3A19+GMT%2B0200+(heure+d%E2%80%99%C3%A9t%C3%A9+d%E2%80%99Europe+centrale)&version=202310.2.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=92a3e744-b25d-4e54-a023-8625a83bd02f&interactionCount=1&landingPath=NotLandingPage&groups=C0048%3A1%2CC0001%3A1%2CC0040%3A0%2CC0032%3A0%2CC0025%3A0%2CC0020%3A0%2CC0037%3A0%2CC0039%3A0%2CC0036%3A0%2CC0041%3A0%2CC0042%3A0%2CC0044%3A0%2CC0043%3A0%2CC0045%3A0%2CC0049%3A0%2CC0047%3A0%2CC0023%3A0%2CC0056%3A0%2CC0038%3A0%2CC0082%3A0%2CC0026%3A0%2CC0177%3A0%2CC0113%3A0%2CC0089%3A0%2CC0092%3A0%2CC0190%3A0%2CC0166%3A0%2CC0222%3A0%2CC0223%3A0%2CC0231%3A0%2CC0263%3A0%2CC0004%3A0%2CC0022%3A0%2CC0054%3A0%2CC0179%3A0%2CC0146%3A0%2CC0052%3A0%2CC0034%3A0%2CC0063%3A0%2CC0157%3A0%2CC0003%3A0%2CC0212%3A0%2CC0081%3A0%2CC0051%3A0%2CC0136%3A0%2CC0135%3A0%2CC0007%3A0%2CV2STACK42%3A0&geolocation=FR%3BPAC&AwaitingReconsent=false',
    'carrefour_counter': '1743682460577%7C137739566618166%7Cp0%7Ce0%7Cv1%7Cc254.41%7CServerSide',
    '__cf_bm': 'Wt8KayPbw5RGitd84E.UhLgNuldF1.1xBQoeAxRw_qo-1743682458-1.0.1.1-GV5m8OpELLf..U6wd6lZLR4Wta2WKOfxtsZtws27cJic6xRAeY.Jb1OxU23jBoz0v0uXV3PZej_z96R_NuWGIGmlITERlwUfUP4gy6N0Ks4',
    '__cfwaitingroom_www': '',
}

headers = {
    'accept': 'application/json, text/plain, */*',
    'accept-language': 'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7',
    'priority': 'u=1, i',
    'referer': 'https://www.carrefour.fr/r/cremerie/oeufs',
    'sec-ch-ua': '"Chromium";v="134", "Not:A-Brand";v="24", "Google Chrome";v="134"',
    'sec-ch-ua-arch': '"x86"',
    'sec-ch-ua-bitness': '"64"',
    'sec-ch-ua-full-version': '"134.0.6998.178"',
    'sec-ch-ua-full-version-list': '"Chromium";v="134.0.6998.178", "Not:A-Brand";v="24.0.0.0", "Google Chrome";v="134.0.6998.178"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-model': '""',
    'sec-ch-ua-platform': '"Windows"',
    'sec-ch-ua-platform-version': '"10.0.0"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest',
    # 'cookie': 'tc_cj_v2_cmp=; tc_cj_v2_med=; tc_ts=40; FRONTONE_ONLINE=1745247464; FRONTONE_SESSION_ID=fe0e97616cc0dc73679f62b16fa7c577b2d86018; CAID=202503221557457366701354; OptanonAlertBoxClosed=2025-03-22T14:57:49.848Z; eupubconsent-v2=CQOq1pgQOq1pgAcABBENBiFwAAAAAAAAAChQAAAAAAChIAYAygF5gTAHQAwBlALzAmAOAAgSEJQAQF5lIAYAygF5gTAA.YAAAAAAAAAAA; OneTrustGroupsConsent=%2CC0048%2CC0001%2C; FRONTONE_SESSID=uim3dg95re0gh6j1p6jnc30adj; sap-closed=1; tc_eff_params=; tc_ab=1; aaaaaaaaa944fac35b02f4d9a99619247b88ad463_cs=; cf_chl_rc_i=1; cf_clearance=iAdgcdq9uVYSHLQkOFY84Qrlja3tKYvd1CbC4LoRSjE-1743682068-1.2.1.1-kNUAUOTviDK6.Gmz8b11GqRgGa1o3YVIodY2o6iSLvQTx7u9S_XsjVsAPpIQfEi5YCvyiGej0j8cfCit1ZAE6xLWShL4gtteCDIqqSnzbDhgMu7gGZNjLEROzl7bKEvgLaNHtSS073X7NXqo5qIjBosGfQaxfXPHv4baAIKkTZLoNRqPbIkWBhUuBsf_q3Jo.ObJPgzlfa5myu4EMbQYUSGNH2stQSe0FjprPKNueAxzoGDW3UUUxDbCbXzMgjv_VLn_mNOpmWa9Mw6cdgNjnrZhjpfuf.BxQ9hxvcbuuK_2gKrUtNVlc73tVn03eiLjQSCWbwY_BC.jFK3cM05GbZ.8YtMv1Jj_PeRpQCVROgY5AT0730cqc0sftA._KcVp; tc_cj_v2=%5Ecl_%5Dny%5B%5D%5D_mmZZZZZZKQNLPOONPSSJKZZZ%5D777m_iZZZ%2C2%7B%29%2FZZZKQNMLOJOSNKMQZZZ%5D777%5Ecl_%5Dny%5B%5D%5D_mmZZZZZZKQNMPRLNOSLOOZZZ%5D; pageCounterCrfOne=20; OptanonConsent=isGpcEnabled=0&datestamp=Thu+Apr+03+2025+14%3A14%3A19+GMT%2B0200+(heure+d%E2%80%99%C3%A9t%C3%A9+d%E2%80%99Europe+centrale)&version=202310.2.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=92a3e744-b25d-4e54-a023-8625a83bd02f&interactionCount=1&landingPath=NotLandingPage&groups=C0048%3A1%2CC0001%3A1%2CC0040%3A0%2CC0032%3A0%2CC0025%3A0%2CC0020%3A0%2CC0037%3A0%2CC0039%3A0%2CC0036%3A0%2CC0041%3A0%2CC0042%3A0%2CC0044%3A0%2CC0043%3A0%2CC0045%3A0%2CC0049%3A0%2CC0047%3A0%2CC0023%3A0%2CC0056%3A0%2CC0038%3A0%2CC0082%3A0%2CC0026%3A0%2CC0177%3A0%2CC0113%3A0%2CC0089%3A0%2CC0092%3A0%2CC0190%3A0%2CC0166%3A0%2CC0222%3A0%2CC0223%3A0%2CC0231%3A0%2CC0263%3A0%2CC0004%3A0%2CC0022%3A0%2CC0054%3A0%2CC0179%3A0%2CC0146%3A0%2CC0052%3A0%2CC0034%3A0%2CC0063%3A0%2CC0157%3A0%2CC0003%3A0%2CC0212%3A0%2CC0081%3A0%2CC0051%3A0%2CC0136%3A0%2CC0135%3A0%2CC0007%3A0%2CV2STACK42%3A0&geolocation=FR%3BPAC&AwaitingReconsent=false; carrefour_counter=1743682460577%7C137739566618166%7Cp0%7Ce0%7Cv1%7Cc254.41%7CServerSide; __cf_bm=Wt8KayPbw5RGitd84E.UhLgNuldF1.1xBQoeAxRw_qo-1743682458-1.0.1.1-GV5m8OpELLf..U6wd6lZLR4Wta2WKOfxtsZtws27cJic6xRAeY.Jb1OxU23jBoz0v0uXV3PZej_z96R_NuWGIGmlITERlwUfUP4gy6N0Ks4; __cfwaitingroom_www=',
}

params = {
    'noRedirect': '0',
    'page': '2',
}

response = requests.get('https://www.carrefour.fr/r/cremerie/oeufs', params=params, cookies=cookies, headers=headers)

# %%
#Loop to get all the page
import time
response_1 = []
for x in range(1,11):
    params = {
    'noRedirect': '0',
    'page': str(x) ,
    }
    response = requests.get(
    'https://www.carrefour.fr/r/cremerie/oeufs',
    params=params,
    cookies=cookies,
    headers=headers,
    )
    response_1.append(response.json())
    time.sleep(2)

print(response_1)
# Out:
# [{'data': [{'type': 'product', 'id': 'product-3560070874989', 'attributes': {'ean': '3560070874989', 'cdbase': '5053365', 'title': 'Œufs plein air CARREFOUR', 'brand': None, 'slug': 'oeufs-plein-air-carrefour', 'businessType': 'food', 'offerServiceId': '0261-150-6', 'uri': 'chandeleur/chandeleur', 'categories': [{'id': '36993', 'code': 'R00F00SF00', 'slug': 'cremerie', 'label': 'Crèmerie et Produits laitiers', 'uri': 'cremerie', 'type': 'RAYON', 'level': 1, 'sellerId': None}, {'id': '28143', 'code': 'R00F00SF00', 'slug': 'oeufs', 'label': 'Œufs', 'uri': 'cremerie/oeufs', 'type': 'RAYON', 'level': 2, 'sellerId': None}], 'topCategoryName': 'Crèmerie et Produits laitiers', 'images': {'formats': {'largest': '540x540', 'common': ['43x43', '200x200', '540x540', '1500x1500']}, 'paths': ['https://media.carrefour.fr/medias/dd64758fa212490b8f639d3e2afdd87f/p_FORMAT/3560070874989_0.jpg', 'https://media.carrefour.fr/medias/c69152960e1448d49d213d7eba62fa5f/p_FORMAT/3560070874989_1.jpg', 'https://media.carrefour.fr/medias/43bed4bfe2b94c76ad0caadeadc7ff04/p_FORMAT/3560070874989_3.jpg', 'https://media.carrefour.fr/medias/2259ea1c18ee4dd99385edf8416cec39/p_FORMAT/3560070874989_4.jpg', 'https://media.carrefour.fr/medias/aac711f26b1a43aa840085b810d0c62e/p_FORMAT/3560070874989_7.jpg']}, 'isDonation': False, 'isBestSeller': False, 'traceability': None, 'keyFeatures': [], 'moreOffers': {'count': 0, 'bestOfferId': None, 'bestOfferPrice': None, 'hasNonFoodDeliveryOffer': False, 'isRexEligible': False, 'withdrawalDelivery': {'exists': False, 'expressWithdrawalEligibility': {'global': False, 'inCurrentStore': False}}, 'hasCarrefourPlus': False}, 'offers': {'3560070874989': {'0261-150-6': {'type': 'offer', 'subType': 'carrefour', 'id': '0261-150-6', 'attributes': {'availability': {'indispensable': False, 'purchasable': True, 'stopped': False, 'suspended': False, 'suspensionReason': None, 'hasLowQuantity': False}, 'preorder': None, 'price': {'price': 3.39, 'taxMessage': '', 'unitOfMeasure': 'U', 'perUnit': 0.28, 'perUnitLabel': '0.28 € / U'}, 'ordering': {'min': 1, 'step': 1, 'max': 50}, 'offerServiceId': '0261-150-6', 'highlightLabel': None, 'freshness': {'value': 7, 'period': 'day'}, 'marketplace': None, 'ean': '3560070874989', 'promotion': None, 'promotions': [{'type': 'rd_offre_pass', 'label': '-15% Mardi PASS', 'message': 'promotion.rd_offre_pass', 'isLoyalty': True, 'isPromo': False, 'isPrixBarre': False, 'isPrixForce': False, 'isVuEnCatalogue': False, 'isCrescendo': False, 'isClubActive': False, 'promotionParts': [], 'progression': {'current': None, 'total': None, 'completed': None}, 'bestQuantity': 1, 'messageArgs': {'quantity': 1, 'discountAmount': 0.51, 'discountedPrice': 3.39, 'initialPrice': 3.39, 'discountedPricePerUnit': None, 'startDate': '2025-01-01T00:00:00+0100', 'endDate': '2026-12-31T23:59:00+0100'}, 'promoStartDate': '2025-01-01T00:00:00+0100', 'promoEndDate': '2026-12-31T23:59:00+0100', 'mixableGtins': [], 'isPriceAlreadyDiscounted': False, 'mandateId': ['1120250000004776'], 'isDisplayed': False}], 'variableWeight': False, 'isRexEligible': False, 'expressWithdrawalEligibility': {'global': False, 'inCurrentStore': False}, 'isNonFoodDelivery': False, 'isRelayPointEligible': False, 'description': None, 'shopReturnPolicy': None, 'bundle': {'label': None}, 'isNew': False, 'isInnovation': False, 'isAlternativeCheaper': False, 'isDigitalCard': False, 'isWholesale': False, 'isClcv': False, 'isZiqy': False, 'isHealthy': False, 'isPhysicalStoreOffer': False, 'isExpressDelivery': False, 'isRecoverable': False, 'guarantees': []}, 'meta': {'cta': 'buy'}, 'links': {'self': ''}}}}, 'packaging': 'la boite de 12', 'deliveryModalities': [], 'flags': ['flag.common.qualityline', 'flag.common.gmofree'], 'clubs': [], 'origin': '', 'format': '12 œufs', 'nutriscore': None, 'customerReviews': {'average': 4.48, 'count': 335, 'rates': None}, 'variants': [], 'weightsAndMeasures': [], 'guarantee_general_document': 'https://static-cms.carrefour.fr/sites/default/ ...

# %%
#Get the relevant columns and extract the price/kg
import pandas as pd

df_1 = pd.DataFrame()  # Initialize an empty DataFrame

for item in response_1:  # Loop through each JSON object
    try:
        # Ensure 'data' exists and extract it safely
        df_data = pd.DataFrame(item.get('data', []))  
        
        # Ensure 'attributes' exists before normalizing
        if 'attributes' in df_data:
            df_product = pd.json_normalize(df_data['attributes'])
        else:
            print("Warning: 'attributes' key missing in data.")
            continue  # Skip this item if 'attributes' is missing

        price_unit = []
        for x in df_product.get("ean", []):  # Use .get() to avoid KeyError
            try:
                ean_index = df_product[df_product["ean"] == x].index[0]
                price_column = f"offers.{x}.0261-150-6.attributes.price.perUnitLabel"

                # Check if the column exists before accessing
                if price_column in df_product.columns:
                    price_unit_variable = df_product.loc[ean_index, price_column]
                else:
                    price_unit_variable = None  # Default if price column missing

                price_unit.append(price_unit_variable)
            except Exception as e:
                print(f"Error processing EAN {x}: {e}")
                price_unit.append(None)  # Append None for failed entries

        price = []
        for x in df_product.get("ean", []):  # Use .get() to avoid KeyError
            try:
                ean_index = df_product[df_product["ean"] == x].index[0]
                price_column = f"offers.{x}.0261-150-6.attributes.price.price"

                # Check if the column exists before accessing
                if price_column in df_product.columns:
                    price_variable = df_product.loc[ean_index, price_column]
                else:
                    price_variable = None  # Default if price column missing

                price.append(price_variable)
            except Exception as e:
                print(f"Error processing EAN {x}: {e}")
                price.append(None)  # Append None for failed entries

        # Select relevant columns safely
        try:
            df_final = df_product[["title", "slug", "topCategoryName", "origin"]].copy()
        except KeyError as e:
            print(f"Missing column error: {e}")
            continue  # Skip this item if required columns are missing

        # Add price_unit column
        df_final["price_unit"] = price_unit
        df_final["price"] = price


        # Concatenate safely
        df_1 = pd.concat([df_1, df_final], ignore_index=True)

    except Exception as e:
        print(f"Error processing item: {e}")
        continue  # Skip the item on error

# Print the final DataFrame
print(df_1)
# Out:
# Warning: 'attributes' key missing in data.
# Warning: 'attributes' key missing in data.
# Warning: 'attributes' key missing in data.
#                                                  title  \
# 0                             Œufs plein air CARREFOUR
# 1                     Œufs bio frais REFLETS DE FRANCE
# 2                               Œufs Bio CARREFOUR BIO
# 3                    Œufs plein air CARREFOUR ORIGINAL
# 4                             Œuf Bio REFS.SANS MARQUE
# ..                                                 ...
# 192                      Œufs de Plein Air Label Rouge
# 193                                           Œufs Bio
# 194  Œufs de poules élevées en plein air L'OEUF DE REY
# 195                          Œufs  Bio NOUS ANTI GASPI
# 196                    Œufs  plein air NOUS ANTI GASPI
#
#                                                   slug  \
# 0                            oeufs-plein-air-carrefour
# 1                    oeufs-bio-frais-reflets-de-france
# 2                              oeufs-bio-carrefour-bio
# 3                   oeufs-plein-air-carrefour-original
# 4                            oeuf-bio-refs-sans-marque
# ..                                                 ...
# 192                     oeufs-de-plein-air-label-rouge
# 193                                          oeufs-bio
# 194  oeufs-de-poules-elevees-en-plein-air-l-oeuf-de...
# 195                          oeufs-bio-nous-anti-gaspi
# 196                    oeufs-plein-air-nous-anti-gaspi
#
#                    topCategoryName origin  price_unit  price
# 0    Crèmerie et Produits laitiers         0.28 € / U   3.39
# 1    Crèmerie et Produits laitiers         0.49 € / U   2.95
# 2    Crèmerie et Produits laitiers         0.36 € / U   2.19
# 3    Crèmerie et Produits laitiers         0.25 € / U   2.99
# 4    Crèmerie et Produits laitiers         0.60 € / U   5.95
# ..                             ...    ...         ...    ...
# 192  Crèmerie et Produits laitiers         0.26 € / U   3.10
# 193  Crèmerie et Produits laitiers         0.42 € / U   4.19
# 194  Crèmerie et Produits laitiers         0.24 € / U   4.39
# 195  Crèmerie et Produits laitiers         0.35 € / U   2.09
# 196  Crèmerie et Produits laitiers         0.22 € / U   1.35
#
# [197 rows x 6 columns]

# %%
df_1.to_csv("egg.csv", index=False)
