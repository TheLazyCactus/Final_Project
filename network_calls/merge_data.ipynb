# %%
import pandas as pd


boeuf = pd.read_csv(r"D:\Documents\GitHub\Final_Project\file_for_reference\boeuf.csv")
beurre = pd.read_csv(r"D:\Documents\GitHub\Final_Project\file_for_reference\beurre.csv")
biere = pd.read_csv(r"D:\Documents\GitHub\Final_Project\file_for_reference\biere.csv")
biscuit = pd.read_csv(r"D:\Documents\GitHub\Final_Project\file_for_reference\biscuit.csv")
bonbon = pd.read_csv(r"D:\Documents\GitHub\Final_Project\file_for_reference\bonbon.csv")
cafe = pd.read_csv(r"D:\Documents\GitHub\Final_Project\file_for_reference\cafe.csv")
cans = pd.read_csv(r"D:\Documents\GitHub\Final_Project\file_for_reference\cans.csv")
carbs = pd.read_csv(r"D:\Documents\GitHub\Final_Project\file_for_reference\carbs.csv")
cheese = pd.read_csv(r"D:\Documents\GitHub\Final_Project\file_for_reference\cheese.csv")
cheese_2 = pd.read_csv(r"D:\Documents\GitHub\Final_Project\file_for_reference\cheese_2.csv")
dessert = pd.read_csv(r"D:\Documents\GitHub\Final_Project\file_for_reference\dessert.csv")
egg = pd.read_csv(r"D:\Documents\GitHub\Final_Project\file_for_reference\egg.csv")
frozen = pd.read_csv(r"D:\Documents\GitHub\Final_Project\file_for_reference\frozen.csv")
fruit = pd.read_csv(r"D:\Documents\GitHub\Final_Project\file_for_reference\fruit.csv")
lait = pd.read_csv(r"D:\Documents\GitHub\Final_Project\file_for_reference\lait.csv")
mer = pd.read_csv(r"D:\Documents\GitHub\Final_Project\file_for_reference\mer.csv")
oil = pd.read_csv(r"D:\Documents\GitHub\Final_Project\file_for_reference\oil.csv")
poisson = pd.read_csv(r"D:\Documents\GitHub\Final_Project\file_for_reference\poisson.csv")
soda = pd.read_csv(r"D:\Documents\GitHub\Final_Project\file_for_reference\soda.csv")
the = pd.read_csv(r"D:\Documents\GitHub\Final_Project\file_for_reference\the.csv")
vin = pd.read_csv(r"D:\Documents\GitHub\Final_Project\file_for_reference\vin.csv")
vollaile = pd.read_csv(r"D:\Documents\GitHub\Final_Project\file_for_reference\vollaile.csv")
yaourt = pd.read_csv(r"D:\Documents\GitHub\Final_Project\file_for_reference\yaourt.csv")

# %%
boeuf
# Out:
#                                           title  \
# 0    Carpaccio bœuf parmesan et marinade CHARAL
# 1       Brochettes de boeuf CARREFOUR LE MARCHE
# 2                  Brochettes de bœuf CARREFOUR
# 3        Brochettes de bœuf haché nature SOCOPA
# 4          Brochettes bœuf haché Tex-mex SOCOPA
# ..                                          ...
# 235                              T BONE GALICE
# 236                         Bavette Européenne
# 237                Frais Côte De Boeuf Confité
# 238                       Filet Portioné 200gr
# 239                                     Tataki
#
#                                             slug      topCategoryName  \
# 0    carpaccio-boeuf-parmesan-et-marinade-charal  Viandes et Poissons
# 1        brochettes-de-boeuf-carrefour-le-marche  Viandes et Poissons
# 2                  brochettes-de-boeuf-carrefour  Viandes et Poissons
# 3        brochettes-de-boeuf-hache-nature-socopa  Viandes et Poissons
# 4          brochettes-boeuf-hache-tex-mex-socopa  Viandes et Poissons
# ..                                           ...                  ...
# 235                                t-bone-galice  Viandes et Poissons
# 236                           bavette-europeenne  Viandes et Poissons
# 237                  frais-cote-de-boeuf-confite  Viandes et Poissons
# 238                         filet-portione-200gr  Viandes et Poissons
# 239                                       tataki  Viandes et Poissons
#
#       origin    price_unit
# 0     FRANCE  28.70 € / KG
# 1     FRANCE  20.30 € / KG
# 2     FRANCE  18.32 € / KG
# 3     FRANCE  13.00 € / KG
# 4     FRANCE  12.98 € / KG
# ..       ...           ...
# 235  ESPAGNE           NaN
# 236      NaN           NaN
# 237      NaN           NaN
# 238      NaN           NaN
# 239      NaN           NaN
#
# [240 rows x 5 columns]

# %%
import pandas as pd
import glob

# Define the folder path
folder_path = r"D:\Documents\GitHub\Final_Project\file_for_reference"

# List of all CSV files
csv_files = [
    "boeuf.csv", "beurre.csv", "biere.csv", "biscuit.csv", "bonbon.csv",
    "cafe.csv", "cans.csv", "carbs.csv", "cheese.csv", "cheese_2.csv",
    "dessert.csv", "egg.csv", "frozen.csv", "fruit.csv", "lait.csv",
    "mer.csv", "oil.csv", "poisson.csv", "soda.csv", "the.csv",
    "vin.csv", "vollaile.csv", "yaourt.csv"
]

# Read and merge all CSV files
df_list = [pd.read_csv(f"{folder_path}\\{file}") for file in csv_files]
merged_df = pd.concat(df_list, ignore_index=True)

# Save the merged DataFrame to a new CSV file
merged_df.to_csv(r"D:\Documents\GitHub\Final_Project\file_for_reference\merged_data.csv", index=False)

print("CSV files merged successfully!")
# Out:
# CSV files merged successfully!

# %%
non_null_count = merged_df["price_unit"].count()
print(non_null_count)
# Out:
# 18163

# %%
import re

#Handle exception
merged_df['slug'] = merged_df['slug'].apply(lambda x: "chocolat" if re.search("choco", x, re.IGNORECASE) else x)
merged_df['slug'] = merged_df['slug'].apply(lambda x: "chocolat" if re.search("cacao", x, re.IGNORECASE) else x)
merged_df['slug'] = merged_df['slug'].apply(lambda x: "boeuf" if re.search("merguez", x, re.IGNORECASE) else x)
merged_df['slug'] = merged_df['slug'].apply(lambda x: "porc" if re.search("chipolata", x, re.IGNORECASE) else x)

# %%
#change/L to /kg
merged_df["price_unit"] = merged_df["price_unit"].replace("€ / L", "€ / KG")

# %%
#Extract /U and check weight per unit
filtered_df = merged_df[merged_df["price_unit"].str.contains("€ / U", na=False)]
filtered_df.count()
#Only 541 values so we will get rid of them
# Out:
# title              541
# slug               541
# topCategoryName    541
# origin             279
# price_unit         541
# dtype: int64

# %%
merged_df = merged_df[~merged_df["price_unit"].str.contains("€ / U", na=False)]
# Save the merged DataFrame to a new CSV file
merged_df.to_csv(r"D:\Documents\GitHub\Final_Project\file_for_reference\merged_data.csv", index=False)

# %% [markdown]
# Add footprint part

# %%
reference = pd.read_csv(r"D:\Documents\GitHub\Final_Project\file_for_reference\reference_product.csv")

# %%
reference
# Out:
#             slug  footprint    farming  processing  packaging  transport  \
# 0        abricot   1.451508   0.347000    0.000108      0.657      0.342
# 1            ail   0.383493   0.084100    0.000193        NaN      0.198
# 2         ananas   1.361435   0.368000    0.000034        NaN      0.645
# 3      artichaut   2.556166   0.615000    0.000266        NaN      0.596
# 4        asperge   1.638878   0.970000    0.000178        NaN      0.417
# ..           ...        ...        ...         ...        ...        ...
# 136       tomate   0.625600   0.222000         NaN        NaN      0.298
# 137  topinambour   0.491266   0.270000    0.000067        NaN      0.170
# 138         veau  22.504653  21.833333    0.074033      0.217      0.302
# 139          vin   1.268630   0.301000    0.033100      0.679      0.233
# 140       yaourt   1.894730   1.030000    0.152000      0.422      0.247
#
#      retail  consumption
# 0    0.0248     0.080600
# 1    0.0206     0.080600
# 2    0.0254     0.323000
# 3    0.0549     1.290000
# 4    0.0367     0.215000
# ..      ...          ...
# 136  0.0250     0.080600
# 137  0.0189     0.032300
# 138  0.0440     0.034287
# 139  0.0157     0.006830
# 140  0.0369     0.006830
#
# [141 rows x 8 columns]

# %%
unique_list = reference["slug"].unique()
unique_list
# Out:
# array(['abricot', 'ail', 'ananas', 'artichaut', 'asperge', 'aubergine',
#        'avocat', 'avoine', 'baguette', 'banane', 'betterave', 'beurre',
#        'biere', 'ble', 'blette', 'boeuf', 'bonbons', 'boulgour',
#        'brocoli', 'burgerpoulet', 'burgervegetarien', 'cabillaud', 'cafe',
#        'canard', 'carambole', 'carotte', 'cassis', 'celeri', 'cerise',
#        'champignon', 'chataigne', 'chaussonauxpommes', 'cheeseburger',
#        'chocolat', 'chou', 'choudebruxelles', 'choufleur', 'citron',
#        'clementine', 'coing', 'concombre', 'courge', 'courgette',
#        'cresson', 'crevettes', 'croissant', 'datte', 'dorade',
#        'eauenbouteille', 'echalote', 'endive', 'epinard', 'fenouil',
#        'feta', 'figue', 'fraise', 'framboise', 'frites', 'fromage',
#        'fromageblanc', 'fruitdelapassion', 'grenade', 'groseille',
#        'haricotsrouges', 'haricotvert', 'huiledecolza', 'huiledepalme',
#        'huiledesoja', 'huiledetournesol', 'huiledolive', 'huitres',
#        'kaki', 'kebab', 'kiwi', 'lait', 'laitue', 'lapin', 'lentilles',
#        'lieu', 'mache', 'madeleine', 'mais', 'mandarine', 'mangue',
#        'manguebateau', 'matieregrasse', 'melon', 'moules', 'mozarella',
#        'mure', 'myrtille', 'navet', 'nectarine', 'noisette', 'noix',
#        'noixdecoco', 'oeuf', 'oignon', 'orange', 'orge', 'painauxraisins',
#        'paindemie', 'pamplemousse', 'panais', 'pasteque', 'pateatartiner',
#        'pates', 'peche', 'petitpois', 'pizza', 'poire', 'poireau',
#        'poischiches', 'poivron', 'pomme', 'pommedeterre', 'porc',
#        'potiron', 'poulet', 'prune', 'radis', 'raisin', 'reineclaude',
#        'rhubarbe', 'riz', 'salsifis', 'sardines', 'saumon', 'seigle',
#        'soda', 'soja', 'sucre', 'sushis', 'the', 'thon', 'tofu', 'tomate',
#        'topinambour', 'veau', 'vin', 'yaourt'], dtype=object)

# %%
import numpy as np

for col in unique_list:
    merged_df[col] = np.nan

print(merged_df)
# Out:
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\3327391957.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[col] = np.nan
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\3327391957.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[col] = np.nan
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\3327391957.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[col] = np.nan
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\3327391957.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[col] = np.nan
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\3327391957.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[col] = np.nan
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\3327391957.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[col] = np.nan
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\3327391957.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[col] = np.nan
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\3327391957.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[col] = np.nan
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\3327391957.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[col] = np.nan
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\3327391957.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[col] = np.nan
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\3327391957.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[col] = np.nan
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\3327391957.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[col] = np.nan
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\3327391957.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[col] = np.nan
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\3327391957.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[col] = np.nan
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\3327391957.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[col] = np.nan
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\3327391957.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[col] = np.nan
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\3327391957.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[col] = np.nan
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\3327391957.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[col] = np.nan
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\3327391957.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[col] = np.nan
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\3327391957.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[col] = np.nan
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\3327391957.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[col] = np.nan
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\3327391957.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[col] = np.nan
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\3327391957.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[col] = np.nan
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\3327391957.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[col] = np.nan
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\3327391957.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[col] = np.nan
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\3327391957.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[col] = np.nan
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\3327391957.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[col] = np.nan
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\3327391957.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[col] = np.nan
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\3327391957.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[col] = np.nan
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\3327391957.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[col] = np.nan
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\3327391957.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[col] = np.nan
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\3327391957.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[col] = np.nan
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\3327391957.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[col] = np.nan
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\3327391957.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[col] = np.nan
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\3327391957.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[col] = np.nan
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\3327391957.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[col] = np.nan
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\3327391957.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[col] = np.nan
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\3327391957.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[col] = np.nan
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\3327391957.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[col] = np.nan
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\3327391957.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[col] = np.nan
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\3327391957.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[col] = np.nan
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\3327391957.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_df[col] = np.nan
#                                                    title  \
# 0             Carpaccio bœuf parmesan et marinade CHARAL
# 1                Brochettes de boeuf CARREFOUR LE MARCHE
# 2                           Brochettes de bœuf CARREFOUR
# 3                 Brochettes de bœuf haché nature SOCOPA
# 4                   Brochettes bœuf haché Tex-mex SOCOPA
# ...                                                  ...
# 20903                                      Ayran  SUNTAT
# 20904  Yaourt à boire protéiné saveur vanille LINDAHL...
# 20905                       Boisson lactée cacao NESQUIK
# 20906              Boisson Lactée Saveur Cookies NESCAFE
# 20907           Petit suisse aux fruits Bio LES 2 VACHES
#
#                                                     slug  \
# 0            carpaccio-boeuf-parmesan-et-marinade-charal
# 1                brochettes-de-boeuf-carrefour-le-marche
# 2                          brochettes-de-boeuf-carrefour
# 3                brochettes-de-boeuf-hache-nature-socopa
# 4                  brochettes-boeuf-hache-tex-mex-socopa
# ...                                                  ...
# 20903                                       ayran-suntat
# 20904  yaourt-a-boire-proteine-saveur-vanille-lindahl...
# 20905                                           chocolat
# 20906              boisson-lactee-saveur-cookies-nescafe
# 20907           petit-suisse-aux-fruits-bio-les-2-vaches
#
#                      topCategoryName  origin    price_unit  abricot  ail  \
# 0                Viandes et Poissons  FRANCE  28.70 € / KG      NaN  NaN
# 1                Viandes et Poissons  FRANCE  20.30 € / KG      NaN  NaN
# 2                Viandes et Poissons  FRANCE  18.32 € / KG      NaN  NaN
# 3                Viandes et Poissons  FRANCE  13.00 € / KG      NaN  NaN
# 4                Viandes et Poissons  FRANCE  12.98 € / KG      NaN  NaN
# ...                              ...     ...           ...      ...  ...
# 20903  Crèmerie et Produits laitiers     NaN   1.84 € / KG      NaN  NaN
# 20904  Crèmerie et Produits laitiers     NaN    7.00 € / L      NaN  NaN
# 20905  Crèmerie et Produits laitiers     NaN    7.46 € / L      NaN  NaN
# 20906  Crèmerie et Produits laitiers     NaN    7.46 € / L      NaN  NaN
# 20907  Crèmerie et Produits laitiers     NaN   6.63 € / KG      NaN  NaN
#
#        ananas  artichaut  asperge  ...  sucre  sushis  the  thon  tofu  \
# 0         NaN        NaN      NaN  ...    NaN     NaN  NaN   NaN   NaN
# 1         NaN        NaN      NaN  ...    NaN     NaN  NaN   NaN   NaN
# 2         NaN        NaN      NaN  ...    NaN     NaN  NaN   NaN   NaN
# 3         NaN        NaN      NaN  ...    NaN     NaN  NaN   NaN   NaN
# 4         NaN        NaN      NaN  ...    NaN     NaN  NaN   NaN   NaN
# ...       ...        ...      ...  ...    ...     ...  ...   ...   ...
# 20903     NaN        NaN      NaN  ...    NaN     NaN  NaN   NaN   NaN
# 20904     NaN        NaN      NaN  ...    NaN     NaN  NaN   NaN   NaN
# 20905     NaN        NaN      NaN  ...    NaN     NaN  NaN   NaN   NaN
# 20906     NaN        NaN      NaN  ...    NaN     NaN  NaN   NaN   NaN
# 20907     NaN        NaN      NaN  ...    NaN     NaN  NaN   NaN   NaN
#
#        tomate  topinambour  veau  vin  yaourt
# 0         NaN          NaN   NaN  NaN     NaN
# 1         NaN          NaN   NaN  NaN     NaN
# 2         NaN          NaN   NaN  NaN     NaN
# 3         NaN          NaN   NaN  NaN     NaN
# 4         NaN          NaN   NaN  NaN     NaN
# ...       ...          ...   ...  ...     ...
# 20903     NaN          NaN   NaN  NaN     NaN
# 20904     NaN          NaN   NaN  NaN     NaN
# 20905     NaN          NaN   NaN  NaN     NaN
# 20906     NaN          NaN   NaN  NaN     NaN
# 20907     NaN          NaN   NaN  NaN     NaN
#
# [20367 rows x 146 columns]

# %%
merged_df
# Out:
#                                                    title  \
# 0             Carpaccio bœuf parmesan et marinade CHARAL
# 1                Brochettes de boeuf CARREFOUR LE MARCHE
# 2                           Brochettes de bœuf CARREFOUR
# 3                 Brochettes de bœuf haché nature SOCOPA
# 4                   Brochettes bœuf haché Tex-mex SOCOPA
# ...                                                  ...
# 20903                                      Ayran  SUNTAT
# 20904  Yaourt à boire protéiné saveur vanille LINDAHL...
# 20905                       Boisson lactée cacao NESQUIK
# 20906              Boisson Lactée Saveur Cookies NESCAFE
# 20907           Petit suisse aux fruits Bio LES 2 VACHES
#
#                                                     slug  \
# 0            carpaccio-boeuf-parmesan-et-marinade-charal
# 1                brochettes-de-boeuf-carrefour-le-marche
# 2                          brochettes-de-boeuf-carrefour
# 3                brochettes-de-boeuf-hache-nature-socopa
# 4                  brochettes-boeuf-hache-tex-mex-socopa
# ...                                                  ...
# 20903                                       ayran-suntat
# 20904  yaourt-a-boire-proteine-saveur-vanille-lindahl...
# 20905                                           chocolat
# 20906              boisson-lactee-saveur-cookies-nescafe
# 20907           petit-suisse-aux-fruits-bio-les-2-vaches
#
#                      topCategoryName  origin    price_unit  abricot  ail  \
# 0                Viandes et Poissons  FRANCE  28.70 € / KG      NaN  NaN
# 1                Viandes et Poissons  FRANCE  20.30 € / KG      NaN  NaN
# 2                Viandes et Poissons  FRANCE  18.32 € / KG      NaN  NaN
# 3                Viandes et Poissons  FRANCE  13.00 € / KG      NaN  NaN
# 4                Viandes et Poissons  FRANCE  12.98 € / KG      NaN  NaN
# ...                              ...     ...           ...      ...  ...
# 20903  Crèmerie et Produits laitiers     NaN   1.84 € / KG      NaN  NaN
# 20904  Crèmerie et Produits laitiers     NaN    7.00 € / L      NaN  NaN
# 20905  Crèmerie et Produits laitiers     NaN    7.46 € / L      NaN  NaN
# 20906  Crèmerie et Produits laitiers     NaN    7.46 € / L      NaN  NaN
# 20907  Crèmerie et Produits laitiers     NaN   6.63 € / KG      NaN  NaN
#
#        ananas  artichaut  asperge  ...  sucre  sushis  the  thon  tofu  \
# 0         NaN        NaN      NaN  ...    NaN     NaN  NaN   NaN   NaN
# 1         NaN        NaN      NaN  ...    NaN     NaN  NaN   NaN   NaN
# 2         NaN        NaN      NaN  ...    NaN     NaN  NaN   NaN   NaN
# 3         NaN        NaN      NaN  ...    NaN     NaN  NaN   NaN   NaN
# 4         NaN        NaN      NaN  ...    NaN     NaN  NaN   NaN   NaN
# ...       ...        ...      ...  ...    ...     ...  ...   ...   ...
# 20903     NaN        NaN      NaN  ...    NaN     NaN  NaN   NaN   NaN
# 20904     NaN        NaN      NaN  ...    NaN     NaN  NaN   NaN   NaN
# 20905     NaN        NaN      NaN  ...    NaN     NaN  NaN   NaN   NaN
# 20906     NaN        NaN      NaN  ...    NaN     NaN  NaN   NaN   NaN
# 20907     NaN        NaN      NaN  ...    NaN     NaN  NaN   NaN   NaN
#
#        tomate  topinambour  veau  vin  yaourt
# 0         NaN          NaN   NaN  NaN     NaN
# 1         NaN          NaN   NaN  NaN     NaN
# 2         NaN          NaN   NaN  NaN     NaN
# 3         NaN          NaN   NaN  NaN     NaN
# 4         NaN          NaN   NaN  NaN     NaN
# ...       ...          ...   ...  ...     ...
# 20903     NaN          NaN   NaN  NaN     NaN
# 20904     NaN          NaN   NaN  NaN     NaN
# 20905     NaN          NaN   NaN  NaN     NaN
# 20906     NaN          NaN   NaN  NaN     NaN
# 20907     NaN          NaN   NaN  NaN     NaN
#
# [20367 rows x 146 columns]

# %%
keywords = merged_df.columns[5:]
keywords
# Out:
# Index(['abricot', 'ail', 'ananas', 'artichaut', 'asperge', 'aubergine',
#        'avocat', 'avoine', 'baguette', 'banane',
#        ...
#        'sucre', 'sushis', 'the', 'thon', 'tofu', 'tomate', 'topinambour',
#        'veau', 'vin', 'yaourt'],
#       dtype='object', length=141)

# %%
from Levenshtein import ratio 

# Function to check partial match and update DataFrame
def mark_keywords(row):
    for keyword in keywords:
        for word in row['slug'].split('_'):  # Split product name into words
            if re.search(keyword, word, re.IGNORECASE) or ratio(keyword, word) > 0.85:  # Allow slight variations
                row[keyword] = 'X'
    return row

# Apply function to each row
df_result = merged_df.apply(mark_keywords, axis=1)

print(df_result)
# Out:
#                                                    title  \
# 0             Carpaccio bœuf parmesan et marinade CHARAL
# 1                Brochettes de boeuf CARREFOUR LE MARCHE
# 2                           Brochettes de bœuf CARREFOUR
# 3                 Brochettes de bœuf haché nature SOCOPA
# 4                   Brochettes bœuf haché Tex-mex SOCOPA
# ...                                                  ...
# 20903                                      Ayran  SUNTAT
# 20904  Yaourt à boire protéiné saveur vanille LINDAHL...
# 20905                       Boisson lactée cacao NESQUIK
# 20906              Boisson Lactée Saveur Cookies NESCAFE
# 20907           Petit suisse aux fruits Bio LES 2 VACHES
#
#                                                     slug  \
# 0            carpaccio-boeuf-parmesan-et-marinade-charal
# 1                brochettes-de-boeuf-carrefour-le-marche
# 2                          brochettes-de-boeuf-carrefour
# 3                brochettes-de-boeuf-hache-nature-socopa
# 4                  brochettes-boeuf-hache-tex-mex-socopa
# ...                                                  ...
# 20903                                       ayran-suntat
# 20904  yaourt-a-boire-proteine-saveur-vanille-lindahl...
# 20905                                           chocolat
# 20906              boisson-lactee-saveur-cookies-nescafe
# 20907           petit-suisse-aux-fruits-bio-les-2-vaches
#
#                      topCategoryName  origin    price_unit abricot  ail  \
# 0                Viandes et Poissons  FRANCE  28.70 € / KG     NaN  NaN
# 1                Viandes et Poissons  FRANCE  20.30 € / KG     NaN  NaN
# 2                Viandes et Poissons  FRANCE  18.32 € / KG     NaN  NaN
# 3                Viandes et Poissons  FRANCE  13.00 € / KG     NaN  NaN
# 4                Viandes et Poissons  FRANCE  12.98 € / KG     NaN  NaN
# ...                              ...     ...           ...     ...  ...
# 20903  Crèmerie et Produits laitiers     NaN   1.84 € / KG     NaN  NaN
# 20904  Crèmerie et Produits laitiers     NaN    7.00 € / L     NaN  NaN
# 20905  Crèmerie et Produits laitiers     NaN    7.46 € / L     NaN  NaN
# 20906  Crèmerie et Produits laitiers     NaN    7.46 € / L     NaN  NaN
# 20907  Crèmerie et Produits laitiers     NaN   6.63 € / KG     NaN  NaN
#
#       ananas artichaut asperge  ... sucre sushis  the thon tofu tomate  \
# 0        NaN       NaN     NaN  ...   NaN    NaN  NaN  NaN  NaN    NaN
# 1        NaN       NaN     NaN  ...   NaN    NaN  NaN  NaN  NaN    NaN
# 2        NaN       NaN     NaN  ...   NaN    NaN  NaN  NaN  NaN    NaN
# 3        NaN       NaN     NaN  ...   NaN    NaN  NaN  NaN  NaN    NaN
# 4        NaN       NaN     NaN  ...   NaN    NaN  NaN  NaN  NaN    NaN
# ...      ...       ...     ...  ...   ...    ...  ...  ...  ...    ...
# 20903    NaN       NaN     NaN  ...   NaN    NaN  NaN  NaN  NaN    NaN
# 20904    NaN       NaN     NaN  ...   NaN    NaN  NaN  NaN  NaN    NaN
# 20905    NaN       NaN     NaN  ...   NaN    NaN  NaN  NaN  NaN    NaN
# 20906    NaN       NaN     NaN  ...   NaN    NaN  NaN  NaN  NaN    NaN
# 20907    NaN       NaN     NaN  ...   NaN    NaN  NaN  NaN  NaN    NaN
#
#       topinambour veau  vin yaourt
# 0             NaN  NaN  NaN    NaN
# 1             NaN  NaN  NaN    NaN
# 2             NaN  NaN  NaN    NaN
# 3             NaN  NaN  NaN    NaN
# 4             NaN  NaN  NaN    NaN
# ...           ...  ...  ...    ...
# 20903         NaN  NaN  NaN    NaN
# 20904         NaN  NaN  NaN      X
# 20905         NaN  NaN  NaN    NaN
# 20906         NaN  NaN  NaN    NaN
# 20907         NaN  NaN  NaN    NaN
#
# [20367 rows x 146 columns]

# %%
def get_footprint(row):
    for column in df_result.columns:
        # Check if the value in df is not empty (not None or NaN)
        if pd.notna(row[column]):
            # Find the corresponding footprint in the 'reference' DataFrame
            footprint_value = reference.loc[reference['slug'] == column, 'footprint'].values
            if footprint_value.size > 0:
                return footprint_value[0]  # Return the footprint value for the matched product
    return None  # If no non-empty values are found


# Apply the function to each row in df
df_result['footprint'] = df_result.apply(get_footprint, axis=1)

#Framing
def get_farming(row):
    for column in df_result.columns:
        # Check if the value in df is not empty (not None or NaN)
        if pd.notna(row[column]):
            # Find the corresponding footprint in the 'reference' DataFrame
            farming_value = reference.loc[reference['slug'] == column, 'farming'].values
            if farming_value.size > 0:
                return farming_value[0]  # Return the footprint value for the matched product
    return None  # If no non-empty values are found


# Apply the function to each row in df
df_result['farming'] = df_result.apply(get_farming, axis=1)

#Processing
def get_processing(row):
    for column in df_result.columns:
        # Check if the value in df is not empty (not None or NaN)
        if pd.notna(row[column]):
            # Find the corresponding footprint in the 'reference' DataFrame
            processing_value = reference.loc[reference['slug'] == column, 'processing'].values
            if processing_value.size > 0:
                return processing_value[0]  # Return the footprint value for the matched product
    return None  # If no non-empty values are found


# Apply the function to each row in df
df_result['processing'] = df_result.apply(get_processing, axis=1)

#Packaging
def get_packaging(row):
    for column in df_result.columns:
        # Check if the value in df is not empty (not None or NaN)
        if pd.notna(row[column]):
            # Find the corresponding footprint in the 'reference' DataFrame
            packaging_value = reference.loc[reference['slug'] == column, 'packaging'].values
            if packaging_value.size > 0:
                return packaging_value[0]  # Return the footprint value for the matched product
    return None  # If no non-empty values are found


# Apply the function to each row in df
df_result['packaging'] = df_result.apply(get_packaging, axis=1)

#Retail
def get_retail(row):
    for column in df_result.columns:
        # Check if the value in df is not empty (not None or NaN)
        if pd.notna(row[column]):
            # Find the corresponding footprint in the 'reference' DataFrame
            retail_value = reference.loc[reference['slug'] == column, 'retail'].values
            if retail_value.size > 0:
                return retail_value[0]  # Return the footprint value for the matched product
    return None  # If no non-empty values are found


# Apply the function to each row in df
df_result['retail'] = df_result.apply(get_retail, axis=1)

#Transport
def get_transport(row):
    for column in df_result.columns:
        # Check if the value in df is not empty (not None or NaN)
        if pd.notna(row[column]):
            # Find the corresponding footprint in the 'reference' DataFrame
            transport_value = reference.loc[reference['slug'] == column, 'transport'].values
            if transport_value.size > 0:
                return transport_value[0]  # Return the footprint value for the matched product
    return None  # If no non-empty values are found


# Apply the function to each row in df
df_result['transport'] = df_result.apply(get_transport, axis=1)

#Consumption
def get_consumption(row):
    for column in df_result.columns:
        # Check if the value in df is not empty (not None or NaN)
        if pd.notna(row[column]):
            # Find the corresponding footprint in the 'reference' DataFrame
            consumption_value = reference.loc[reference['slug'] == column, 'consumption'].values
            if consumption_value.size > 0:
                return consumption_value[0]  # Return the footprint value for the matched product
    return None  # If no non-empty values are found


# Apply the function to each row in df
df_result['consumption'] = df_result.apply(get_consumption, axis=1)
# Out:
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\1175754737.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_result['footprint'] = df_result.apply(get_footprint, axis=1)
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\1175754737.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_result['farming'] = df_result.apply(get_farming, axis=1)
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\1175754737.py:43: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_result['processing'] = df_result.apply(get_processing, axis=1)
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\1175754737.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_result['packaging'] = df_result.apply(get_packaging, axis=1)
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\1175754737.py:73: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_result['retail'] = df_result.apply(get_retail, axis=1)
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\1175754737.py:88: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_result['transport'] = df_result.apply(get_transport, axis=1)
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_20124\1175754737.py:103: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_result['consumption'] = df_result.apply(get_consumption, axis=1)

# %%
df_result
# Out:
#                                                    title  \
# 0             Carpaccio bœuf parmesan et marinade CHARAL
# 1                Brochettes de boeuf CARREFOUR LE MARCHE
# 2                           Brochettes de bœuf CARREFOUR
# 3                 Brochettes de bœuf haché nature SOCOPA
# 4                   Brochettes bœuf haché Tex-mex SOCOPA
# ...                                                  ...
# 20903                                      Ayran  SUNTAT
# 20904  Yaourt à boire protéiné saveur vanille LINDAHL...
# 20905                       Boisson lactée cacao NESQUIK
# 20906              Boisson Lactée Saveur Cookies NESCAFE
# 20907           Petit suisse aux fruits Bio LES 2 VACHES
#
#                                                     slug  \
# 0            carpaccio-boeuf-parmesan-et-marinade-charal
# 1                brochettes-de-boeuf-carrefour-le-marche
# 2                          brochettes-de-boeuf-carrefour
# 3                brochettes-de-boeuf-hache-nature-socopa
# 4                  brochettes-boeuf-hache-tex-mex-socopa
# ...                                                  ...
# 20903                                       ayran-suntat
# 20904  yaourt-a-boire-proteine-saveur-vanille-lindahl...
# 20905                                           chocolat
# 20906              boisson-lactee-saveur-cookies-nescafe
# 20907           petit-suisse-aux-fruits-bio-les-2-vaches
#
#                      topCategoryName  origin    price_unit abricot  ail  \
# 0                Viandes et Poissons  FRANCE  28.70 € / KG     NaN  NaN
# 1                Viandes et Poissons  FRANCE  20.30 € / KG     NaN  NaN
# 2                Viandes et Poissons  FRANCE  18.32 € / KG     NaN  NaN
# 3                Viandes et Poissons  FRANCE  13.00 € / KG     NaN  NaN
# 4                Viandes et Poissons  FRANCE  12.98 € / KG     NaN  NaN
# ...                              ...     ...           ...     ...  ...
# 20903  Crèmerie et Produits laitiers     NaN   1.84 € / KG     NaN  NaN
# 20904  Crèmerie et Produits laitiers     NaN    7.00 € / L     NaN  NaN
# 20905  Crèmerie et Produits laitiers     NaN    7.46 € / L     NaN  NaN
# 20906  Crèmerie et Produits laitiers     NaN    7.46 € / L     NaN  NaN
# 20907  Crèmerie et Produits laitiers     NaN   6.63 € / KG     NaN  NaN
#
#       ananas artichaut asperge  ... veau  vin yaourt  footprint    farming  \
# 0        NaN       NaN     NaN  ...  NaN  NaN    NaN  28.009170  27.316667
# 1        NaN       NaN     NaN  ...  NaN  NaN    NaN  28.009170  27.316667
# 2        NaN       NaN     NaN  ...  NaN  NaN    NaN  28.009170  27.316667
# 3        NaN       NaN     NaN  ...  NaN  NaN    NaN  28.009170  27.316667
# 4        NaN       NaN     NaN  ...  NaN  NaN    NaN  28.009170  27.316667
# ...      ...       ...     ...  ...  ...  ...    ...        ...        ...
# 20903    NaN       NaN     NaN  ...  NaN  NaN    NaN        NaN        NaN
# 20904    NaN       NaN     NaN  ...  NaN  NaN      X   1.894730   1.030000
# 20905    NaN       NaN     NaN  ...  NaN  NaN    NaN   7.889800   6.687000
# 20906    NaN       NaN     NaN  ...  NaN  NaN    NaN   0.635463   0.436000
# 20907    NaN       NaN     NaN  ...  NaN  NaN    NaN        NaN        NaN
#
#       processing packaging    retail transport consumption
# 0       0.088917     0.217  0.043967  0.308333    0.034287
# 1       0.088917     0.217  0.043967  0.308333    0.034287
# 2       0.088917     0.217  0.043967  0.308333    0.034287
# 3       0.088917     0.217  0.043967  0.308333    0.034287
# 4       0.088917     0.217  0.043967  0.308333    0.034287
# ...          ...       ...       ...       ...         ...
# 20903        NaN       NaN       NaN       NaN         NaN
# 20904   0.152000     0.422  0.036900  0.247000    0.006830
# 20905   0.333000     0.722  0.037000  0.110800         NaN
# 20906   0.018100     0.129  0.000963  0.040200    0.011200
# 20907        NaN       NaN       NaN       NaN         NaN
#
# [20367 rows x 153 columns]

# %%
# Count rows where both 'price_unit' and 'footprint' are NOT null
non_null_count = df_result.dropna(subset=["price_unit", "footprint"]).shape[0]

print(f"Number of rows with no null values in 'price_unit' and 'footprint': {non_null_count}")
# Out:
# Number of rows with no null values in 'price_unit' and 'footprint': 14518

# %%
df_result.count()
# Out:
# title              20367
# slug               20367
# topCategoryName    20367
# origin              4309
# price_unit         17622
#                    ...
# processing         15129
# packaging          13082
# retail             16263
# transport          16263
# consumption        12393
# Length: 153, dtype: int64

# %%
df_result = df_result.rename(columns={"topCategoryName": "product_family"})

# %%
# Save the merged DataFrame to a new CSV file
df_result.to_csv(r"D:\Documents\GitHub\Final_Project\file_for_reference\product_library.csv", index=False)
