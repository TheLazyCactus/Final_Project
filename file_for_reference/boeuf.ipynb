# %% [markdown]
# # Boeuf

# %%
import requests

cookies = {
    'tc_cj_v2_cmp': '',
    'tc_cj_v2_med': '',
    'tc_ts': '40',
    'FRONTONE_ONLINE': '1745247464',
    'FRONTONE_SESSION_ID': 'fe0e97616cc0dc73679f62b16fa7c577b2d86018',
    'CAID': '202503221557457366701354',
    'OptanonAlertBoxClosed': '2025-03-22T14:57:49.848Z',
    'eupubconsent-v2': 'CQOq1pgQOq1pgAcABBENBiFwAAAAAAAAAChQAAAAAAChIAYAygF5gTAHQAwBlALzAmAOAAgSEJQAQF5lIAYAygF5gTAA.YAAAAAAAAAAA',
    'OneTrustGroupsConsent': '%2CC0048%2CC0001%2C',
    'tc_ab': '0',
    'FRONTONE_SESSID': 'uim3dg95re0gh6j1p6jnc30adj',
    'sap-closed': '1',
    'tc_eff_params': '',
    'WID': 'ac1ba23c-7ad7-47aa-bdb4-316ab7c4b6f0',
    'tc_cj_v2': '%5Ecl_%5Dny%5B%5D%5D_mmZZZZZZKQNLPOONPSSJKZZZ%5D777m_iZZZ%2C2%7B%29%2FZZZKQNMLOJOSNKMQZZZ%5D777%5Ecl_%5Dny%5B%5D%5D_mmZZZZZZKQNMLONNMLMQPZZZ%5D',
    'cf_clearance': 'btSxXJc9JYrDu1p0Kx6YXd2sgDvmk2XUAuXff0zU..E-1743262024-1.2.1.1-LRARv3uIE_FW24gaeytXsQ5JulIZPlSUCjR9xIpB7dwWLCEKGmS1Xf4NvvOD7909mF0_QqaqkDD.qCX50RM0gUlu.LGD0.BAeN7aloe7F6F.wmfKMsmUvO2c_TQQEGTIVzWWUJC9xuWCUISjZNBEyKovHRPzyTUAe0hP0A43Bn9NR9dvQIKYCql9nRhvwTCtG4HnoUDkBSTggbQZJw1MRGNOaX4hiXO1UdK3D35MdOKBi5Bf1vWPMCL0wQIAl7_3Lg90kTsyljzpfRlxq.nKhLuUVA_qrviHFyyqGc08EGD8hDk8KOjsn3de1SPDX5fNPW5NuBEgFeqGGKoaohza4zklxCuWTNGCrf8OEh7FYgjQE2SiuLLab7aOO2JbMnixC6NwXMGNwAkOMm6Z5xU1Vuv2KkgurQosAdPCDMtwC4w',
    'pageCounterCrfOne': '7',
    'carrefour_counter': '1743262035915%7C64137448530538%7Cp0%7Ce0%7Cv1%7Cc254.41%7CServerSide',
    'OptanonConsent': 'isGpcEnabled=0&datestamp=Sat+Mar+29+2025+16%3A27%3A19+GMT%2B0100+(heure+normale+d%E2%80%99Europe+centrale)&version=202310.2.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=92a3e744-b25d-4e54-a023-8625a83bd02f&interactionCount=1&landingPath=NotLandingPage&groups=C0048%3A1%2CC0001%3A1%2CC0040%3A0%2CC0032%3A0%2CC0025%3A0%2CC0020%3A0%2CC0037%3A0%2CC0039%3A0%2CC0036%3A0%2CC0041%3A0%2CC0042%3A0%2CC0044%3A0%2CC0043%3A0%2CC0045%3A0%2CC0049%3A0%2CC0047%3A0%2CC0023%3A0%2CC0056%3A0%2CC0038%3A0%2CC0082%3A0%2CC0026%3A0%2CC0177%3A0%2CC0113%3A0%2CC0089%3A0%2CC0092%3A0%2CC0190%3A0%2CC0166%3A0%2CC0222%3A0%2CC0223%3A0%2CC0231%3A0%2CC0263%3A0%2CC0004%3A0%2CC0022%3A0%2CC0054%3A0%2CC0179%3A0%2CC0146%3A0%2CC0052%3A0%2CC0034%3A0%2CC0063%3A0%2CC0157%3A0%2CC0003%3A0%2CC0212%3A0%2CC0081%3A0%2CC0051%3A0%2CC0136%3A0%2CC0135%3A0%2CC0007%3A0%2CV2STACK42%3A0&geolocation=FR%3BPAC&AwaitingReconsent=false',
    '__cf_bm': '0EDEIrI9_K6nd6RkyOJpZf5dqcrFOfwffgjDphUAy8w-1743262041-1.0.1.1-xthoR2cL5nQ4I2tMKrJuQ8Ukzd7CLCfz_0EsR6_fUetXcpNANNK8Ol5ue0qoosMK2UuG4e3dtTF0UW688_qJ7m6.8_cQddWCt78aDBI2NFM',
}

headers = {
    'accept': 'application/json, text/plain, */*',
    'accept-language': 'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7',
    'priority': 'u=1, i',
    'referer': 'https://www.carrefour.fr/r/viandes-et-poissons/boucherie/boeuf?noRedirect=1&page=2',
    'sec-ch-ua': '"Chromium";v="134", "Not:A-Brand";v="24", "Google Chrome";v="134"',
    'sec-ch-ua-arch': '"x86"',
    'sec-ch-ua-bitness': '"64"',
    'sec-ch-ua-full-version': '"134.0.6998.178"',
    'sec-ch-ua-full-version-list': '"Chromium";v="134.0.6998.178", "Not:A-Brand";v="24.0.0.0", "Google Chrome";v="134.0.6998.178"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-model': '""',
    'sec-ch-ua-platform': '"Windows"',
    'sec-ch-ua-platform-version': '"10.0.0"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest',
    # 'cookie': 'tc_cj_v2_cmp=; tc_cj_v2_med=; tc_ts=40; FRONTONE_ONLINE=1745247464; FRONTONE_SESSION_ID=fe0e97616cc0dc73679f62b16fa7c577b2d86018; CAID=202503221557457366701354; OptanonAlertBoxClosed=2025-03-22T14:57:49.848Z; eupubconsent-v2=CQOq1pgQOq1pgAcABBENBiFwAAAAAAAAAChQAAAAAAChIAYAygF5gTAHQAwBlALzAmAOAAgSEJQAQF5lIAYAygF5gTAA.YAAAAAAAAAAA; OneTrustGroupsConsent=%2CC0048%2CC0001%2C; tc_ab=0; FRONTONE_SESSID=uim3dg95re0gh6j1p6jnc30adj; sap-closed=1; tc_eff_params=; WID=ac1ba23c-7ad7-47aa-bdb4-316ab7c4b6f0; tc_cj_v2=%5Ecl_%5Dny%5B%5D%5D_mmZZZZZZKQNLPOONPSSJKZZZ%5D777m_iZZZ%2C2%7B%29%2FZZZKQNMLOJOSNKMQZZZ%5D777%5Ecl_%5Dny%5B%5D%5D_mmZZZZZZKQNMLONNMLMQPZZZ%5D; cf_clearance=btSxXJc9JYrDu1p0Kx6YXd2sgDvmk2XUAuXff0zU..E-1743262024-1.2.1.1-LRARv3uIE_FW24gaeytXsQ5JulIZPlSUCjR9xIpB7dwWLCEKGmS1Xf4NvvOD7909mF0_QqaqkDD.qCX50RM0gUlu.LGD0.BAeN7aloe7F6F.wmfKMsmUvO2c_TQQEGTIVzWWUJC9xuWCUISjZNBEyKovHRPzyTUAe0hP0A43Bn9NR9dvQIKYCql9nRhvwTCtG4HnoUDkBSTggbQZJw1MRGNOaX4hiXO1UdK3D35MdOKBi5Bf1vWPMCL0wQIAl7_3Lg90kTsyljzpfRlxq.nKhLuUVA_qrviHFyyqGc08EGD8hDk8KOjsn3de1SPDX5fNPW5NuBEgFeqGGKoaohza4zklxCuWTNGCrf8OEh7FYgjQE2SiuLLab7aOO2JbMnixC6NwXMGNwAkOMm6Z5xU1Vuv2KkgurQosAdPCDMtwC4w; pageCounterCrfOne=7; carrefour_counter=1743262035915%7C64137448530538%7Cp0%7Ce0%7Cv1%7Cc254.41%7CServerSide; OptanonConsent=isGpcEnabled=0&datestamp=Sat+Mar+29+2025+16%3A27%3A19+GMT%2B0100+(heure+normale+d%E2%80%99Europe+centrale)&version=202310.2.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=92a3e744-b25d-4e54-a023-8625a83bd02f&interactionCount=1&landingPath=NotLandingPage&groups=C0048%3A1%2CC0001%3A1%2CC0040%3A0%2CC0032%3A0%2CC0025%3A0%2CC0020%3A0%2CC0037%3A0%2CC0039%3A0%2CC0036%3A0%2CC0041%3A0%2CC0042%3A0%2CC0044%3A0%2CC0043%3A0%2CC0045%3A0%2CC0049%3A0%2CC0047%3A0%2CC0023%3A0%2CC0056%3A0%2CC0038%3A0%2CC0082%3A0%2CC0026%3A0%2CC0177%3A0%2CC0113%3A0%2CC0089%3A0%2CC0092%3A0%2CC0190%3A0%2CC0166%3A0%2CC0222%3A0%2CC0223%3A0%2CC0231%3A0%2CC0263%3A0%2CC0004%3A0%2CC0022%3A0%2CC0054%3A0%2CC0179%3A0%2CC0146%3A0%2CC0052%3A0%2CC0034%3A0%2CC0063%3A0%2CC0157%3A0%2CC0003%3A0%2CC0212%3A0%2CC0081%3A0%2CC0051%3A0%2CC0136%3A0%2CC0135%3A0%2CC0007%3A0%2CV2STACK42%3A0&geolocation=FR%3BPAC&AwaitingReconsent=false; __cf_bm=0EDEIrI9_K6nd6RkyOJpZf5dqcrFOfwffgjDphUAy8w-1743262041-1.0.1.1-xthoR2cL5nQ4I2tMKrJuQ8Ukzd7CLCfz_0EsR6_fUetXcpNANNK8Ol5ue0qoosMK2UuG4e3dtTF0UW688_qJ7m6.8_cQddWCt78aDBI2NFM',
}

params = {
    'noRedirect': '1',
    'page': '1',
}

response = requests.get(
    'https://www.carrefour.fr/r/viandes-et-poissons/boucherie/boeuf',
    params=params,
    cookies=cookies,
    headers=headers,
)

# %%
import time
response_boeuf = []
for x in range(1,9):
    params = {
    'noRedirect': '0',
    'page': str(x) ,
    }
    response = requests.get(
    'https://www.carrefour.fr/r/viandes-et-poissons/boucherie/boeuf',
    params=params,
    cookies=cookies,
    headers=headers,
    )
    response_boeuf.append(response.json())
    time.sleep(2)

print(response_boeuf)
# Out:
# [{'data': [{'type': 'product', 'id': 'product-3181232180504', 'attributes': {'ean': '3181232180504', 'cdbase': '2690050', 'title': 'Carpaccio bœuf parmesan et marinade CHARAL', 'brand': None, 'slug': 'carpaccio-boeuf-parmesan-et-marinade-charal', 'businessType': 'food', 'offerServiceId': '0261-150-6', 'uri': 'viandes-et-poissons/boucherie/boeuf', 'categories': [{'id': '1921', 'code': 'R00F00SF00', 'slug': 'viandes-et-poissons', 'label': 'Viandes et Poissons', 'uri': 'viandes-et-poissons', 'type': 'RAYON', 'level': 1, 'sellerId': None}, {'id': '1922', 'code': 'R00F00SF00', 'slug': 'boucherie', 'label': 'Boucherie', 'uri': 'viandes-et-poissons/boucherie', 'type': 'RAYON', 'level': 2, 'sellerId': None}, {'id': '1924', 'code': 'R00F00SF00', 'slug': 'boeuf', 'label': 'Boeuf', 'uri': 'viandes-et-poissons/boucherie/boeuf', 'type': 'RAYON', 'level': 3, 'sellerId': None}], 'topCategoryName': 'Viandes et Poissons', 'images': {'formats': {'largest': '540x540', 'common': ['43x43', '200x200', '54
# ...

# %%
response_boeuf
# Out:
# [{'data': [{'type': 'product',
#     'id': 'product-3181232180504',
#     'attributes': {'ean': '3181232180504',
#      'cdbase': '2690050',
#      'title': 'Carpaccio bœuf parmesan et marinade CHARAL',
#      'brand': None,
#      'slug': 'carpaccio-boeuf-parmesan-et-marinade-charal',
#      'businessType': 'food',
#      'offerServiceId': '0261-150-6',
#      'uri': 'viandes-et-poissons/boucherie/boeuf',
#      'categories': [{'id': '1921',
#        'code': 'R00F00SF00',
#        'slug': 'viandes-et-poissons',
#        'label': 'Viandes et Poissons',
#        'uri': 'viandes-et-poissons',
#        'type': 'RAYON',
#        'level': 1,
#        'sellerId': None},
#       {'id': '1922',
#        'code': 'R00F00SF00',
#        'slug': 'boucherie',
#        'label': 'Boucherie',
#        'uri': 'viandes-et-poissons/boucherie',
#        'type': 'RAYON',
#        'level': 2,
#        'sellerId': None},
#       {'id': '1924',
#        'code': 'R00F00SF00',
#        'slug': 'boeuf',
# ...

# %%
import pandas as pd
df_boeuf = pd.DataFrame()
for item in response_boeuf:  # Loop through each JSON object
    df_data = pd.DataFrame(item.get('data', []))  # Convert 'data' to DataFrame
    df_product = pd.json_normalize(df_data['attributes'])  # Normalize 'attributes'
    
    price_unit = []
    for x in df_product["ean"]:
        ean_index = df_product[df_product["ean"] == x].index[0]
        price_unit_variable = df_product.loc[ean_index, f"offers.{x}.0261-150-6.attributes.price.perUnitLabel" ]
        price_unit.append(price_unit_variable)

    df_final = df_product[["title", "slug", "topCategoryName", "origin"]]
    df_final["price_unit"] = price_unit


    df_boeuf = pd.concat([df_boeuf , df_final])
# Out:
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_12824\4046442274.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["price_unit"] = price_unit
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_12824\4046442274.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["price_unit"] = price_unit
# C:\Users\UTILISATEUR\AppData\Local\Temp\ipykernel_12824\4046442274.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df_finale.shape
# Out:
# (240, 12254)

# %%
df_product.shape
# Out:
# (30, 1673)

# %%
import pandas as pd

df_boeuf = pd.DataFrame()  # Initialize an empty DataFrame

for item in response_boeuf:  # Loop through each JSON object
    try:
        # Ensure 'data' exists and extract it safely
        df_data = pd.DataFrame(item.get('data', []))  
        
        # Ensure 'attributes' exists before normalizing
        if 'attributes' in df_data:
            df_product = pd.json_normalize(df_data['attributes'])
        else:
            print("Warning: 'attributes' key missing in data.")
            continue  # Skip this item if 'attributes' is missing

        price_unit = []
        for x in df_product.get("ean", []):  # Use .get() to avoid KeyError
            try:
                ean_index = df_product[df_product["ean"] == x].index[0]
                price_column = f"offers.{x}.0261-150-6.attributes.price.perUnitLabel"

                # Check if the column exists before accessing
                if price_column in df_product.columns:
                    price_unit_variable = df_product.loc[ean_index, price_column]
                else:
                    price_unit_variable = None  # Default if price column missing

                price_unit.append(price_unit_variable)
            except Exception as e:
                print(f"Error processing EAN {x}: {e}")
                price_unit.append(None)  # Append None for failed entries

        # Select relevant columns safely
        try:
            df_final = df_product[["title", "slug", "topCategoryName", "origin"]].copy()
        except KeyError as e:
            print(f"Missing column error: {e}")
            continue  # Skip this item if required columns are missing

        # Add price_unit column
        df_final["price_unit"] = price_unit

        # Concatenate safely
        df_boeuf = pd.concat([df_boeuf, df_final], ignore_index=True)

    except Exception as e:
        print(f"Error processing item: {e}")
        continue  # Skip the item on error

# Print the final DataFrame
print(df_boeuf)
# Out:
#                                           title  \
# 0    Carpaccio bœuf parmesan et marinade CHARAL
# 1       Brochettes de boeuf CARREFOUR LE MARCHE
# 2                  Brochettes de bœuf CARREFOUR
# 3        Brochettes de bœuf haché nature SOCOPA
# 4          Brochettes bœuf haché Tex-mex SOCOPA
# ..                                          ...
# 235                              T BONE GALICE
# 236                         Bavette Européenne
# 237                Frais Côte De Boeuf Confité
# 238                       Filet Portioné 200gr
# 239                                     Tataki
#
#                                             slug      topCategoryName  \
# 0    carpaccio-boeuf-parmesan-et-marinade-charal  Viandes et Poissons
# 1        brochettes-de-boeuf-carrefour-le-marche  Viandes et Poissons
# 2                  brochettes-de-boeuf-carrefour  Viandes et Poissons
# 3        brochettes-de-boeuf-hache-nature-socopa  Viandes et Poissons
# ...

# %%
df_boeuf["price_unit"].value_counts()
# Out:
# price_unit
# 28.70 € / KG    5
# 24.54 € / KG    3
# 19.98 € / KG    3
# 20.79 € / KG    3
# 9.36 € / KG     3
#                ..
# 13.89 € / KG    1
# 21.40 € / KG    1
# 20.63 € / KG    1
# 24.81 € / KG    1
# 9.54 € / KG     1
# Name: count, Length: 190, dtype: int64

# %%
non_null_count = df_boeuf["price_unit"].count()
print(non_null_count)
# Out:
# 217

# %%
df_boeuf.to_csv("boeuf.csv", index=False)
